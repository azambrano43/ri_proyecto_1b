# %% [markdown]
# ### NOTEBOOKS PARA REALIZAR PRUEBAS Y ANÁLISIS EXPLORATORIO
#
# A continuación se muestra el proceso desde el inicio para construir un buscador en base al corpus de reuters, se realizará cada paso:
# 1. Construcción de un archivo .csv que contenga todos los textos de reuters unificados (corpus).
# 2. Implementación de funciones para preprocesar y normalizar cada texto de reuters.
# 3. Construcción de un nuevo archivo .csv con todos los textos de nuestro corpus preprocesados y normalizados.
# 4. Implementación de las funciones de vectorización (TF-IDF, Bag Of Words, Word2Vec).
# 5. Construcción de un índice inverso que mapee términos a documentos.
# 6. Implementación de funciones de búsqueda que utilicen como base distancia coseno para realizar consultas y obtener los documentos más relevantes de acuerdo al método que se haya escogido (TF-IDF, BOW, Word2Vec, Índice invertido).
#
# Se documentará cada paso del proceso, explicando que librerías son necesarias, que hace cada función y cosas relevantes. Cuando se tengan implementadas ya todas las funcionalidades destacadas anteriormente, se procederá a modularizar las funciones en varios archivos .py para que puedan ser implementados con interfaz.
#
# Nota: Para la interfaz vamos a utilizar Flask, con sus respectivas rutas y demás.

# %%
import pandas as pd
import os
import spacy
import re
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import gensim.downloader as api
import nltk
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from collections import defaultdict


directorio_base = os.path.join(os.getcwd(), "..")  # Volver a directorio RI_PROYECTO_1B

# %%
# Ejecutar una vez para tener las dependencias necesarias de nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')

# %%
# Ejecutar una vez para obtener dependencias necesarias
# %pip install scikit-learn gensim

# %% [markdown]
# ### 1. Construcción del corpus
#
# A partir de todos los archivos de reuters, vamos a construir un solo archivo .csv, en el cual vamos a tener todos estos textos, para este fin vamos a realizar el siguiente proceso:
# 1. Iterar sobre las carpetas /data/test y /data/training
# 2. Iterar sobre cada archivo dentro de esas carpetas
# 3. Obtener el contenido de dicho archivo
# 4. Guardar en una lista [id_archivo, contenido_archivio, path_archivo]
#
# Cuando se finalicen todas las iteraciones, esta lista va a ser convertida en un DataFrame de pandas y, posteriormente a un archivo .csv con sus respectivas 3 columnas mencionadas anteriormente.

# %%
subcarpeta_reuters = [f"{directorio_base}\\data\\training",
                      f"{directorio_base}\\data\\test"]

noticias = []

for subcarpeta in subcarpeta_reuters:
    textos = os.scandir(subcarpeta)

    for texto in textos:
        with open(texto, 'r', encoding='utf-8', errors='ignore') as file:
            nombre_archivo = file.name.split("\\")[-1]
            subcarpeta_texto = subcarpeta.split("\\")[-1]
            print(f"Iterando sobre texto {nombre_archivo} en subcarpeta {subcarpeta_texto}")
            contenido = file.read()

            noticias.append([nombre_archivo, contenido, subcarpeta_texto])
# Out:
# Iterando sobre texto 1 en subcarpeta training
# Iterando sobre texto 10 en subcarpeta training
# Iterando sobre texto 100 en subcarpeta training
# Iterando sobre texto 1000 en subcarpeta training
# Iterando sobre texto 10000 en subcarpeta training
# Iterando sobre texto 10002 en subcarpeta training
# Iterando sobre texto 10005 en subcarpeta training
# Iterando sobre texto 10008 en subcarpeta training
# Iterando sobre texto 10011 en subcarpeta training
# Iterando sobre texto 10014 en subcarpeta training
# Iterando sobre texto 10015 en subcarpeta training
# Iterando sobre texto 10018 en subcarpeta training
# Iterando sobre texto 10023 en subcarpeta training
# Iterando sobre texto 10025 en subcarpeta training
# Iterando sobre texto 10027 en subcarpeta training
# Iterando sobre texto 1003 en subcarpeta training
# Iterando sobre texto 10032 en subcarpeta training
# Iterando sobre texto 10035 en subcarpeta training
# Iterando sobre texto 10037 en subcarpeta training
# Iterando sobre texto 10038 en subcarpeta training
# Iterando sobre texto 10040 en subcarpeta training
# Iterando sobre texto 10041 en subcarpeta training
# Iterando sobre texto 10042 en subcarpeta training
# Iterando sobre texto 10043 en subcarpeta training
# Iterando sobre texto 10046 en subcarpeta training
# Iterando sobre texto 10048 en subcarpeta training
# Iterando sobre texto 10049 en subcarpeta training
# Iterando sobre texto 10050 en subcarpeta training
# Iterando sobre texto 10052 en subcarpeta training
# Iterando sobre texto 10053 en subcarpeta training
# Iterando sobre texto 10054 en subcarpeta training
# Iterando sobre texto 10057 en subcarpeta training
# Iterando sobre texto 10058 en subcarpeta training
# Iterando sobre texto 10061 en subcarpeta training
# Iterando sobre texto 10062 en subcarpeta training
# Iterando sobre texto 10064 en subcarpeta training
# Iterando sobre texto 10065 en subcarpeta training
# Iterando sobre texto 10066 en subcarpeta training
# Iterando sobre texto 10067 en subcarpeta training
# Iterando sobre texto 10068 en subcarpeta training
# Iterando sobre texto 1007 en subcarpeta training
# Iterando sobre texto 10071 en subcarpeta training
# Iterando sobre texto 10073 en subcarpeta training
# Iterando sobre texto 10074 en subcarpeta training
# Iterando sobre texto 10075 en subcarpeta training
# Iterando sobre texto 10076 en subcarpeta training
# Iterando sobre texto 10078 en subcarpeta training
# Iterando sobre texto 10079 en subcarpeta training
# Iterando sobre texto 1008 en subcarpeta training
# Iterando sobre texto 10080 en subcarpeta training
# Iterando sobre texto 10081 en subcarpeta training
# Iterando sobre texto 10083 en subcarpeta training
# Iterando sobre texto 10085 en subcarpeta training
# Iterando sobre texto 10086 en subcarpeta training
# Iterando sobre texto 10088 en subcarpeta training
# Iterando sobre texto 10089 en subcarpeta training
# Iterando sobre texto 1009 en subcarpeta training
# Iterando sobre texto 10090 en subcarpeta training
# Iterando sobre texto 10091 en subcarpeta training
# Iterando sobre texto 10092 en subcarpeta training
# Iterando sobre texto 10094 en subcarpeta training
# Iterando sobre texto 10095 en subcarpeta training
# Iterando sobre texto 10096 en subcarpeta training
# Iterando sobre texto 10097 en subcarpeta training
# Iterando sobre texto 10098 en subcarpeta training
# Iterando sobre texto 10099 en subcarpeta training
# Iterando sobre texto 101 en subcarpeta training
# Iterando sobre texto 1010 en subcarpeta training
# Iterando sobre texto 10100 en subcarpeta training
# Iterando sobre texto 10102 en subcarpeta training
# Iterando sobre texto 10105 en subcarpeta training
# Iterando sobre texto 10106 en subcarpeta training
# Iterando sobre texto 10107 en subcarpeta training
# Iterando sobre texto 10108 en subcarpeta training
# Iterando sobre texto 10109 en subcarpeta training
# Iterando sobre texto 1011 en subcarpeta training
# Iterando sobre texto 10110 en subcarpeta training
# Iterando sobre texto 10112 en subcarpeta training
# Iterando sobre texto 10114 en subcarpeta training
# Iterando sobre texto 10115 en subcarpeta training
# Iterando sobre texto 10119 en subcarpeta training
# Iterando sobre texto 10120 en subcarpeta training
# Iterando sobre texto 10122 en subcarpeta training
# Iterando sobre texto 10124 en subcarpeta training
# Iterando sobre texto 10128 en subcarpeta training
# Iterando sobre texto 10129 en subcarpeta training
# Iterando sobre texto 1013 en subcarpeta training
# Iterando sobre texto 10130 en subcarpeta training
# Iterando sobre texto 10135 en subcarpeta training
# Iterando sobre texto 10136 en subcarpeta training
# Iterando sobre texto 10139 en subcarpeta training
# Iterando sobre texto 10140 en subcarpeta training
# Iterando sobre texto 10146 en subcarpeta training
# Iterando sobre texto 1015 en subcarpeta training
# Iterando sobre texto 10151 en subcarpeta training
# Iterando sobre texto 10153 en subcarpeta training
# Iterando sobre texto 10154 en subcarpeta training
# Iterando sobre texto 10155 en subcarpeta training
# Iterando sobre texto 10156 en subcarpeta training
# Iterando sobre texto 10158 en subcarpeta training
# Iterando sobre texto 1016 en subcarpeta training
# Iterando sobre texto 10162 en subcarpeta training
# Iterando sobre texto 10163 en subcarpeta training
# Iterando sobre texto 10165 en subcarpeta training
# Iterando sobre texto 10168 en subcarpeta training
# Iterando sobre texto 1017 en subcarpeta training
# Iterando sobre texto 10171 en subcarpeta training
# Iterando sobre texto 10172 en subcarpeta training
# Iterando sobre texto 10173 en subcarpeta training
# Iterando sobre texto 10174 en subcarpeta training
# Iterando sobre texto 10175 en subcarpeta training
# Iterando sobre texto 10176 en subcarpeta training
# Iterando sobre texto 10177 en subcarpeta training
# Iterando sobre texto 10178 en subcarpeta training
# Iterando sobre texto 10180 en subcarpeta training
# Iterando sobre texto 10181 en subcarpeta training
# Iterando sobre texto 10183 en subcarpeta training
# Iterando sobre texto 10185 en subcarpeta training
# Iterando sobre texto 10186 en subcarpeta training
# Iterando sobre texto 1019 en subcarpeta training
# Iterando sobre texto 10190 en subcarpeta training
# Iterando sobre texto 10191 en subcarpeta training
# Iterando sobre texto 10192 en subcarpeta training
# Iterando sobre texto 10196 en subcarpeta training
# Iterando sobre texto 10197 en subcarpeta training
# Iterando sobre texto 102 en subcarpeta training
# Iterando sobre texto 1020 en subcarpeta training
# Iterando sobre texto 10200 en subcarpeta training
# Iterando sobre texto 10201 en subcarpeta training
# Iterando sobre texto 10207 en subcarpeta training
# Iterando sobre texto 10208 en subcarpeta training
# Iterando sobre texto 10209 en subcarpeta training
# Iterando sobre texto 10211 en subcarpeta training
# Iterando sobre texto 10213 en subcarpeta training
# Iterando sobre texto 10214 en subcarpeta training
# Iterando sobre texto 10215 en subcarpeta training
# Iterando sobre texto 10216 en subcarpeta training
# Iterando sobre texto 10218 en subcarpeta training
# Iterando sobre texto 10219 en subcarpeta training
# Iterando sobre texto 1022 en subcarpeta training
# Iterando sobre texto 10222 en subcarpeta training
# Iterando sobre texto 10224 en subcarpeta training
# Iterando sobre texto 10225 en subcarpeta training
# Iterando sobre texto 10227 en subcarpeta training
# Iterando sobre texto 10228 en subcarpeta training
# Iterando sobre texto 1023 en subcarpeta training
# Iterando sobre texto 10230 en subcarpeta training
# Iterando sobre texto 10231 en subcarpeta training
# Iterando sobre texto 10233 en subcarpeta training
# Iterando sobre texto 10235 en subcarpeta training
# Iterando sobre texto 10237 en subcarpeta training
# Iterando sobre texto 10238 en subcarpeta training
# Iterando sobre texto 1024 en subcarpeta training
# Iterando sobre texto 10240 en subcarpeta training
# Iterando sobre texto 10242 en subcarpeta training
# Iterando sobre texto 10243 en subcarpeta training
# Iterando sobre texto 10245 en subcarpeta training
# Iterando sobre texto 10246 en subcarpeta training
# Iterando sobre texto 10253 en subcarpeta training
# Iterando sobre texto 10254 en subcarpeta training
# Iterando sobre texto 10255 en subcarpeta training
# Iterando sobre texto 10258 en subcarpeta training
# Iterando sobre texto 1026 en subcarpeta training
# Iterando sobre texto 10260 en subcarpeta training
# Iterando sobre texto 10261 en subcarpeta training
# Iterando sobre texto 10262 en subcarpeta training
# Iterando sobre texto 10263 en subcarpeta training
# Iterando sobre texto 10264 en subcarpeta training
# Iterando sobre texto 10265 en subcarpeta training
# Iterando sobre texto 10268 en subcarpeta training
# Iterando sobre texto 10272 en subcarpeta training
# Iterando sobre texto 10275 en subcarpeta training
# Iterando sobre texto 10277 en subcarpeta training
# Iterando sobre texto 10280 en subcarpeta training
# Iterando sobre texto 10281 en subcarpeta training
# Iterando sobre texto 10282 en subcarpeta training
# Iterando sobre texto 10283 en subcarpeta training
# Iterando sobre texto 10284 en subcarpeta training
# Iterando sobre texto 10285 en subcarpeta training
# Iterando sobre texto 10289 en subcarpeta training
# Iterando sobre texto 1029 en subcarpeta training
# Iterando sobre texto 10291 en subcarpeta training
# Iterando sobre texto 10292 en subcarpeta training
# Iterando sobre texto 10294 en subcarpeta training
# Iterando sobre texto 10295 en subcarpeta training
# Iterando sobre texto 10297 en subcarpeta training
# Iterando sobre texto 10299 en subcarpeta training
# Iterando sobre texto 103 en subcarpeta training
# Iterando sobre texto 1030 en subcarpeta training
# Iterando sobre texto 10300 en subcarpeta training
# Iterando sobre texto 10302 en subcarpeta training
# Iterando sobre texto 10305 en subcarpeta training
# Iterando sobre texto 10306 en subcarpeta training
# Iterando sobre texto 10308 en subcarpeta training
# Iterando sobre texto 10310 en subcarpeta training
# Iterando sobre texto 10311 en subcarpeta training
# Iterando sobre texto 10313 en subcarpeta training
# Iterando sobre texto 10314 en subcarpeta training
# Iterando sobre texto 10315 en subcarpeta training
# Iterando sobre texto 10318 en subcarpeta training
# Iterando sobre texto 10319 en subcarpeta training
# Iterando sobre texto 1032 en subcarpeta training
# Iterando sobre texto 10321 en subcarpeta training
# Iterando sobre texto 10322 en subcarpeta training
# Iterando sobre texto 10323 en subcarpeta training
# Iterando sobre texto 10324 en subcarpeta training
# Iterando sobre texto 10328 en subcarpeta training
# Iterando sobre texto 1033 en subcarpeta training
# Iterando sobre texto 10330 en subcarpeta training
# Iterando sobre texto 10332 en subcarpeta training
# Iterando sobre texto 10334 en subcarpeta training
# Iterando sobre texto 10335 en subcarpeta training
# Iterando sobre texto 10337 en subcarpeta training
# Iterando sobre texto 10338 en subcarpeta training
# Iterando sobre texto 10339 en subcarpeta training
# Iterando sobre texto 10340 en subcarpeta training
# Iterando sobre texto 10341 en subcarpeta training
# Iterando sobre texto 10342 en subcarpeta training
# Iterando sobre texto 10344 en subcarpeta training
# Iterando sobre texto 10347 en subcarpeta training
# Iterando sobre texto 10348 en subcarpeta training
# Iterando sobre texto 10349 en subcarpeta training
# Iterando sobre texto 1035 en subcarpeta training
# Iterando sobre texto 10352 en subcarpeta training
# Iterando sobre texto 10354 en subcarpeta training
# Iterando sobre texto 10355 en subcarpeta training
# Iterando sobre texto 10356 en subcarpeta training
# Iterando sobre texto 10357 en subcarpeta training
# Iterando sobre texto 10358 en subcarpeta training
# Iterando sobre texto 10359 en subcarpeta training
# Iterando sobre texto 1036 en subcarpeta training
# Iterando sobre texto 10361 en subcarpeta training
# Iterando sobre texto 10362 en subcarpeta training
# Iterando sobre texto 10364 en subcarpeta training
# Iterando sobre texto 10367 en subcarpeta training
# Iterando sobre texto 10368 en subcarpeta training
# Iterando sobre texto 10370 en subcarpeta training
# Iterando sobre texto 10371 en subcarpeta training
# Iterando sobre texto 10372 en subcarpeta training
# Iterando sobre texto 10373 en subcarpeta training
# Iterando sobre texto 10375 en subcarpeta training
# Iterando sobre texto 10376 en subcarpeta training
# Iterando sobre texto 10377 en subcarpeta training
# Iterando sobre texto 10381 en subcarpeta training
# Iterando sobre texto 10382 en subcarpeta training
# Iterando sobre texto 10384 en subcarpeta training
# Iterando sobre texto 10385 en subcarpeta training
# Iterando sobre texto 10387 en subcarpeta training
# Iterando sobre texto 10388 en subcarpeta training
# Iterando sobre texto 1039 en subcarpeta training
# Iterando sobre texto 10390 en subcarpeta training
# Iterando sobre texto 10391 en subcarpeta training
# Iterando sobre texto 10393 en subcarpeta training
# Iterando sobre texto 10394 en subcarpeta training
# Iterando sobre texto 10395 en subcarpeta training
# Iterando sobre texto 10397 en subcarpeta training
# Iterando sobre texto 10398 en subcarpeta training
# Iterando sobre texto 10399 en subcarpeta training
# Iterando sobre texto 104 en subcarpeta training
# Iterando sobre texto 1040 en subcarpeta training
# Iterando sobre texto 10401 en subcarpeta training
# Iterando sobre texto 10402 en subcarpeta training
# Iterando sobre texto 10403 en subcarpeta training
# Iterando sobre texto 10404 en subcarpeta training
# Iterando sobre texto 10406 en subcarpeta training
# Iterando sobre texto 10411 en subcarpeta training
# Iterando sobre texto 10412 en subcarpeta training
# Iterando sobre texto 10414 en subcarpeta training
# Iterando sobre texto 10416 en subcarpeta training
# Iterando sobre texto 10418 en subcarpeta training
# Iterando sobre texto 10419 en subcarpeta training
# Iterando sobre texto 10423 en subcarpeta training
# Iterando sobre texto 10427 en subcarpeta training
# Iterando sobre texto 10429 en subcarpeta training
# Iterando sobre texto 10430 en subcarpeta training
# Iterando sobre texto 10431 en subcarpeta training
# Iterando sobre texto 10432 en subcarpeta training
# Iterando sobre texto 10434 en subcarpeta training
# Iterando sobre texto 10435 en subcarpeta training
# Iterando sobre texto 10436 en subcarpeta training
# Iterando sobre texto 10439 en subcarpeta training
# Iterando sobre texto 1044 en subcarpeta training
# Iterando sobre texto 10440 en subcarpeta training
# Iterando sobre texto 10442 en subcarpeta training
# Iterando sobre texto 10444 en subcarpeta training
# Iterando sobre texto 10445 en subcarpeta training
# Iterando sobre texto 10446 en subcarpeta training
# Iterando sobre texto 10447 en subcarpeta training
# Iterando sobre texto 10449 en subcarpeta training
# Iterando sobre texto 10452 en subcarpeta training
# Iterando sobre texto 10453 en subcarpeta training
# Iterando sobre texto 10454 en subcarpeta training
# Iterando sobre texto 10455 en subcarpeta training
# Iterando sobre texto 10458 en subcarpeta training
# Iterando sobre texto 10459 en subcarpeta training
# Iterando sobre texto 10462 en subcarpeta training
# Iterando sobre texto 10464 en subcarpeta training
# Iterando sobre texto 10467 en subcarpeta training
# Iterando sobre texto 1047 en subcarpeta training
# Iterando sobre texto 10470 en subcarpeta training
# Iterando sobre texto 10471 en subcarpeta training
# Iterando sobre texto 10472 en subcarpeta training
# Iterando sobre texto 10473 en subcarpeta training
# Iterando sobre texto 10475 en subcarpeta training
# Iterando sobre texto 10478 en subcarpeta training
# Iterando sobre texto 10484 en subcarpeta training
# Iterando sobre texto 10485 en subcarpeta training
# Iterando sobre texto 10487 en subcarpeta training
# Iterando sobre texto 10489 en subcarpeta training
# Iterando sobre texto 1049 en subcarpeta training
# Iterando sobre texto 10491 en subcarpeta training
# Iterando sobre texto 10494 en subcarpeta training
# Iterando sobre texto 10498 en subcarpeta training
# Iterando sobre texto 10499 en subcarpeta training
# Iterando sobre texto 105 en subcarpeta training
# Iterando sobre texto 1050 en subcarpeta training
# Iterando sobre texto 10500 en subcarpeta training
# Iterando sobre texto 10503 en subcarpeta training
# Iterando sobre texto 10505 en subcarpeta training
# Iterando sobre texto 10506 en subcarpeta training
# Iterando sobre texto 10508 en subcarpeta training
# Iterando sobre texto 10509 en subcarpeta training
# Iterando sobre texto 10515 en subcarpeta training
# Iterando sobre texto 10518 en subcarpeta training
# Iterando sobre texto 10519 en subcarpeta training
# Iterando sobre texto 1052 en subcarpeta training
# Iterando sobre texto 10520 en subcarpeta training
# Iterando sobre texto 10521 en subcarpeta training
# Iterando sobre texto 10524 en subcarpeta training
# Iterando sobre texto 10527 en subcarpeta training
# Iterando sobre texto 10529 en subcarpeta training
# Iterando sobre texto 10530 en subcarpeta training
# Iterando sobre texto 10531 en subcarpeta training
# Iterando sobre texto 10532 en subcarpeta training
# Iterando sobre texto 10534 en subcarpeta training
# Iterando sobre texto 10536 en subcarpeta training
# Iterando sobre texto 10537 en subcarpeta training
# Iterando sobre texto 10538 en subcarpeta training
# Iterando sobre texto 10539 en subcarpeta training
# Iterando sobre texto 10541 en subcarpeta training
# Iterando sobre texto 10542 en subcarpeta training
# Iterando sobre texto 10544 en subcarpeta training
# Iterando sobre texto 10545 en subcarpeta training
# Iterando sobre texto 10546 en subcarpeta training
# Iterando sobre texto 10547 en subcarpeta training
# Iterando sobre texto 10548 en subcarpeta training
# Iterando sobre texto 10551 en subcarpeta training
# Iterando sobre texto 10553 en subcarpeta training
# Iterando sobre texto 10555 en subcarpeta training
# Iterando sobre texto 10556 en subcarpeta training
# Iterando sobre texto 10559 en subcarpeta training
# Iterando sobre texto 10561 en subcarpeta training
# Iterando sobre texto 10563 en subcarpeta training
# Iterando sobre texto 10564 en subcarpeta training
# Iterando sobre texto 10565 en subcarpeta training
# Iterando sobre texto 10566 en subcarpeta training
# Iterando sobre texto 10567 en subcarpeta training
# Iterando sobre texto 10569 en subcarpeta training
# Iterando sobre texto 1057 en subcarpeta training
# Iterando sobre texto 10573 en subcarpeta training
# Iterando sobre texto 10576 en subcarpeta training
# Iterando sobre texto 1058 en subcarpeta training
# Iterando sobre texto 10581 en subcarpeta training
# Iterando sobre texto 10582 en subcarpeta training
# Iterando sobre texto 10584 en subcarpeta training
# Iterando sobre texto 10585 en subcarpeta training
# Iterando sobre texto 10586 en subcarpeta training
# Iterando sobre texto 10587 en subcarpeta training
# Iterando sobre texto 10588 en subcarpeta training
# Iterando sobre texto 1059 en subcarpeta training
# Iterando sobre texto 10590 en subcarpeta training
# Iterando sobre texto 10592 en subcarpeta training
# Iterando sobre texto 10593 en subcarpeta training
# Iterando sobre texto 10594 en subcarpeta training
# Iterando sobre texto 10596 en subcarpeta training
# Iterando sobre texto 10597 en subcarpeta training
# Iterando sobre texto 10598 en subcarpeta training
# Iterando sobre texto 10599 en subcarpeta training
# Iterando sobre texto 106 en subcarpeta training
# Iterando sobre texto 10600 en subcarpeta training
# Iterando sobre texto 10601 en subcarpeta training
# Iterando sobre texto 10602 en subcarpeta training
# Iterando sobre texto 10604 en subcarpeta training
# Iterando sobre texto 10606 en subcarpeta training
# Iterando sobre texto 10608 en subcarpeta training
# Iterando sobre texto 10609 en subcarpeta training
# Iterando sobre texto 10610 en subcarpeta training
# Iterando sobre texto 10611 en subcarpeta training
# Iterando sobre texto 10612 en subcarpeta training
# Iterando sobre texto 10613 en subcarpeta training
# Iterando sobre texto 10615 en subcarpeta training
# Iterando sobre texto 10616 en subcarpeta training
# Iterando sobre texto 10617 en subcarpeta training
# Iterando sobre texto 10618 en subcarpeta training
# Iterando sobre texto 10619 en subcarpeta training
# Iterando sobre texto 10620 en subcarpeta training
# Iterando sobre texto 10621 en subcarpeta training
# Iterando sobre texto 10622 en subcarpeta training
# Iterando sobre texto 10623 en subcarpeta training
# Iterando sobre texto 10625 en subcarpeta training
# Iterando sobre texto 10627 en subcarpeta training
# Iterando sobre texto 1063 en subcarpeta training
# Iterando sobre texto 10632 en subcarpeta training
# Iterando sobre texto 10633 en subcarpeta training
# Iterando sobre texto 10634 en subcarpeta training
# Iterando sobre texto 10636 en subcarpeta training
# Iterando sobre texto 10638 en subcarpeta training
# Iterando sobre texto 10640 en subcarpeta training
# Iterando sobre texto 10641 en subcarpeta training
# Iterando sobre texto 10642 en subcarpeta training
# Iterando sobre texto 10643 en subcarpeta training
# Iterando sobre texto 10644 en subcarpeta training
# Iterando sobre texto 10648 en subcarpeta training
# Iterando sobre texto 1065 en subcarpeta training
# Iterando sobre texto 10650 en subcarpeta training
# Iterando sobre texto 10651 en subcarpeta training
# Iterando sobre texto 10652 en subcarpeta training
# Iterando sobre texto 10653 en subcarpeta training
# Iterando sobre texto 10654 en subcarpeta training
# Iterando sobre texto 10657 en subcarpeta training
# Iterando sobre texto 10658 en subcarpeta training
# Iterando sobre texto 10659 en subcarpeta training
# Iterando sobre texto 1066 en subcarpeta training
# Iterando sobre texto 10660 en subcarpeta training
# Iterando sobre texto 10661 en subcarpeta training
# Iterando sobre texto 10662 en subcarpeta training
# Iterando sobre texto 10665 en subcarpeta training
# Iterando sobre texto 10669 en subcarpeta training
# Iterando sobre texto 1067 en subcarpeta training
# Iterando sobre texto 10674 en subcarpeta training
# Iterando sobre texto 10676 en subcarpeta training
# Iterando sobre texto 10678 en subcarpeta training
# Iterando sobre texto 10679 en subcarpeta training
# Iterando sobre texto 1068 en subcarpeta training
# Iterando sobre texto 10681 en subcarpeta training
# Iterando sobre texto 10682 en subcarpeta training
# Iterando sobre texto 10684 en subcarpeta training
# Iterando sobre texto 10685 en subcarpeta training
# Iterando sobre texto 10687 en subcarpeta training
# Iterando sobre texto 10688 en subcarpeta training
# Iterando sobre texto 10689 en subcarpeta training
# Iterando sobre texto 1069 en subcarpeta training
# Iterando sobre texto 10692 en subcarpeta training
# Iterando sobre texto 10693 en subcarpeta training
# Iterando sobre texto 10694 en subcarpeta training
# Iterando sobre texto 10695 en subcarpeta training
# Iterando sobre texto 10696 en subcarpeta training
# Iterando sobre texto 10699 en subcarpeta training
# Iterando sobre texto 1070 en subcarpeta training
# Iterando sobre texto 10701 en subcarpeta training
# Iterando sobre texto 10702 en subcarpeta training
# Iterando sobre texto 10703 en subcarpeta training
# Iterando sobre texto 10704 en subcarpeta training
# Iterando sobre texto 10705 en subcarpeta training
# Iterando sobre texto 10708 en subcarpeta training
# Iterando sobre texto 10709 en subcarpeta training
# Iterando sobre texto 1071 en subcarpeta training
# Iterando sobre texto 10710 en subcarpeta training
# Iterando sobre texto 10712 en subcarpeta training
# Iterando sobre texto 10714 en subcarpeta training
# Iterando sobre texto 10715 en subcarpeta training
# Iterando sobre texto 10717 en subcarpeta training
# Iterando sobre texto 10718 en subcarpeta training
# Iterando sobre texto 1072 en subcarpeta training
# Iterando sobre texto 10720 en subcarpeta training
# Iterando sobre texto 10721 en subcarpeta training
# Iterando sobre texto 10724 en subcarpeta training
# Iterando sobre texto 10729 en subcarpeta training
# Iterando sobre texto 10731 en subcarpeta training
# Iterando sobre texto 10734 en subcarpeta training
# Iterando sobre texto 10736 en subcarpeta training
# Iterando sobre texto 10737 en subcarpeta training
# Iterando sobre texto 10738 en subcarpeta training
# Iterando sobre texto 1074 en subcarpeta training
# Iterando sobre texto 10742 en subcarpeta training
# Iterando sobre texto 10743 en subcarpeta training
# Iterando sobre texto 10744 en subcarpeta training
# Iterando sobre texto 10746 en subcarpeta training
# Iterando sobre texto 10748 en subcarpeta training
# Iterando sobre texto 10749 en subcarpeta training
# Iterando sobre texto 10750 en subcarpeta training
# Iterando sobre texto 10751 en subcarpeta training
# Iterando sobre texto 10752 en subcarpeta training
# Iterando sobre texto 10754 en subcarpeta training
# Iterando sobre texto 10755 en subcarpeta training
# Iterando sobre texto 10756 en subcarpeta training
# Iterando sobre texto 10757 en subcarpeta training
# Iterando sobre texto 10758 en subcarpeta training
# Iterando sobre texto 1076 en subcarpeta training
# Iterando sobre texto 10760 en subcarpeta training
# Iterando sobre texto 10762 en subcarpeta training
# Iterando sobre texto 10766 en subcarpeta training
# Iterando sobre texto 10767 en subcarpeta training
# Iterando sobre texto 10768 en subcarpeta training
# Iterando sobre texto 10769 en subcarpeta training
# Iterando sobre texto 1077 en subcarpeta training
# Iterando sobre texto 10770 en subcarpeta training
# Iterando sobre texto 10771 en subcarpeta training
# Iterando sobre texto 10773 en subcarpeta training
# Iterando sobre texto 10774 en subcarpeta training
# Iterando sobre texto 10779 en subcarpeta training
# Iterando sobre texto 1078 en subcarpeta training
# Iterando sobre texto 10780 en subcarpeta training
# Iterando sobre texto 10781 en subcarpeta training
# Iterando sobre texto 10782 en subcarpeta training
# Iterando sobre texto 10784 en subcarpeta training
# Iterando sobre texto 10786 en subcarpeta training
# Iterando sobre texto 10787 en subcarpeta training
# Iterando sobre texto 10788 en subcarpeta training
# Iterando sobre texto 1079 en subcarpeta training
# Iterando sobre texto 10790 en subcarpeta training
# Iterando sobre texto 10794 en subcarpeta training
# Iterando sobre texto 10796 en subcarpeta training
# Iterando sobre texto 10797 en subcarpeta training
# Iterando sobre texto 108 en subcarpeta training
# Iterando sobre texto 1080 en subcarpeta training
# Iterando sobre texto 10803 en subcarpeta training
# Iterando sobre texto 10804 en subcarpeta training
# Iterando sobre texto 10805 en subcarpeta training
# Iterando sobre texto 10807 en subcarpeta training
# Iterando sobre texto 10808 en subcarpeta training
# Iterando sobre texto 10809 en subcarpeta training
# Iterando sobre texto 10811 en subcarpeta training
# Iterando sobre texto 10815 en subcarpeta training
# Iterando sobre texto 10816 en subcarpeta training
# Iterando sobre texto 10817 en subcarpeta training
# Iterando sobre texto 1082 en subcarpeta training
# Iterando sobre texto 10822 en subcarpeta training
# Iterando sobre texto 10825 en subcarpeta training
# Iterando sobre texto 10826 en subcarpeta training
# Iterando sobre texto 10827 en subcarpeta training
# Iterando sobre texto 10830 en subcarpeta training
# Iterando sobre texto 10831 en subcarpeta training
# Iterando sobre texto 10832 en subcarpeta training
# Iterando sobre texto 10833 en subcarpeta training
# Iterando sobre texto 10834 en subcarpeta training
# Iterando sobre texto 10839 en subcarpeta training
# Iterando sobre texto 1084 en subcarpeta training
# Iterando sobre texto 10840 en subcarpeta training
# Iterando sobre texto 10841 en subcarpeta training
# Iterando sobre texto 10843 en subcarpeta training
# Iterando sobre texto 10844 en subcarpeta training
# Iterando sobre texto 10845 en subcarpeta training
# Iterando sobre texto 10847 en subcarpeta training
# Iterando sobre texto 10848 en subcarpeta training
# Iterando sobre texto 10849 en subcarpeta training
# Iterando sobre texto 1085 en subcarpeta training
# Iterando sobre texto 10851 en subcarpeta training
# Iterando sobre texto 10853 en subcarpeta training
# Iterando sobre texto 10855 en subcarpeta training
# Iterando sobre texto 10856 en subcarpeta training
# Iterando sobre texto 10857 en subcarpeta training
# Iterando sobre texto 10859 en subcarpeta training
# Iterando sobre texto 10860 en subcarpeta training
# Iterando sobre texto 10864 en subcarpeta training
# Iterando sobre texto 10867 en subcarpeta training
# Iterando sobre texto 10868 en subcarpeta training
# Iterando sobre texto 1087 en subcarpeta training
# Iterando sobre texto 10870 en subcarpeta training
# Iterando sobre texto 10871 en subcarpeta training
# Iterando sobre texto 10872 en subcarpeta training
# Iterando sobre texto 10873 en subcarpeta training
# Iterando sobre texto 10874 en subcarpeta training
# Iterando sobre texto 10876 en subcarpeta training
# Iterando sobre texto 10877 en subcarpeta training
# Iterando sobre texto 10879 en subcarpeta training
# Iterando sobre texto 1088 en subcarpeta training
# Iterando sobre texto 10882 en subcarpeta training
# Iterando sobre texto 10883 en subcarpeta training
# Iterando sobre texto 10884 en subcarpeta training
# Iterando sobre texto 10885 en subcarpeta training
# Iterando sobre texto 10886 en subcarpeta training
# Iterando sobre texto 10887 en subcarpeta training
# Iterando sobre texto 10891 en subcarpeta training
# Iterando sobre texto 10892 en subcarpeta training
# Iterando sobre texto 10893 en subcarpeta training
# Iterando sobre texto 10894 en subcarpeta training
# Iterando sobre texto 10895 en subcarpeta training
# Iterando sobre texto 10897 en subcarpeta training
# Iterando sobre texto 10899 en subcarpeta training
# Iterando sobre texto 109 en subcarpeta training
# Iterando sobre texto 1090 en subcarpeta training
# Iterando sobre texto 10901 en subcarpeta training
# Iterando sobre texto 10902 en subcarpeta training
# Iterando sobre texto 10903 en subcarpeta training
# Iterando sobre texto 10904 en subcarpeta training
# Iterando sobre texto 10905 en subcarpeta training
# Iterando sobre texto 10907 en subcarpeta training
# Iterando sobre texto 10908 en subcarpeta training
# Iterando sobre texto 10909 en subcarpeta training
# Iterando sobre texto 1091 en subcarpeta training
# Iterando sobre texto 10913 en subcarpeta training
# Iterando sobre texto 10917 en subcarpeta training
# Iterando sobre texto 10918 en subcarpeta training
# Iterando sobre texto 10919 en subcarpeta training
# Iterando sobre texto 10921 en subcarpeta training
# Iterando sobre texto 10922 en subcarpeta training
# Iterando sobre texto 10923 en subcarpeta training
# Iterando sobre texto 10924 en subcarpeta training
# Iterando sobre texto 10925 en subcarpeta training
# Iterando sobre texto 10926 en subcarpeta training
# Iterando sobre texto 10928 en subcarpeta training
# Iterando sobre texto 10931 en subcarpeta training
# Iterando sobre texto 1094 en subcarpeta training
# Iterando sobre texto 10941 en subcarpeta training
# Iterando sobre texto 10943 en subcarpeta training
# Iterando sobre texto 10944 en subcarpeta training
# Iterando sobre texto 10946 en subcarpeta training
# Iterando sobre texto 10947 en subcarpeta training
# Iterando sobre texto 10950 en subcarpeta training
# Iterando sobre texto 10956 en subcarpeta training
# Iterando sobre texto 10959 en subcarpeta training
# Iterando sobre texto 1096 en subcarpeta training
# Iterando sobre texto 10960 en subcarpeta training
# Iterando sobre texto 10961 en subcarpeta training
# Iterando sobre texto 10962 en subcarpeta training
# Iterando sobre texto 10963 en subcarpeta training
# Iterando sobre texto 10964 en subcarpeta training
# Iterando sobre texto 10966 en subcarpeta training
# Iterando sobre texto 10969 en subcarpeta training
# Iterando sobre texto 10971 en subcarpeta training
# Iterando sobre texto 10972 en subcarpeta training
# Iterando sobre texto 10973 en subcarpeta training
# Iterando sobre texto 10974 en subcarpeta training
# Iterando sobre texto 10978 en subcarpeta training
# Iterando sobre texto 10980 en subcarpeta training
# Iterando sobre texto 10983 en subcarpeta training
# Iterando sobre texto 10985 en subcarpeta training
# Iterando sobre texto 10988 en subcarpeta training
# Iterando sobre texto 10989 en subcarpeta training
# Iterando sobre texto 1099 en subcarpeta training
# Iterando sobre texto 10992 en subcarpeta training
# Iterando sobre texto 10994 en subcarpeta training
# Iterando sobre texto 10998 en subcarpeta training
# Iterando sobre texto 10999 en subcarpeta training
# Iterando sobre texto 11 en subcarpeta training
# Iterando sobre texto 110 en subcarpeta training
# Iterando sobre texto 1100 en subcarpeta training
# Iterando sobre texto 11000 en subcarpeta training
# Iterando sobre texto 11006 en subcarpeta training
# Iterando sobre texto 11007 en subcarpeta training
# Iterando sobre texto 1101 en subcarpeta training
# Iterando sobre texto 11012 en subcarpeta training
# Iterando sobre texto 11015 en subcarpeta training
# Iterando sobre texto 11018 en subcarpeta training
# Iterando sobre texto 11019 en subcarpeta training
# Iterando sobre texto 1102 en subcarpeta training
# Iterando sobre texto 11025 en subcarpeta training
# Iterando sobre texto 11027 en subcarpeta training
# Iterando sobre texto 11028 en subcarpeta training
# Iterando sobre texto 11029 en subcarpeta training
# Iterando sobre texto 1103 en subcarpeta training
# Iterando sobre texto 11030 en subcarpeta training
# Iterando sobre texto 11031 en subcarpeta training
# Iterando sobre texto 11034 en subcarpeta training
# Iterando sobre texto 11035 en subcarpeta training
# Iterando sobre texto 11036 en subcarpeta training
# Iterando sobre texto 11039 en subcarpeta training
# Iterando sobre texto 1104 en subcarpeta training
# Iterando sobre texto 11040 en subcarpeta training
# Iterando sobre texto 11041 en subcarpeta training
# Iterando sobre texto 11043 en subcarpeta training
# Iterando sobre texto 11046 en subcarpeta training
# Iterando sobre texto 11047 en subcarpeta training
# Iterando sobre texto 11048 en subcarpeta training
# Iterando sobre texto 11049 en subcarpeta training
# Iterando sobre texto 1105 en subcarpeta training
# Iterando sobre texto 11051 en subcarpeta training
# Iterando sobre texto 11052 en subcarpeta training
# Iterando sobre texto 11056 en subcarpeta training
# Iterando sobre texto 11057 en subcarpeta training
# Iterando sobre texto 11058 en subcarpeta training
# Iterando sobre texto 11059 en subcarpeta training
# Iterando sobre texto 11060 en subcarpeta training
# Iterando sobre texto 11063 en subcarpeta training
# Iterando sobre texto 11064 en subcarpeta training
# Iterando sobre texto 11065 en subcarpeta training
# Iterando sobre texto 11066 en subcarpeta training
# Iterando sobre texto 11070 en subcarpeta training
# Iterando sobre texto 11071 en subcarpeta training
# Iterando sobre texto 11074 en subcarpeta training
# Iterando sobre texto 11076 en subcarpeta training
# Iterando sobre texto 11078 en subcarpeta training
# Iterando sobre texto 1108 en subcarpeta training
# Iterando sobre texto 11083 en subcarpeta training
# Iterando sobre texto 11085 en subcarpeta training
# Iterando sobre texto 11086 en subcarpeta training
# Iterando sobre texto 11087 en subcarpeta training
# Iterando sobre texto 11088 en subcarpeta training
# Iterando sobre texto 1109 en subcarpeta training
# Iterando sobre texto 11090 en subcarpeta training
# Iterando sobre texto 11091 en subcarpeta training
# Iterando sobre texto 11093 en subcarpeta training
# Iterando sobre texto 11095 en subcarpeta training
# Iterando sobre texto 11098 en subcarpeta training
# Iterando sobre texto 111 en subcarpeta training
# Iterando sobre texto 1110 en subcarpeta training
# Iterando sobre texto 11100 en subcarpeta training
# Iterando sobre texto 11101 en subcarpeta training
# Iterando sobre texto 11102 en subcarpeta training
# Iterando sobre texto 11103 en subcarpeta training
# Iterando sobre texto 11104 en subcarpeta training
# Iterando sobre texto 11105 en subcarpeta training
# Iterando sobre texto 11106 en subcarpeta training
# Iterando sobre texto 11107 en subcarpeta training
# Iterando sobre texto 11109 en subcarpeta training
# Iterando sobre texto 1111 en subcarpeta training
# Iterando sobre texto 11111 en subcarpeta training
# Iterando sobre texto 11112 en subcarpeta training
# Iterando sobre texto 11113 en subcarpeta training
# Iterando sobre texto 11115 en subcarpeta training
# Iterando sobre texto 11118 en subcarpeta training
# Iterando sobre texto 11119 en subcarpeta training
# Iterando sobre texto 1112 en subcarpeta training
# Iterando sobre texto 11120 en subcarpeta training
# Iterando sobre texto 11121 en subcarpeta training
# Iterando sobre texto 11123 en subcarpeta training
# Iterando sobre texto 11124 en subcarpeta training
# Iterando sobre texto 11126 en subcarpeta training
# Iterando sobre texto 11127 en subcarpeta training
# Iterando sobre texto 11128 en subcarpeta training
# Iterando sobre texto 11132 en subcarpeta training
# Iterando sobre texto 11133 en subcarpeta training
# Iterando sobre texto 11134 en subcarpeta training
# Iterando sobre texto 11135 en subcarpeta training
# Iterando sobre texto 11136 en subcarpeta training
# Iterando sobre texto 11137 en subcarpeta training
# Iterando sobre texto 11139 en subcarpeta training
# Iterando sobre texto 11143 en subcarpeta training
# Iterando sobre texto 11144 en subcarpeta training
# Iterando sobre texto 11145 en subcarpeta training
# Iterando sobre texto 11149 en subcarpeta training
# Iterando sobre texto 11153 en subcarpeta training
# Iterando sobre texto 11154 en subcarpeta training
# Iterando sobre texto 11156 en subcarpeta training
# Iterando sobre texto 11158 en subcarpeta training
# Iterando sobre texto 11159 en subcarpeta training
# Iterando sobre texto 11160 en subcarpeta training
# Iterando sobre texto 11161 en subcarpeta training
# Iterando sobre texto 11162 en subcarpeta training
# Iterando sobre texto 11163 en subcarpeta training
# Iterando sobre texto 11164 en subcarpeta training
# Iterando sobre texto 11166 en subcarpeta training
# Iterando sobre texto 11168 en subcarpeta training
# Iterando sobre texto 1117 en subcarpeta training
# Iterando sobre texto 11170 en subcarpeta training
# Iterando sobre texto 11171 en subcarpeta training
# Iterando sobre texto 11173 en subcarpeta training
# Iterando sobre texto 11174 en subcarpeta training
# Iterando sobre texto 11175 en subcarpeta training
# Iterando sobre texto 11177 en subcarpeta training
# Iterando sobre texto 11179 en subcarpeta training
# Iterando sobre texto 1118 en subcarpeta training
# Iterando sobre texto 11181 en subcarpeta training
# Iterando sobre texto 11183 en subcarpeta training
# Iterando sobre texto 11185 en subcarpeta training
# Iterando sobre texto 11190 en subcarpeta training
# Iterando sobre texto 11191 en subcarpeta training
# Iterando sobre texto 11192 en subcarpeta training
# Iterando sobre texto 11193 en subcarpeta training
# Iterando sobre texto 11196 en subcarpeta training
# Iterando sobre texto 11197 en subcarpeta training
# Iterando sobre texto 11198 en subcarpeta training
# Iterando sobre texto 1120 en subcarpeta training
# Iterando sobre texto 11200 en subcarpeta training
# Iterando sobre texto 11201 en subcarpeta training
# Iterando sobre texto 11202 en subcarpeta training
# Iterando sobre texto 11203 en subcarpeta training
# Iterando sobre texto 11205 en subcarpeta training
# Iterando sobre texto 11208 en subcarpeta training
# Iterando sobre texto 11209 en subcarpeta training
# Iterando sobre texto 11210 en subcarpeta training
# Iterando sobre texto 11211 en subcarpeta training
# Iterando sobre texto 11212 en subcarpeta training
# Iterando sobre texto 11213 en subcarpeta training
# Iterando sobre texto 11216 en subcarpeta training
# Iterando sobre texto 1122 en subcarpeta training
# Iterando sobre texto 11220 en subcarpeta training
# Iterando sobre texto 11221 en subcarpeta training
# Iterando sobre texto 11222 en subcarpeta training
# Iterando sobre texto 11224 en subcarpeta training
# Iterando sobre texto 11225 en subcarpeta training
# Iterando sobre texto 11227 en subcarpeta training
# Iterando sobre texto 11228 en subcarpeta training
# Iterando sobre texto 11229 en subcarpeta training
# Iterando sobre texto 1123 en subcarpeta training
# Iterando sobre texto 11230 en subcarpeta training
# Iterando sobre texto 11231 en subcarpeta training
# Iterando sobre texto 11232 en subcarpeta training
# Iterando sobre texto 11233 en subcarpeta training
# Iterando sobre texto 11234 en subcarpeta training
# Iterando sobre texto 11236 en subcarpeta training
# Iterando sobre texto 11237 en subcarpeta training
# Iterando sobre texto 11238 en subcarpeta training
# Iterando sobre texto 11239 en subcarpeta training
# Iterando sobre texto 1124 en subcarpeta training
# Iterando sobre texto 11241 en subcarpeta training
# Iterando sobre texto 11242 en subcarpeta training
# Iterando sobre texto 11243 en subcarpeta training
# Iterando sobre texto 11244 en subcarpeta training
# Iterando sobre texto 11249 en subcarpeta training
# Iterando sobre texto 1125 en subcarpeta training
# Iterando sobre texto 11251 en subcarpeta training
# Iterando sobre texto 11252 en subcarpeta training
# Iterando sobre texto 11253 en subcarpeta training
# Iterando sobre texto 11254 en subcarpeta training
# Iterando sobre texto 11255 en subcarpeta training
# Iterando sobre texto 11256 en subcarpeta training
# Iterando sobre texto 11257 en subcarpeta training
# Iterando sobre texto 11259 en subcarpeta training
# Iterando sobre texto 11260 en subcarpeta training
# Iterando sobre texto 11261 en subcarpeta training
# Iterando sobre texto 11263 en subcarpeta training
# Iterando sobre texto 11265 en subcarpeta training
# Iterando sobre texto 11268 en subcarpeta training
# Iterando sobre texto 11269 en subcarpeta training
# Iterando sobre texto 11270 en subcarpeta training
# Iterando sobre texto 11271 en subcarpeta training
# Iterando sobre texto 11272 en subcarpeta training
# Iterando sobre texto 11273 en subcarpeta training
# Iterando sobre texto 11274 en subcarpeta training
# Iterando sobre texto 11276 en subcarpeta training
# Iterando sobre texto 11277 en subcarpeta training
# Iterando sobre texto 11278 en subcarpeta training
# Iterando sobre texto 11279 en subcarpeta training
# Iterando sobre texto 1128 en subcarpeta training
# Iterando sobre texto 11281 en subcarpeta training
# Iterando sobre texto 11282 en subcarpeta training
# Iterando sobre texto 11283 en subcarpeta training
# Iterando sobre texto 11284 en subcarpeta training
# Iterando sobre texto 11285 en subcarpeta training
# Iterando sobre texto 11287 en subcarpeta training
# Iterando sobre texto 11289 en subcarpeta training
# Iterando sobre texto 11291 en subcarpeta training
# Iterando sobre texto 11292 en subcarpeta training
# Iterando sobre texto 11295 en subcarpeta training
# Iterando sobre texto 11297 en subcarpeta training
# Iterando sobre texto 11299 en subcarpeta training
# Iterando sobre texto 113 en subcarpeta training
# Iterando sobre texto 11300 en subcarpeta training
# Iterando sobre texto 11301 en subcarpeta training
# Iterando sobre texto 11302 en subcarpeta training
# Iterando sobre texto 11305 en subcarpeta training
# Iterando sobre texto 11306 en subcarpeta training
# Iterando sobre texto 11307 en subcarpeta training
# Iterando sobre texto 11308 en subcarpeta training
# Iterando sobre texto 1131 en subcarpeta training
# Iterando sobre texto 11314 en subcarpeta training
# Iterando sobre texto 11315 en subcarpeta training
# Iterando sobre texto 11316 en subcarpeta training
# Iterando sobre texto 11317 en subcarpeta training
# Iterando sobre texto 11320 en subcarpeta training
# Iterando sobre texto 11322 en subcarpeta training
# Iterando sobre texto 11324 en subcarpeta training
# Iterando sobre texto 11327 en subcarpeta training
# Iterando sobre texto 11330 en subcarpeta training
# Iterando sobre texto 11333 en subcarpeta training
# Iterando sobre texto 11335 en subcarpeta training
# Iterando sobre texto 11336 en subcarpeta training
# Iterando sobre texto 11338 en subcarpeta training
# Iterando sobre texto 1134 en subcarpeta training
# Iterando sobre texto 11340 en subcarpeta training
# Iterando sobre texto 11341 en subcarpeta training
# Iterando sobre texto 11343 en subcarpeta training
# Iterando sobre texto 11344 en subcarpeta training
# Iterando sobre texto 11348 en subcarpeta training
# Iterando sobre texto 11349 en subcarpeta training
# Iterando sobre texto 1135 en subcarpeta training
# Iterando sobre texto 11350 en subcarpeta training
# Iterando sobre texto 11352 en subcarpeta training
# Iterando sobre texto 11354 en subcarpeta training
# Iterando sobre texto 11356 en subcarpeta training
# Iterando sobre texto 11357 en subcarpeta training
# Iterando sobre texto 11358 en subcarpeta training
# Iterando sobre texto 11359 en subcarpeta training
# Iterando sobre texto 11362 en subcarpeta training
# Iterando sobre texto 11365 en subcarpeta training
# Iterando sobre texto 11369 en subcarpeta training
# Iterando sobre texto 1137 en subcarpeta training
# Iterando sobre texto 11370 en subcarpeta training
# Iterando sobre texto 11371 en subcarpeta training
# Iterando sobre texto 11372 en subcarpeta training
# Iterando sobre texto 11373 en subcarpeta training
# Iterando sobre texto 11374 en subcarpeta training
# Iterando sobre texto 11377 en subcarpeta training
# Iterando sobre texto 11378 en subcarpeta training
# Iterando sobre texto 11379 en subcarpeta training
# Iterando sobre texto 1138 en subcarpeta training
# Iterando sobre texto 11380 en subcarpeta training
# Iterando sobre texto 11381 en subcarpeta training
# Iterando sobre texto 11384 en subcarpeta training
# Iterando sobre texto 11385 en subcarpeta training
# Iterando sobre texto 11386 en subcarpeta training
# Iterando sobre texto 11387 en subcarpeta training
# Iterando sobre texto 11388 en subcarpeta training
# Iterando sobre texto 11390 en subcarpeta training
# Iterando sobre texto 11392 en subcarpeta training
# Iterando sobre texto 11393 en subcarpeta training
# Iterando sobre texto 11394 en subcarpeta training
# Iterando sobre texto 11395 en subcarpeta training
# Iterando sobre texto 11396 en subcarpeta training
# Iterando sobre texto 11397 en subcarpeta training
# Iterando sobre texto 11399 en subcarpeta training
# Iterando sobre texto 11400 en subcarpeta training
# Iterando sobre texto 11402 en subcarpeta training
# Iterando sobre texto 11403 en subcarpeta training
# Iterando sobre texto 11405 en subcarpeta training
# Iterando sobre texto 11406 en subcarpeta training
# Iterando sobre texto 11407 en subcarpeta training
# Iterando sobre texto 11413 en subcarpeta training
# Iterando sobre texto 11415 en subcarpeta training
# Iterando sobre texto 11416 en subcarpeta training
# Iterando sobre texto 11417 en subcarpeta training
# Iterando sobre texto 11418 en subcarpeta training
# Iterando sobre texto 11420 en subcarpeta training
# Iterando sobre texto 11421 en subcarpeta training
# Iterando sobre texto 11422 en subcarpeta training
# Iterando sobre texto 11424 en subcarpeta training
# Iterando sobre texto 11425 en subcarpeta training
# Iterando sobre texto 11427 en subcarpeta training
# Iterando sobre texto 11428 en subcarpeta training
# Iterando sobre texto 11429 en subcarpeta training
# Iterando sobre texto 1143 en subcarpeta training
# Iterando sobre texto 11430 en subcarpeta training
# Iterando sobre texto 11431 en subcarpeta training
# Iterando sobre texto 11433 en subcarpeta training
# Iterando sobre texto 11435 en subcarpeta training
# Iterando sobre texto 11436 en subcarpeta training
# Iterando sobre texto 11437 en subcarpeta training
# Iterando sobre texto 11440 en subcarpeta training
# Iterando sobre texto 11441 en subcarpeta training
# Iterando sobre texto 11443 en subcarpeta training
# Iterando sobre texto 11444 en subcarpeta training
# Iterando sobre texto 11445 en subcarpeta training
# Iterando sobre texto 11446 en subcarpeta training
# Iterando sobre texto 11447 en subcarpeta training
# Iterando sobre texto 11449 en subcarpeta training
# Iterando sobre texto 11450 en subcarpeta training
# Iterando sobre texto 11451 en subcarpeta training
# Iterando sobre texto 11452 en subcarpeta training
# Iterando sobre texto 11455 en subcarpeta training
# Iterando sobre texto 11459 en subcarpeta training
# Iterando sobre texto 11460 en subcarpeta training
# Iterando sobre texto 11461 en subcarpeta training
# Iterando sobre texto 11462 en subcarpeta training
# Iterando sobre texto 11464 en subcarpeta training
# Iterando sobre texto 11465 en subcarpeta training
# Iterando sobre texto 11466 en subcarpeta training
# Iterando sobre texto 11468 en subcarpeta training
# Iterando sobre texto 11469 en subcarpeta training
# Iterando sobre texto 1147 en subcarpeta training
# Iterando sobre texto 11470 en subcarpeta training
# Iterando sobre texto 11475 en subcarpeta training
# Iterando sobre texto 11476 en subcarpeta training
# Iterando sobre texto 11477 en subcarpeta training
# Iterando sobre texto 11478 en subcarpeta training
# Iterando sobre texto 11479 en subcarpeta training
# Iterando sobre texto 1148 en subcarpeta training
# Iterando sobre texto 11481 en subcarpeta training
# Iterando sobre texto 11484 en subcarpeta training
# Iterando sobre texto 11487 en subcarpeta training
# Iterando sobre texto 11488 en subcarpeta training
# ...
# Iterando sobre texto 20949 en subcarpeta test
# Iterando sobre texto 20954 en subcarpeta test
# Iterando sobre texto 20958 en subcarpeta test
# Iterando sobre texto 20959 en subcarpeta test
# Iterando sobre texto 20968 en subcarpeta test
# Iterando sobre texto 20969 en subcarpeta test
# Iterando sobre texto 20972 en subcarpeta test
# Iterando sobre texto 20973 en subcarpeta test
# Iterando sobre texto 20974 en subcarpeta test
# Iterando sobre texto 20975 en subcarpeta test
# Iterando sobre texto 20976 en subcarpeta test
# Iterando sobre texto 20979 en subcarpeta test
# Iterando sobre texto 20981 en subcarpeta test
# Iterando sobre texto 20982 en subcarpeta test
# Iterando sobre texto 20983 en subcarpeta test
# Iterando sobre texto 20984 en subcarpeta test
# Iterando sobre texto 20988 en subcarpeta test
# Iterando sobre texto 20989 en subcarpeta test
# Iterando sobre texto 20991 en subcarpeta test
# Iterando sobre texto 20995 en subcarpeta test
# Iterando sobre texto 21000 en subcarpeta test
# Iterando sobre texto 21002 en subcarpeta test
# Iterando sobre texto 21003 en subcarpeta test
# Iterando sobre texto 21006 en subcarpeta test
# Iterando sobre texto 21007 en subcarpeta test
# Iterando sobre texto 21012 en subcarpeta test
# Iterando sobre texto 21013 en subcarpeta test
# Iterando sobre texto 21014 en subcarpeta test
# Iterando sobre texto 21016 en subcarpeta test
# Iterando sobre texto 21017 en subcarpeta test
# Iterando sobre texto 21018 en subcarpeta test
# Iterando sobre texto 21019 en subcarpeta test
# Iterando sobre texto 21022 en subcarpeta test
# Iterando sobre texto 21023 en subcarpeta test
# Iterando sobre texto 21028 en subcarpeta test
# Iterando sobre texto 21030 en subcarpeta test
# Iterando sobre texto 21031 en subcarpeta test
# Iterando sobre texto 21032 en subcarpeta test
# Iterando sobre texto 21034 en subcarpeta test
# Iterando sobre texto 21036 en subcarpeta test
# Iterando sobre texto 21037 en subcarpeta test
# Iterando sobre texto 21038 en subcarpeta test
# Iterando sobre texto 21039 en subcarpeta test
# Iterando sobre texto 21040 en subcarpeta test
# Iterando sobre texto 21041 en subcarpeta test
# Iterando sobre texto 21042 en subcarpeta test
# Iterando sobre texto 21044 en subcarpeta test
# Iterando sobre texto 21045 en subcarpeta test
# Iterando sobre texto 21046 en subcarpeta test
# Iterando sobre texto 21047 en subcarpeta test
# Iterando sobre texto 21049 en subcarpeta test
# Iterando sobre texto 21050 en subcarpeta test
# Iterando sobre texto 21051 en subcarpeta test
# Iterando sobre texto 21053 en subcarpeta test
# Iterando sobre texto 21055 en subcarpeta test
# Iterando sobre texto 21058 en subcarpeta test
# Iterando sobre texto 21059 en subcarpeta test
# Iterando sobre texto 21060 en subcarpeta test
# Iterando sobre texto 21061 en subcarpeta test
# Iterando sobre texto 21063 en subcarpeta test
# Iterando sobre texto 21065 en subcarpeta test
# Iterando sobre texto 21067 en subcarpeta test
# Iterando sobre texto 21071 en subcarpeta test
# Iterando sobre texto 21073 en subcarpeta test
# Iterando sobre texto 21076 en subcarpeta test
# Iterando sobre texto 21077 en subcarpeta test
# Iterando sobre texto 21078 en subcarpeta test
# Iterando sobre texto 21080 en subcarpeta test
# Iterando sobre texto 21081 en subcarpeta test
# Iterando sobre texto 21082 en subcarpeta test
# Iterando sobre texto 21091 en subcarpeta test
# Iterando sobre texto 21093 en subcarpeta test
# Iterando sobre texto 21095 en subcarpeta test
# Iterando sobre texto 21096 en subcarpeta test
# Iterando sobre texto 21097 en subcarpeta test
# Iterando sobre texto 21100 en subcarpeta test
# Iterando sobre texto 21103 en subcarpeta test
# Iterando sobre texto 21105 en subcarpeta test
# Iterando sobre texto 21106 en subcarpeta test
# Iterando sobre texto 21109 en subcarpeta test
# Iterando sobre texto 21112 en subcarpeta test
# Iterando sobre texto 21113 en subcarpeta test
# Iterando sobre texto 21114 en subcarpeta test
# Iterando sobre texto 21117 en subcarpeta test
# Iterando sobre texto 21122 en subcarpeta test
# Iterando sobre texto 21123 en subcarpeta test
# Iterando sobre texto 21124 en subcarpeta test
# Iterando sobre texto 21128 en subcarpeta test
# Iterando sobre texto 21129 en subcarpeta test
# Iterando sobre texto 21130 en subcarpeta test
# Iterando sobre texto 21131 en subcarpeta test
# Iterando sobre texto 21132 en subcarpeta test
# Iterando sobre texto 21133 en subcarpeta test
# Iterando sobre texto 21134 en subcarpeta test
# Iterando sobre texto 21135 en subcarpeta test
# Iterando sobre texto 21136 en subcarpeta test
# Iterando sobre texto 21138 en subcarpeta test
# Iterando sobre texto 21140 en subcarpeta test
# Iterando sobre texto 21142 en subcarpeta test
# Iterando sobre texto 21143 en subcarpeta test
# Iterando sobre texto 21146 en subcarpeta test
# Iterando sobre texto 21148 en subcarpeta test
# Iterando sobre texto 21149 en subcarpeta test
# Iterando sobre texto 21151 en subcarpeta test
# Iterando sobre texto 21152 en subcarpeta test
# Iterando sobre texto 21157 en subcarpeta test
# Iterando sobre texto 21163 en subcarpeta test
# Iterando sobre texto 21164 en subcarpeta test
# Iterando sobre texto 21165 en subcarpeta test
# Iterando sobre texto 21166 en subcarpeta test
# Iterando sobre texto 21168 en subcarpeta test
# Iterando sobre texto 21172 en subcarpeta test
# Iterando sobre texto 21173 en subcarpeta test
# Iterando sobre texto 21175 en subcarpeta test
# Iterando sobre texto 21176 en subcarpeta test
# Iterando sobre texto 21177 en subcarpeta test
# Iterando sobre texto 21178 en subcarpeta test
# Iterando sobre texto 21179 en subcarpeta test
# Iterando sobre texto 21181 en subcarpeta test
# Iterando sobre texto 21182 en subcarpeta test
# Iterando sobre texto 21187 en subcarpeta test
# Iterando sobre texto 21189 en subcarpeta test
# Iterando sobre texto 21190 en subcarpeta test
# Iterando sobre texto 21191 en subcarpeta test
# Iterando sobre texto 21192 en subcarpeta test
# Iterando sobre texto 21193 en subcarpeta test
# Iterando sobre texto 21194 en subcarpeta test
# Iterando sobre texto 21195 en subcarpeta test
# Iterando sobre texto 21196 en subcarpeta test
# Iterando sobre texto 21197 en subcarpeta test
# Iterando sobre texto 21199 en subcarpeta test
# Iterando sobre texto 21201 en subcarpeta test
# Iterando sobre texto 21202 en subcarpeta test
# Iterando sobre texto 21203 en subcarpeta test
# Iterando sobre texto 21205 en subcarpeta test
# Iterando sobre texto 21206 en subcarpeta test
# Iterando sobre texto 21207 en subcarpeta test
# Iterando sobre texto 21208 en subcarpeta test
# Iterando sobre texto 21209 en subcarpeta test
# Iterando sobre texto 21210 en subcarpeta test
# Iterando sobre texto 21211 en subcarpeta test
# Iterando sobre texto 21212 en subcarpeta test
# Iterando sobre texto 21214 en subcarpeta test
# Iterando sobre texto 21215 en subcarpeta test
# Iterando sobre texto 21216 en subcarpeta test
# Iterando sobre texto 21218 en subcarpeta test
# Iterando sobre texto 21219 en subcarpeta test
# Iterando sobre texto 21221 en subcarpeta test
# Iterando sobre texto 21222 en subcarpeta test
# Iterando sobre texto 21224 en subcarpeta test
# Iterando sobre texto 21227 en subcarpeta test
# Iterando sobre texto 21228 en subcarpeta test
# Iterando sobre texto 21230 en subcarpeta test
# Iterando sobre texto 21232 en subcarpeta test
# Iterando sobre texto 21233 en subcarpeta test
# Iterando sobre texto 21234 en subcarpeta test
# Iterando sobre texto 21236 en subcarpeta test
# Iterando sobre texto 21237 en subcarpeta test
# Iterando sobre texto 21238 en subcarpeta test
# Iterando sobre texto 21240 en subcarpeta test
# Iterando sobre texto 21242 en subcarpeta test
# Iterando sobre texto 21243 en subcarpeta test
# Iterando sobre texto 21244 en subcarpeta test
# Iterando sobre texto 21245 en subcarpeta test
# Iterando sobre texto 21248 en subcarpeta test
# Iterando sobre texto 21251 en subcarpeta test
# Iterando sobre texto 21252 en subcarpeta test
# Iterando sobre texto 21253 en subcarpeta test
# Iterando sobre texto 21255 en subcarpeta test
# Iterando sobre texto 21256 en subcarpeta test
# Iterando sobre texto 21257 en subcarpeta test
# Iterando sobre texto 21259 en subcarpeta test
# Iterando sobre texto 21260 en subcarpeta test
# Iterando sobre texto 21261 en subcarpeta test
# Iterando sobre texto 21262 en subcarpeta test
# Iterando sobre texto 21264 en subcarpeta test
# Iterando sobre texto 21265 en subcarpeta test
# Iterando sobre texto 21266 en subcarpeta test
# Iterando sobre texto 21267 en subcarpeta test
# Iterando sobre texto 21271 en subcarpeta test
# Iterando sobre texto 21272 en subcarpeta test
# Iterando sobre texto 21274 en subcarpeta test
# Iterando sobre texto 21275 en subcarpeta test
# Iterando sobre texto 21277 en subcarpeta test
# Iterando sobre texto 21278 en subcarpeta test
# Iterando sobre texto 21281 en subcarpeta test
# Iterando sobre texto 21282 en subcarpeta test
# Iterando sobre texto 21283 en subcarpeta test
# Iterando sobre texto 21285 en subcarpeta test
# Iterando sobre texto 21286 en subcarpeta test
# Iterando sobre texto 21287 en subcarpeta test
# Iterando sobre texto 21291 en subcarpeta test
# Iterando sobre texto 21292 en subcarpeta test
# Iterando sobre texto 21293 en subcarpeta test
# Iterando sobre texto 21295 en subcarpeta test
# Iterando sobre texto 21297 en subcarpeta test
# Iterando sobre texto 21298 en subcarpeta test
# Iterando sobre texto 21300 en subcarpeta test
# Iterando sobre texto 21301 en subcarpeta test
# Iterando sobre texto 21302 en subcarpeta test
# Iterando sobre texto 21303 en subcarpeta test
# Iterando sobre texto 21307 en subcarpeta test
# Iterando sobre texto 21308 en subcarpeta test
# Iterando sobre texto 21314 en subcarpeta test
# Iterando sobre texto 21315 en subcarpeta test
# Iterando sobre texto 21318 en subcarpeta test
# Iterando sobre texto 21319 en subcarpeta test
# Iterando sobre texto 21321 en subcarpeta test
# Iterando sobre texto 21322 en subcarpeta test
# Iterando sobre texto 21323 en subcarpeta test
# Iterando sobre texto 21324 en subcarpeta test
# Iterando sobre texto 21325 en subcarpeta test
# Iterando sobre texto 21330 en subcarpeta test
# Iterando sobre texto 21331 en subcarpeta test
# Iterando sobre texto 21333 en subcarpeta test
# Iterando sobre texto 21336 en subcarpeta test
# Iterando sobre texto 21337 en subcarpeta test
# Iterando sobre texto 21339 en subcarpeta test
# Iterando sobre texto 21342 en subcarpeta test
# Iterando sobre texto 21343 en subcarpeta test
# Iterando sobre texto 21346 en subcarpeta test
# Iterando sobre texto 21350 en subcarpeta test
# Iterando sobre texto 21352 en subcarpeta test
# Iterando sobre texto 21354 en subcarpeta test
# Iterando sobre texto 21356 en subcarpeta test
# Iterando sobre texto 21357 en subcarpeta test
# Iterando sobre texto 21358 en subcarpeta test
# Iterando sobre texto 21359 en subcarpeta test
# Iterando sobre texto 21360 en subcarpeta test
# Iterando sobre texto 21362 en subcarpeta test
# Iterando sobre texto 21363 en subcarpeta test
# Iterando sobre texto 21367 en subcarpeta test
# Iterando sobre texto 21368 en subcarpeta test
# Iterando sobre texto 21369 en subcarpeta test
# Iterando sobre texto 21371 en subcarpeta test
# Iterando sobre texto 21372 en subcarpeta test
# Iterando sobre texto 21373 en subcarpeta test
# Iterando sobre texto 21375 en subcarpeta test
# Iterando sobre texto 21376 en subcarpeta test
# Iterando sobre texto 21378 en subcarpeta test
# Iterando sobre texto 21380 en subcarpeta test
# Iterando sobre texto 21382 en subcarpeta test
# Iterando sobre texto 21385 en subcarpeta test
# Iterando sobre texto 21386 en subcarpeta test
# Iterando sobre texto 21387 en subcarpeta test
# Iterando sobre texto 21388 en subcarpeta test
# Iterando sobre texto 21391 en subcarpeta test
# Iterando sobre texto 21392 en subcarpeta test
# Iterando sobre texto 21393 en subcarpeta test
# Iterando sobre texto 21394 en subcarpeta test
# Iterando sobre texto 21401 en subcarpeta test
# Iterando sobre texto 21403 en subcarpeta test
# Iterando sobre texto 21404 en subcarpeta test
# Iterando sobre texto 21405 en subcarpeta test
# Iterando sobre texto 21406 en subcarpeta test
# Iterando sobre texto 21408 en subcarpeta test
# Iterando sobre texto 21410 en subcarpeta test
# Iterando sobre texto 21411 en subcarpeta test
# Iterando sobre texto 21412 en subcarpeta test
# Iterando sobre texto 21413 en subcarpeta test
# Iterando sobre texto 21414 en subcarpeta test
# Iterando sobre texto 21415 en subcarpeta test
# Iterando sobre texto 21416 en subcarpeta test
# Iterando sobre texto 21417 en subcarpeta test
# Iterando sobre texto 21419 en subcarpeta test
# Iterando sobre texto 21421 en subcarpeta test
# Iterando sobre texto 21423 en subcarpeta test
# Iterando sobre texto 21427 en subcarpeta test
# Iterando sobre texto 21429 en subcarpeta test
# Iterando sobre texto 21430 en subcarpeta test
# Iterando sobre texto 21431 en subcarpeta test
# Iterando sobre texto 21435 en subcarpeta test
# Iterando sobre texto 21436 en subcarpeta test
# Iterando sobre texto 21437 en subcarpeta test
# Iterando sobre texto 21440 en subcarpeta test
# Iterando sobre texto 21441 en subcarpeta test
# Iterando sobre texto 21443 en subcarpeta test
# Iterando sobre texto 21447 en subcarpeta test
# Iterando sobre texto 21448 en subcarpeta test
# Iterando sobre texto 21451 en subcarpeta test
# Iterando sobre texto 21453 en subcarpeta test
# Iterando sobre texto 21454 en subcarpeta test
# Iterando sobre texto 21455 en subcarpeta test
# Iterando sobre texto 21459 en subcarpeta test
# Iterando sobre texto 21460 en subcarpeta test
# Iterando sobre texto 21462 en subcarpeta test
# Iterando sobre texto 21465 en subcarpeta test
# Iterando sobre texto 21466 en subcarpeta test
# Iterando sobre texto 21468 en subcarpeta test
# Iterando sobre texto 21469 en subcarpeta test
# Iterando sobre texto 21473 en subcarpeta test
# Iterando sobre texto 21474 en subcarpeta test
# Iterando sobre texto 21475 en subcarpeta test
# Iterando sobre texto 21477 en subcarpeta test
# Iterando sobre texto 21478 en subcarpeta test
# Iterando sobre texto 21479 en subcarpeta test
# Iterando sobre texto 21480 en subcarpeta test
# Iterando sobre texto 21482 en subcarpeta test
# Iterando sobre texto 21484 en subcarpeta test
# Iterando sobre texto 21485 en subcarpeta test
# Iterando sobre texto 21486 en subcarpeta test
# Iterando sobre texto 21488 en subcarpeta test
# Iterando sobre texto 21489 en subcarpeta test
# Iterando sobre texto 21490 en subcarpeta test
# Iterando sobre texto 21492 en subcarpeta test
# Iterando sobre texto 21493 en subcarpeta test
# Iterando sobre texto 21496 en subcarpeta test
# Iterando sobre texto 21497 en subcarpeta test
# Iterando sobre texto 21501 en subcarpeta test
# Iterando sobre texto 21502 en subcarpeta test
# Iterando sobre texto 21503 en subcarpeta test
# Iterando sobre texto 21506 en subcarpeta test
# Iterando sobre texto 21508 en subcarpeta test
# Iterando sobre texto 21510 en subcarpeta test
# Iterando sobre texto 21511 en subcarpeta test
# Iterando sobre texto 21512 en subcarpeta test
# Iterando sobre texto 21517 en subcarpeta test
# Iterando sobre texto 21519 en subcarpeta test
# Iterando sobre texto 21521 en subcarpeta test
# Iterando sobre texto 21523 en subcarpeta test
# Iterando sobre texto 21525 en subcarpeta test
# Iterando sobre texto 21526 en subcarpeta test
# Iterando sobre texto 21530 en subcarpeta test
# Iterando sobre texto 21532 en subcarpeta test
# Iterando sobre texto 21535 en subcarpeta test
# Iterando sobre texto 21536 en subcarpeta test
# Iterando sobre texto 21538 en subcarpeta test
# Iterando sobre texto 21539 en subcarpeta test
# Iterando sobre texto 21541 en subcarpeta test
# Iterando sobre texto 21542 en subcarpeta test
# Iterando sobre texto 21550 en subcarpeta test
# Iterando sobre texto 21551 en subcarpeta test
# Iterando sobre texto 21553 en subcarpeta test
# Iterando sobre texto 21555 en subcarpeta test
# Iterando sobre texto 21556 en subcarpeta test
# Iterando sobre texto 21557 en subcarpeta test
# Iterando sobre texto 21561 en subcarpeta test
# Iterando sobre texto 21562 en subcarpeta test
# Iterando sobre texto 21565 en subcarpeta test
# Iterando sobre texto 21567 en subcarpeta test
# Iterando sobre texto 21568 en subcarpeta test
# Iterando sobre texto 21570 en subcarpeta test
# Iterando sobre texto 21571 en subcarpeta test
# Iterando sobre texto 21573 en subcarpeta test
# Iterando sobre texto 21574 en subcarpeta test
# Iterando sobre texto 21575 en subcarpeta test
# Iterando sobre texto 21576 en subcarpeta test

# %%
df_textos_corpus = pd.DataFrame(noticias, columns=["id", "contenido", "subcarpeta"])

# %%
df_textos_corpus.to_csv(f"{directorio_base}\\data\\corpus_sin_procesar.csv", index=False)

# %% [markdown]
# ### 2. Preprocesar los corpus obtenidos
#
# Hemos obtenido los textos que van a conformar nuestro corpus y los hemos concatenado todos en un archivo .csv el cual podemos manipularlo de una manera mucho más fácil y eficiente. Ahora lo que vamos a realizar es el preprocesamiento de este corpus, para ello vamos a realizar el siguiente proceso:
#
# 1. Extracción de contenido relevante de los documentos
# 2. Eliminar caracteres no deseados y normalizar el texto
# 3. Tokenización del texto
# 4. Eliminación de stop words y aplicación de lematización
#
# Para este apartado vamos a crear una sola función de nombre preprocesar_contenido, la cual va a realizar todo el proceso de tokenización y normalización de cada contenido de cada documento que conforma el corpus

# %%
df_corpus_sp = pd.read_csv(f"{directorio_base}\data\corpus_sin_procesar.csv")

# %%
# Obtencion de las stopwords desde el archivo 'stopwords'
 
with open(f"{directorio_base}\data\stopwords", mode='r', encoding='utf-8') as file:
    contenido_stopwords = file.read()

stopwords = []

for words in contenido_stopwords.split("\n"):
    stopword = words.replace("\n", "")
    stopwords.append(stopword)

print(stopwords)
# Out:
# ['a', "a's", 'able', 'about', 'above', 'according', 'accordingly', 'across', 'actually', 'after', 'afterwards', 'again', 'against', "ain't", 'all', 'allow', 'allows', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'an', 'and', 'another', 'any', 'anybody', 'anyhow', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'apart', 'appear', 'appreciate', 'appropriate', 'are', "aren't", 'around', 'as', 'aside', 'ask', 'asking', 'associated', 'at', 'available', 'away', 'awfully', 'b', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before', 'beforehand', 'behind', 'being', 'believe', 'below', 'beside', 'besides', 'best', 'better', 'between', 'beyond', 'both', 'brief', 'but', 'by', 'c', "c'mon", "c's", 'came', 'can', "can't", 'cannot', 'cant', 'cause', 'causes', 'certain', 'certainly', 'changes', 'clearly', 'co', 'com', 'come', 'comes', 'concerning', 'consequently', 'consider', 'considering', 'contain', 'containing', 'contains', 'corresponding', 'could', "couldn't", 'course', 'currently', 'd', 'definitely', 'described', 'despite', 'did', "didn't", 'different', 'do', 'does', "doesn't", 'doing', "don't", 'done', 'down', 'downwards', 'during', 'e', 'each', 'edu', 'eg', 'eight', 'either', 'else', 'elsewhere', 'enough', 'entirely', 'especially', 'et', 'etc', 'even', 'ever', 'every', 'everybody', 'everyone', 'everything', 'everywhere', 'ex', 'exactly', 'example', 'except', 'f', 'far', 'few', 'fifth', 'first', 'five', 'followed', 'following', 'follows', 'for', 'former', 'formerly', 'forth', 'four', 'from', 'further', 'furthermore', 'g', 'get', 'gets', 'getting', 'given', 'gives', 'go', 'goes', 'going', 'gone', 'got', 'gotten', 'greetings', 'h', 'had', "hadn't", 'happens', 'hardly', 'has', "hasn't", 'have', "haven't", 'having', 'he', "he's", 'hello', 'help', 'hence', 'her', 'here', "here's", 'hereafter', 'hereby', 'herein', 'hereupon', 'hers', 'herself', 'hi', 'him', 'himself', 'his', 'hither', 'hopefully', 'how', 'howbeit', 'however', 'i', "i'd", "i'll", "i'm", "i've", 'ie', 'if', 'ignored', 'immediate', 'in', 'inasmuch', 'inc', 'indeed', 'indicate', 'indicated', 'indicates', 'inner', 'insofar', 'instead', 'into', 'inward', 'is', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', 'j', 'just', 'k', 'keep', 'keeps', 'kept', 'know', 'knows', 'known', 'l', 'last', 'lately', 'later', 'latter', 'latterly', 'least', 'less', 'lest', 'let', "let's", 'like', 'liked', 'likely', 'little', 'look', 'looking', 'looks', 'ltd', 'm', 'mainly', 'many', 'may', 'maybe', 'me', 'mean', 'meanwhile', 'merely', 'might', 'more', 'moreover', 'most', 'mostly', 'much', 'must', 'my', 'myself', 'n', 'name', 'namely', 'nd', 'near', 'nearly', 'necessary', 'need', 'needs', 'neither', 'never', 'nevertheless', 'new', 'next', 'nine', 'no', 'nobody', 'non', 'none', 'noone', 'nor', 'normally', 'not', 'nothing', 'novel', 'now', 'nowhere', 'o', 'obviously', 'of', 'off', 'often', 'oh', 'ok', 'okay', 'old', 'on', 'once', 'one', 'ones', 'only', 'onto', 'or', 'other', 'others', 'otherwise', 'ought', 'our', 'ours', 'ourselves', 'out', 'outside', 'over', 'overall', 'own', 'p', 'particular', 'particularly', 'per', 'perhaps', 'placed', 'please', 'plus', 'possible', 'presumably', 'probably', 'provides', 'q', 'que', 'quite', 'qv', 'r', 'rather', 'rd', 're', 'really', 'reasonably', 'regarding', 'regardless', 'regards', 'relatively', 'respectively', 'right', 's', 'said', 'same', 'saw', 'say', 'saying', 'says', 'second', 'secondly', 'see', 'seeing', 'seem', 'seemed', 'seeming', 'seems', 'seen', 'self', 'selves', 'sensible', 'sent', 'serious', 'seriously', 'seven', 'several', 'shall', 'she', 'should', "shouldn't", 'since', 'six', 'so', 'some', 'somebody', 'somehow', 'someone', 'something', 'sometime', 'sometimes', 'somewhat', 'somewhere', 'soon', 'sorry', 'specified', 'specify', 'specifying', 'still', 'sub', 'such', 'sup', 'sure', 't', "t's", 'take', 'taken', 'tell', 'tends', 'th', 'than', 'thank', 'thanks', 'thanx', 'th ...

# %%
signos_puntuacion = [",", ".", ":", "...", "-", "_", "+", ";", '"', "(", ")", "[", "]", "%", "$", "#", "@", "&", "?", "!", "/", ">", "<"]

# %%
# Configuración de lematizador y stopwords
lemmatizer = WordNetLemmatizer()

# Función para convertir etiquetas POS de nltk a WordNet
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # Por defecto

# Función de preprocesamiento
def preprocesar_contenido(contenido):
    # Convertir texto a minúsculas
    contenido = contenido.lower()

    # Reemplazar caracteres y limpiar texto
    contenido = contenido.replace("'", " ").replace(" &lt;", " ").replace("&lt;", " ")
    contenido = contenido.replace("trading", "trade").replace("united states of america", "usa").replace("united states", "usa")
    contenido = re.sub(r'\d+', '', contenido)  # Eliminar números
    contenido = re.sub(r'\s+', ' ', contenido)  # Eliminar saltos de línea y espacios redundantes

    # Remover signos de puntuación
    for signo in signos_puntuacion:
        contenido = contenido.replace(signo, "")

    # Tokenización
    contenido_tokenizado = contenido.split()

    # Eliminar stopwords
    tokens_sin_stopwords = [word for word in contenido_tokenizado if word not in stopwords]

    # Etiquetado POS (Part Of Speech)
    tokens_pos = pos_tag(tokens_sin_stopwords)
    #print(tokens_pos)

    # Lematización utilizando etiquetado POS
    tokens_lematizados = [
        lemmatizer.lemmatize(token, get_wordnet_pos(pos)) for token, pos in tokens_pos
    ]

    # Reconstruir texto lematizado a un solo string
    contenido_lematizado_str = " ".join(tokens_lematizados)

    return contenido_lematizado_str

# %%
print(preprocesar_contenido("Trading trading better running jumped, saw on the United States Of America is really easy teams united to win championship"))
# Out:
# trade trade run jump usa easy team unite win championship

# %%
for index, row in df_corpus_sp.iterrows():
    print(f"Iterando sobre elemento {index+1} del .csv de los corpus")
    contenido = row["contenido"]
    contenido_preprocesado = preprocesar_contenido(contenido)
    df_corpus_sp.at[index, "contenido_preproc_str"] = contenido_preprocesado
# Out:
# Iterando sobre elemento 1 del .csv de los corpus
# Iterando sobre elemento 2 del .csv de los corpus
# Iterando sobre elemento 3 del .csv de los corpus
# Iterando sobre elemento 4 del .csv de los corpus
# Iterando sobre elemento 5 del .csv de los corpus
# Iterando sobre elemento 6 del .csv de los corpus
# Iterando sobre elemento 7 del .csv de los corpus
# Iterando sobre elemento 8 del .csv de los corpus
# Iterando sobre elemento 9 del .csv de los corpus
# Iterando sobre elemento 10 del .csv de los corpus
# Iterando sobre elemento 11 del .csv de los corpus
# Iterando sobre elemento 12 del .csv de los corpus
# Iterando sobre elemento 13 del .csv de los corpus
# Iterando sobre elemento 14 del .csv de los corpus
# Iterando sobre elemento 15 del .csv de los corpus
# Iterando sobre elemento 16 del .csv de los corpus
# Iterando sobre elemento 17 del .csv de los corpus
# Iterando sobre elemento 18 del .csv de los corpus
# Iterando sobre elemento 19 del .csv de los corpus
# Iterando sobre elemento 20 del .csv de los corpus
# Iterando sobre elemento 21 del .csv de los corpus
# Iterando sobre elemento 22 del .csv de los corpus
# Iterando sobre elemento 23 del .csv de los corpus
# Iterando sobre elemento 24 del .csv de los corpus
# Iterando sobre elemento 25 del .csv de los corpus
# Iterando sobre elemento 26 del .csv de los corpus
# Iterando sobre elemento 27 del .csv de los corpus
# Iterando sobre elemento 28 del .csv de los corpus
# Iterando sobre elemento 29 del .csv de los corpus
# Iterando sobre elemento 30 del .csv de los corpus
# Iterando sobre elemento 31 del .csv de los corpus
# Iterando sobre elemento 32 del .csv de los corpus
# Iterando sobre elemento 33 del .csv de los corpus
# Iterando sobre elemento 34 del .csv de los corpus
# Iterando sobre elemento 35 del .csv de los corpus
# Iterando sobre elemento 36 del .csv de los corpus
# Iterando sobre elemento 37 del .csv de los corpus
# Iterando sobre elemento 38 del .csv de los corpus
# Iterando sobre elemento 39 del .csv de los corpus
# Iterando sobre elemento 40 del .csv de los corpus
# Iterando sobre elemento 41 del .csv de los corpus
# Iterando sobre elemento 42 del .csv de los corpus
# Iterando sobre elemento 43 del .csv de los corpus
# Iterando sobre elemento 44 del .csv de los corpus
# Iterando sobre elemento 45 del .csv de los corpus
# Iterando sobre elemento 46 del .csv de los corpus
# Iterando sobre elemento 47 del .csv de los corpus
# Iterando sobre elemento 48 del .csv de los corpus
# Iterando sobre elemento 49 del .csv de los corpus
# Iterando sobre elemento 50 del .csv de los corpus
# Iterando sobre elemento 51 del .csv de los corpus
# Iterando sobre elemento 52 del .csv de los corpus
# Iterando sobre elemento 53 del .csv de los corpus
# Iterando sobre elemento 54 del .csv de los corpus
# Iterando sobre elemento 55 del .csv de los corpus
# Iterando sobre elemento 56 del .csv de los corpus
# Iterando sobre elemento 57 del .csv de los corpus
# Iterando sobre elemento 58 del .csv de los corpus
# Iterando sobre elemento 59 del .csv de los corpus
# Iterando sobre elemento 60 del .csv de los corpus
# Iterando sobre elemento 61 del .csv de los corpus
# Iterando sobre elemento 62 del .csv de los corpus
# Iterando sobre elemento 63 del .csv de los corpus
# Iterando sobre elemento 64 del .csv de los corpus
# Iterando sobre elemento 65 del .csv de los corpus
# Iterando sobre elemento 66 del .csv de los corpus
# Iterando sobre elemento 67 del .csv de los corpus
# Iterando sobre elemento 68 del .csv de los corpus
# Iterando sobre elemento 69 del .csv de los corpus
# Iterando sobre elemento 70 del .csv de los corpus
# Iterando sobre elemento 71 del .csv de los corpus
# Iterando sobre elemento 72 del .csv de los corpus
# Iterando sobre elemento 73 del .csv de los corpus
# Iterando sobre elemento 74 del .csv de los corpus
# Iterando sobre elemento 75 del .csv de los corpus
# Iterando sobre elemento 76 del .csv de los corpus
# Iterando sobre elemento 77 del .csv de los corpus
# Iterando sobre elemento 78 del .csv de los corpus
# Iterando sobre elemento 79 del .csv de los corpus
# Iterando sobre elemento 80 del .csv de los corpus
# Iterando sobre elemento 81 del .csv de los corpus
# Iterando sobre elemento 82 del .csv de los corpus
# Iterando sobre elemento 83 del .csv de los corpus
# Iterando sobre elemento 84 del .csv de los corpus
# Iterando sobre elemento 85 del .csv de los corpus
# Iterando sobre elemento 86 del .csv de los corpus
# Iterando sobre elemento 87 del .csv de los corpus
# Iterando sobre elemento 88 del .csv de los corpus
# Iterando sobre elemento 89 del .csv de los corpus
# Iterando sobre elemento 90 del .csv de los corpus
# Iterando sobre elemento 91 del .csv de los corpus
# Iterando sobre elemento 92 del .csv de los corpus
# Iterando sobre elemento 93 del .csv de los corpus
# Iterando sobre elemento 94 del .csv de los corpus
# Iterando sobre elemento 95 del .csv de los corpus
# Iterando sobre elemento 96 del .csv de los corpus
# Iterando sobre elemento 97 del .csv de los corpus
# Iterando sobre elemento 98 del .csv de los corpus
# Iterando sobre elemento 99 del .csv de los corpus
# Iterando sobre elemento 100 del .csv de los corpus
# Iterando sobre elemento 101 del .csv de los corpus
# Iterando sobre elemento 102 del .csv de los corpus
# Iterando sobre elemento 103 del .csv de los corpus
# Iterando sobre elemento 104 del .csv de los corpus
# Iterando sobre elemento 105 del .csv de los corpus
# Iterando sobre elemento 106 del .csv de los corpus
# Iterando sobre elemento 107 del .csv de los corpus
# Iterando sobre elemento 108 del .csv de los corpus
# Iterando sobre elemento 109 del .csv de los corpus
# Iterando sobre elemento 110 del .csv de los corpus
# Iterando sobre elemento 111 del .csv de los corpus
# Iterando sobre elemento 112 del .csv de los corpus
# Iterando sobre elemento 113 del .csv de los corpus
# Iterando sobre elemento 114 del .csv de los corpus
# Iterando sobre elemento 115 del .csv de los corpus
# Iterando sobre elemento 116 del .csv de los corpus
# Iterando sobre elemento 117 del .csv de los corpus
# Iterando sobre elemento 118 del .csv de los corpus
# Iterando sobre elemento 119 del .csv de los corpus
# Iterando sobre elemento 120 del .csv de los corpus
# Iterando sobre elemento 121 del .csv de los corpus
# Iterando sobre elemento 122 del .csv de los corpus
# Iterando sobre elemento 123 del .csv de los corpus
# Iterando sobre elemento 124 del .csv de los corpus
# Iterando sobre elemento 125 del .csv de los corpus
# Iterando sobre elemento 126 del .csv de los corpus
# Iterando sobre elemento 127 del .csv de los corpus
# Iterando sobre elemento 128 del .csv de los corpus
# Iterando sobre elemento 129 del .csv de los corpus
# Iterando sobre elemento 130 del .csv de los corpus
# Iterando sobre elemento 131 del .csv de los corpus
# Iterando sobre elemento 132 del .csv de los corpus
# Iterando sobre elemento 133 del .csv de los corpus
# Iterando sobre elemento 134 del .csv de los corpus
# Iterando sobre elemento 135 del .csv de los corpus
# Iterando sobre elemento 136 del .csv de los corpus
# Iterando sobre elemento 137 del .csv de los corpus
# Iterando sobre elemento 138 del .csv de los corpus
# Iterando sobre elemento 139 del .csv de los corpus
# Iterando sobre elemento 140 del .csv de los corpus
# Iterando sobre elemento 141 del .csv de los corpus
# Iterando sobre elemento 142 del .csv de los corpus
# Iterando sobre elemento 143 del .csv de los corpus
# Iterando sobre elemento 144 del .csv de los corpus
# Iterando sobre elemento 145 del .csv de los corpus
# Iterando sobre elemento 146 del .csv de los corpus
# Iterando sobre elemento 147 del .csv de los corpus
# Iterando sobre elemento 148 del .csv de los corpus
# Iterando sobre elemento 149 del .csv de los corpus
# Iterando sobre elemento 150 del .csv de los corpus
# Iterando sobre elemento 151 del .csv de los corpus
# Iterando sobre elemento 152 del .csv de los corpus
# Iterando sobre elemento 153 del .csv de los corpus
# Iterando sobre elemento 154 del .csv de los corpus
# Iterando sobre elemento 155 del .csv de los corpus
# Iterando sobre elemento 156 del .csv de los corpus
# Iterando sobre elemento 157 del .csv de los corpus
# Iterando sobre elemento 158 del .csv de los corpus
# Iterando sobre elemento 159 del .csv de los corpus
# Iterando sobre elemento 160 del .csv de los corpus
# Iterando sobre elemento 161 del .csv de los corpus
# Iterando sobre elemento 162 del .csv de los corpus
# Iterando sobre elemento 163 del .csv de los corpus
# Iterando sobre elemento 164 del .csv de los corpus
# Iterando sobre elemento 165 del .csv de los corpus
# Iterando sobre elemento 166 del .csv de los corpus
# Iterando sobre elemento 167 del .csv de los corpus
# Iterando sobre elemento 168 del .csv de los corpus
# Iterando sobre elemento 169 del .csv de los corpus
# Iterando sobre elemento 170 del .csv de los corpus
# Iterando sobre elemento 171 del .csv de los corpus
# Iterando sobre elemento 172 del .csv de los corpus
# Iterando sobre elemento 173 del .csv de los corpus
# Iterando sobre elemento 174 del .csv de los corpus
# Iterando sobre elemento 175 del .csv de los corpus
# Iterando sobre elemento 176 del .csv de los corpus
# Iterando sobre elemento 177 del .csv de los corpus
# Iterando sobre elemento 178 del .csv de los corpus
# Iterando sobre elemento 179 del .csv de los corpus
# Iterando sobre elemento 180 del .csv de los corpus
# Iterando sobre elemento 181 del .csv de los corpus
# Iterando sobre elemento 182 del .csv de los corpus
# Iterando sobre elemento 183 del .csv de los corpus
# Iterando sobre elemento 184 del .csv de los corpus
# Iterando sobre elemento 185 del .csv de los corpus
# Iterando sobre elemento 186 del .csv de los corpus
# Iterando sobre elemento 187 del .csv de los corpus
# Iterando sobre elemento 188 del .csv de los corpus
# Iterando sobre elemento 189 del .csv de los corpus
# Iterando sobre elemento 190 del .csv de los corpus
# Iterando sobre elemento 191 del .csv de los corpus
# Iterando sobre elemento 192 del .csv de los corpus
# Iterando sobre elemento 193 del .csv de los corpus
# Iterando sobre elemento 194 del .csv de los corpus
# Iterando sobre elemento 195 del .csv de los corpus
# Iterando sobre elemento 196 del .csv de los corpus
# Iterando sobre elemento 197 del .csv de los corpus
# Iterando sobre elemento 198 del .csv de los corpus
# Iterando sobre elemento 199 del .csv de los corpus
# Iterando sobre elemento 200 del .csv de los corpus
# Iterando sobre elemento 201 del .csv de los corpus
# Iterando sobre elemento 202 del .csv de los corpus
# Iterando sobre elemento 203 del .csv de los corpus
# Iterando sobre elemento 204 del .csv de los corpus
# Iterando sobre elemento 205 del .csv de los corpus
# Iterando sobre elemento 206 del .csv de los corpus
# Iterando sobre elemento 207 del .csv de los corpus
# Iterando sobre elemento 208 del .csv de los corpus
# Iterando sobre elemento 209 del .csv de los corpus
# Iterando sobre elemento 210 del .csv de los corpus
# Iterando sobre elemento 211 del .csv de los corpus
# Iterando sobre elemento 212 del .csv de los corpus
# Iterando sobre elemento 213 del .csv de los corpus
# Iterando sobre elemento 214 del .csv de los corpus
# Iterando sobre elemento 215 del .csv de los corpus
# Iterando sobre elemento 216 del .csv de los corpus
# Iterando sobre elemento 217 del .csv de los corpus
# Iterando sobre elemento 218 del .csv de los corpus
# Iterando sobre elemento 219 del .csv de los corpus
# Iterando sobre elemento 220 del .csv de los corpus
# Iterando sobre elemento 221 del .csv de los corpus
# Iterando sobre elemento 222 del .csv de los corpus
# Iterando sobre elemento 223 del .csv de los corpus
# Iterando sobre elemento 224 del .csv de los corpus
# Iterando sobre elemento 225 del .csv de los corpus
# Iterando sobre elemento 226 del .csv de los corpus
# Iterando sobre elemento 227 del .csv de los corpus
# Iterando sobre elemento 228 del .csv de los corpus
# Iterando sobre elemento 229 del .csv de los corpus
# Iterando sobre elemento 230 del .csv de los corpus
# Iterando sobre elemento 231 del .csv de los corpus
# Iterando sobre elemento 232 del .csv de los corpus
# Iterando sobre elemento 233 del .csv de los corpus
# Iterando sobre elemento 234 del .csv de los corpus
# Iterando sobre elemento 235 del .csv de los corpus
# Iterando sobre elemento 236 del .csv de los corpus
# Iterando sobre elemento 237 del .csv de los corpus
# Iterando sobre elemento 238 del .csv de los corpus
# Iterando sobre elemento 239 del .csv de los corpus
# Iterando sobre elemento 240 del .csv de los corpus
# Iterando sobre elemento 241 del .csv de los corpus
# Iterando sobre elemento 242 del .csv de los corpus
# Iterando sobre elemento 243 del .csv de los corpus
# Iterando sobre elemento 244 del .csv de los corpus
# Iterando sobre elemento 245 del .csv de los corpus
# Iterando sobre elemento 246 del .csv de los corpus
# Iterando sobre elemento 247 del .csv de los corpus
# Iterando sobre elemento 248 del .csv de los corpus
# Iterando sobre elemento 249 del .csv de los corpus
# Iterando sobre elemento 250 del .csv de los corpus
# Iterando sobre elemento 251 del .csv de los corpus
# Iterando sobre elemento 252 del .csv de los corpus
# Iterando sobre elemento 253 del .csv de los corpus
# Iterando sobre elemento 254 del .csv de los corpus
# Iterando sobre elemento 255 del .csv de los corpus
# Iterando sobre elemento 256 del .csv de los corpus
# Iterando sobre elemento 257 del .csv de los corpus
# Iterando sobre elemento 258 del .csv de los corpus
# Iterando sobre elemento 259 del .csv de los corpus
# Iterando sobre elemento 260 del .csv de los corpus
# Iterando sobre elemento 261 del .csv de los corpus
# Iterando sobre elemento 262 del .csv de los corpus
# Iterando sobre elemento 263 del .csv de los corpus
# Iterando sobre elemento 264 del .csv de los corpus
# Iterando sobre elemento 265 del .csv de los corpus
# Iterando sobre elemento 266 del .csv de los corpus
# Iterando sobre elemento 267 del .csv de los corpus
# Iterando sobre elemento 268 del .csv de los corpus
# Iterando sobre elemento 269 del .csv de los corpus
# Iterando sobre elemento 270 del .csv de los corpus
# Iterando sobre elemento 271 del .csv de los corpus
# Iterando sobre elemento 272 del .csv de los corpus
# Iterando sobre elemento 273 del .csv de los corpus
# Iterando sobre elemento 274 del .csv de los corpus
# Iterando sobre elemento 275 del .csv de los corpus
# Iterando sobre elemento 276 del .csv de los corpus
# Iterando sobre elemento 277 del .csv de los corpus
# Iterando sobre elemento 278 del .csv de los corpus
# Iterando sobre elemento 279 del .csv de los corpus
# Iterando sobre elemento 280 del .csv de los corpus
# Iterando sobre elemento 281 del .csv de los corpus
# Iterando sobre elemento 282 del .csv de los corpus
# Iterando sobre elemento 283 del .csv de los corpus
# Iterando sobre elemento 284 del .csv de los corpus
# Iterando sobre elemento 285 del .csv de los corpus
# Iterando sobre elemento 286 del .csv de los corpus
# Iterando sobre elemento 287 del .csv de los corpus
# Iterando sobre elemento 288 del .csv de los corpus
# Iterando sobre elemento 289 del .csv de los corpus
# Iterando sobre elemento 290 del .csv de los corpus
# Iterando sobre elemento 291 del .csv de los corpus
# Iterando sobre elemento 292 del .csv de los corpus
# Iterando sobre elemento 293 del .csv de los corpus
# Iterando sobre elemento 294 del .csv de los corpus
# Iterando sobre elemento 295 del .csv de los corpus
# Iterando sobre elemento 296 del .csv de los corpus
# Iterando sobre elemento 297 del .csv de los corpus
# Iterando sobre elemento 298 del .csv de los corpus
# Iterando sobre elemento 299 del .csv de los corpus
# Iterando sobre elemento 300 del .csv de los corpus
# Iterando sobre elemento 301 del .csv de los corpus
# Iterando sobre elemento 302 del .csv de los corpus
# Iterando sobre elemento 303 del .csv de los corpus
# Iterando sobre elemento 304 del .csv de los corpus
# Iterando sobre elemento 305 del .csv de los corpus
# Iterando sobre elemento 306 del .csv de los corpus
# Iterando sobre elemento 307 del .csv de los corpus
# Iterando sobre elemento 308 del .csv de los corpus
# Iterando sobre elemento 309 del .csv de los corpus
# Iterando sobre elemento 310 del .csv de los corpus
# Iterando sobre elemento 311 del .csv de los corpus
# Iterando sobre elemento 312 del .csv de los corpus
# Iterando sobre elemento 313 del .csv de los corpus
# Iterando sobre elemento 314 del .csv de los corpus
# Iterando sobre elemento 315 del .csv de los corpus
# Iterando sobre elemento 316 del .csv de los corpus
# Iterando sobre elemento 317 del .csv de los corpus
# Iterando sobre elemento 318 del .csv de los corpus
# Iterando sobre elemento 319 del .csv de los corpus
# Iterando sobre elemento 320 del .csv de los corpus
# Iterando sobre elemento 321 del .csv de los corpus
# Iterando sobre elemento 322 del .csv de los corpus
# Iterando sobre elemento 323 del .csv de los corpus
# Iterando sobre elemento 324 del .csv de los corpus
# Iterando sobre elemento 325 del .csv de los corpus
# Iterando sobre elemento 326 del .csv de los corpus
# Iterando sobre elemento 327 del .csv de los corpus
# Iterando sobre elemento 328 del .csv de los corpus
# Iterando sobre elemento 329 del .csv de los corpus
# Iterando sobre elemento 330 del .csv de los corpus
# Iterando sobre elemento 331 del .csv de los corpus
# Iterando sobre elemento 332 del .csv de los corpus
# Iterando sobre elemento 333 del .csv de los corpus
# Iterando sobre elemento 334 del .csv de los corpus
# Iterando sobre elemento 335 del .csv de los corpus
# Iterando sobre elemento 336 del .csv de los corpus
# Iterando sobre elemento 337 del .csv de los corpus
# Iterando sobre elemento 338 del .csv de los corpus
# Iterando sobre elemento 339 del .csv de los corpus
# Iterando sobre elemento 340 del .csv de los corpus
# Iterando sobre elemento 341 del .csv de los corpus
# Iterando sobre elemento 342 del .csv de los corpus
# Iterando sobre elemento 343 del .csv de los corpus
# Iterando sobre elemento 344 del .csv de los corpus
# Iterando sobre elemento 345 del .csv de los corpus
# Iterando sobre elemento 346 del .csv de los corpus
# Iterando sobre elemento 347 del .csv de los corpus
# Iterando sobre elemento 348 del .csv de los corpus
# Iterando sobre elemento 349 del .csv de los corpus
# Iterando sobre elemento 350 del .csv de los corpus
# Iterando sobre elemento 351 del .csv de los corpus
# Iterando sobre elemento 352 del .csv de los corpus
# Iterando sobre elemento 353 del .csv de los corpus
# Iterando sobre elemento 354 del .csv de los corpus
# Iterando sobre elemento 355 del .csv de los corpus
# Iterando sobre elemento 356 del .csv de los corpus
# Iterando sobre elemento 357 del .csv de los corpus
# Iterando sobre elemento 358 del .csv de los corpus
# Iterando sobre elemento 359 del .csv de los corpus
# Iterando sobre elemento 360 del .csv de los corpus
# Iterando sobre elemento 361 del .csv de los corpus
# Iterando sobre elemento 362 del .csv de los corpus
# Iterando sobre elemento 363 del .csv de los corpus
# Iterando sobre elemento 364 del .csv de los corpus
# Iterando sobre elemento 365 del .csv de los corpus
# Iterando sobre elemento 366 del .csv de los corpus
# Iterando sobre elemento 367 del .csv de los corpus
# Iterando sobre elemento 368 del .csv de los corpus
# Iterando sobre elemento 369 del .csv de los corpus
# Iterando sobre elemento 370 del .csv de los corpus
# Iterando sobre elemento 371 del .csv de los corpus
# Iterando sobre elemento 372 del .csv de los corpus
# Iterando sobre elemento 373 del .csv de los corpus
# Iterando sobre elemento 374 del .csv de los corpus
# Iterando sobre elemento 375 del .csv de los corpus
# Iterando sobre elemento 376 del .csv de los corpus
# Iterando sobre elemento 377 del .csv de los corpus
# Iterando sobre elemento 378 del .csv de los corpus
# Iterando sobre elemento 379 del .csv de los corpus
# Iterando sobre elemento 380 del .csv de los corpus
# Iterando sobre elemento 381 del .csv de los corpus
# Iterando sobre elemento 382 del .csv de los corpus
# Iterando sobre elemento 383 del .csv de los corpus
# Iterando sobre elemento 384 del .csv de los corpus
# Iterando sobre elemento 385 del .csv de los corpus
# Iterando sobre elemento 386 del .csv de los corpus
# Iterando sobre elemento 387 del .csv de los corpus
# Iterando sobre elemento 388 del .csv de los corpus
# Iterando sobre elemento 389 del .csv de los corpus
# Iterando sobre elemento 390 del .csv de los corpus
# Iterando sobre elemento 391 del .csv de los corpus
# Iterando sobre elemento 392 del .csv de los corpus
# Iterando sobre elemento 393 del .csv de los corpus
# Iterando sobre elemento 394 del .csv de los corpus
# Iterando sobre elemento 395 del .csv de los corpus
# Iterando sobre elemento 396 del .csv de los corpus
# Iterando sobre elemento 397 del .csv de los corpus
# Iterando sobre elemento 398 del .csv de los corpus
# Iterando sobre elemento 399 del .csv de los corpus
# Iterando sobre elemento 400 del .csv de los corpus
# Iterando sobre elemento 401 del .csv de los corpus
# Iterando sobre elemento 402 del .csv de los corpus
# Iterando sobre elemento 403 del .csv de los corpus
# Iterando sobre elemento 404 del .csv de los corpus
# Iterando sobre elemento 405 del .csv de los corpus
# Iterando sobre elemento 406 del .csv de los corpus
# Iterando sobre elemento 407 del .csv de los corpus
# Iterando sobre elemento 408 del .csv de los corpus
# Iterando sobre elemento 409 del .csv de los corpus
# Iterando sobre elemento 410 del .csv de los corpus
# Iterando sobre elemento 411 del .csv de los corpus
# Iterando sobre elemento 412 del .csv de los corpus
# Iterando sobre elemento 413 del .csv de los corpus
# Iterando sobre elemento 414 del .csv de los corpus
# Iterando sobre elemento 415 del .csv de los corpus
# Iterando sobre elemento 416 del .csv de los corpus
# Iterando sobre elemento 417 del .csv de los corpus
# Iterando sobre elemento 418 del .csv de los corpus
# Iterando sobre elemento 419 del .csv de los corpus
# Iterando sobre elemento 420 del .csv de los corpus
# Iterando sobre elemento 421 del .csv de los corpus
# Iterando sobre elemento 422 del .csv de los corpus
# Iterando sobre elemento 423 del .csv de los corpus
# Iterando sobre elemento 424 del .csv de los corpus
# Iterando sobre elemento 425 del .csv de los corpus
# Iterando sobre elemento 426 del .csv de los corpus
# Iterando sobre elemento 427 del .csv de los corpus
# Iterando sobre elemento 428 del .csv de los corpus
# Iterando sobre elemento 429 del .csv de los corpus
# Iterando sobre elemento 430 del .csv de los corpus
# Iterando sobre elemento 431 del .csv de los corpus
# Iterando sobre elemento 432 del .csv de los corpus
# Iterando sobre elemento 433 del .csv de los corpus
# Iterando sobre elemento 434 del .csv de los corpus
# Iterando sobre elemento 435 del .csv de los corpus
# Iterando sobre elemento 436 del .csv de los corpus
# Iterando sobre elemento 437 del .csv de los corpus
# Iterando sobre elemento 438 del .csv de los corpus
# Iterando sobre elemento 439 del .csv de los corpus
# Iterando sobre elemento 440 del .csv de los corpus
# Iterando sobre elemento 441 del .csv de los corpus
# Iterando sobre elemento 442 del .csv de los corpus
# Iterando sobre elemento 443 del .csv de los corpus
# Iterando sobre elemento 444 del .csv de los corpus
# Iterando sobre elemento 445 del .csv de los corpus
# Iterando sobre elemento 446 del .csv de los corpus
# Iterando sobre elemento 447 del .csv de los corpus
# Iterando sobre elemento 448 del .csv de los corpus
# Iterando sobre elemento 449 del .csv de los corpus
# Iterando sobre elemento 450 del .csv de los corpus
# Iterando sobre elemento 451 del .csv de los corpus
# Iterando sobre elemento 452 del .csv de los corpus
# Iterando sobre elemento 453 del .csv de los corpus
# Iterando sobre elemento 454 del .csv de los corpus
# Iterando sobre elemento 455 del .csv de los corpus
# Iterando sobre elemento 456 del .csv de los corpus
# Iterando sobre elemento 457 del .csv de los corpus
# Iterando sobre elemento 458 del .csv de los corpus
# Iterando sobre elemento 459 del .csv de los corpus
# Iterando sobre elemento 460 del .csv de los corpus
# Iterando sobre elemento 461 del .csv de los corpus
# Iterando sobre elemento 462 del .csv de los corpus
# Iterando sobre elemento 463 del .csv de los corpus
# Iterando sobre elemento 464 del .csv de los corpus
# Iterando sobre elemento 465 del .csv de los corpus
# Iterando sobre elemento 466 del .csv de los corpus
# Iterando sobre elemento 467 del .csv de los corpus
# Iterando sobre elemento 468 del .csv de los corpus
# Iterando sobre elemento 469 del .csv de los corpus
# Iterando sobre elemento 470 del .csv de los corpus
# Iterando sobre elemento 471 del .csv de los corpus
# Iterando sobre elemento 472 del .csv de los corpus
# Iterando sobre elemento 473 del .csv de los corpus
# Iterando sobre elemento 474 del .csv de los corpus
# Iterando sobre elemento 475 del .csv de los corpus
# Iterando sobre elemento 476 del .csv de los corpus
# Iterando sobre elemento 477 del .csv de los corpus
# Iterando sobre elemento 478 del .csv de los corpus
# Iterando sobre elemento 479 del .csv de los corpus
# Iterando sobre elemento 480 del .csv de los corpus
# Iterando sobre elemento 481 del .csv de los corpus
# Iterando sobre elemento 482 del .csv de los corpus
# Iterando sobre elemento 483 del .csv de los corpus
# Iterando sobre elemento 484 del .csv de los corpus
# Iterando sobre elemento 485 del .csv de los corpus
# Iterando sobre elemento 486 del .csv de los corpus
# Iterando sobre elemento 487 del .csv de los corpus
# Iterando sobre elemento 488 del .csv de los corpus
# Iterando sobre elemento 489 del .csv de los corpus
# Iterando sobre elemento 490 del .csv de los corpus
# Iterando sobre elemento 491 del .csv de los corpus
# Iterando sobre elemento 492 del .csv de los corpus
# Iterando sobre elemento 493 del .csv de los corpus
# Iterando sobre elemento 494 del .csv de los corpus
# Iterando sobre elemento 495 del .csv de los corpus
# Iterando sobre elemento 496 del .csv de los corpus
# Iterando sobre elemento 497 del .csv de los corpus
# Iterando sobre elemento 498 del .csv de los corpus
# Iterando sobre elemento 499 del .csv de los corpus
# Iterando sobre elemento 500 del .csv de los corpus
# Iterando sobre elemento 501 del .csv de los corpus
# Iterando sobre elemento 502 del .csv de los corpus
# Iterando sobre elemento 503 del .csv de los corpus
# Iterando sobre elemento 504 del .csv de los corpus
# Iterando sobre elemento 505 del .csv de los corpus
# Iterando sobre elemento 506 del .csv de los corpus
# Iterando sobre elemento 507 del .csv de los corpus
# Iterando sobre elemento 508 del .csv de los corpus
# Iterando sobre elemento 509 del .csv de los corpus
# Iterando sobre elemento 510 del .csv de los corpus
# Iterando sobre elemento 511 del .csv de los corpus
# Iterando sobre elemento 512 del .csv de los corpus
# Iterando sobre elemento 513 del .csv de los corpus
# Iterando sobre elemento 514 del .csv de los corpus
# Iterando sobre elemento 515 del .csv de los corpus
# Iterando sobre elemento 516 del .csv de los corpus
# Iterando sobre elemento 517 del .csv de los corpus
# Iterando sobre elemento 518 del .csv de los corpus
# Iterando sobre elemento 519 del .csv de los corpus
# Iterando sobre elemento 520 del .csv de los corpus
# Iterando sobre elemento 521 del .csv de los corpus
# Iterando sobre elemento 522 del .csv de los corpus
# Iterando sobre elemento 523 del .csv de los corpus
# Iterando sobre elemento 524 del .csv de los corpus
# Iterando sobre elemento 525 del .csv de los corpus
# Iterando sobre elemento 526 del .csv de los corpus
# Iterando sobre elemento 527 del .csv de los corpus
# Iterando sobre elemento 528 del .csv de los corpus
# Iterando sobre elemento 529 del .csv de los corpus
# Iterando sobre elemento 530 del .csv de los corpus
# Iterando sobre elemento 531 del .csv de los corpus
# Iterando sobre elemento 532 del .csv de los corpus
# Iterando sobre elemento 533 del .csv de los corpus
# Iterando sobre elemento 534 del .csv de los corpus
# Iterando sobre elemento 535 del .csv de los corpus
# Iterando sobre elemento 536 del .csv de los corpus
# Iterando sobre elemento 537 del .csv de los corpus
# Iterando sobre elemento 538 del .csv de los corpus
# Iterando sobre elemento 539 del .csv de los corpus
# Iterando sobre elemento 540 del .csv de los corpus
# Iterando sobre elemento 541 del .csv de los corpus
# Iterando sobre elemento 542 del .csv de los corpus
# Iterando sobre elemento 543 del .csv de los corpus
# Iterando sobre elemento 544 del .csv de los corpus
# Iterando sobre elemento 545 del .csv de los corpus
# Iterando sobre elemento 546 del .csv de los corpus
# Iterando sobre elemento 547 del .csv de los corpus
# Iterando sobre elemento 548 del .csv de los corpus
# Iterando sobre elemento 549 del .csv de los corpus
# Iterando sobre elemento 550 del .csv de los corpus
# Iterando sobre elemento 551 del .csv de los corpus
# Iterando sobre elemento 552 del .csv de los corpus
# Iterando sobre elemento 553 del .csv de los corpus
# Iterando sobre elemento 554 del .csv de los corpus
# Iterando sobre elemento 555 del .csv de los corpus
# Iterando sobre elemento 556 del .csv de los corpus
# Iterando sobre elemento 557 del .csv de los corpus
# Iterando sobre elemento 558 del .csv de los corpus
# Iterando sobre elemento 559 del .csv de los corpus
# Iterando sobre elemento 560 del .csv de los corpus
# Iterando sobre elemento 561 del .csv de los corpus
# Iterando sobre elemento 562 del .csv de los corpus
# Iterando sobre elemento 563 del .csv de los corpus
# Iterando sobre elemento 564 del .csv de los corpus
# Iterando sobre elemento 565 del .csv de los corpus
# Iterando sobre elemento 566 del .csv de los corpus
# Iterando sobre elemento 567 del .csv de los corpus
# Iterando sobre elemento 568 del .csv de los corpus
# Iterando sobre elemento 569 del .csv de los corpus
# Iterando sobre elemento 570 del .csv de los corpus
# Iterando sobre elemento 571 del .csv de los corpus
# Iterando sobre elemento 572 del .csv de los corpus
# Iterando sobre elemento 573 del .csv de los corpus
# Iterando sobre elemento 574 del .csv de los corpus
# Iterando sobre elemento 575 del .csv de los corpus
# Iterando sobre elemento 576 del .csv de los corpus
# Iterando sobre elemento 577 del .csv de los corpus
# Iterando sobre elemento 578 del .csv de los corpus
# Iterando sobre elemento 579 del .csv de los corpus
# Iterando sobre elemento 580 del .csv de los corpus
# Iterando sobre elemento 581 del .csv de los corpus
# Iterando sobre elemento 582 del .csv de los corpus
# Iterando sobre elemento 583 del .csv de los corpus
# Iterando sobre elemento 584 del .csv de los corpus
# Iterando sobre elemento 585 del .csv de los corpus
# Iterando sobre elemento 586 del .csv de los corpus
# Iterando sobre elemento 587 del .csv de los corpus
# Iterando sobre elemento 588 del .csv de los corpus
# Iterando sobre elemento 589 del .csv de los corpus
# Iterando sobre elemento 590 del .csv de los corpus
# Iterando sobre elemento 591 del .csv de los corpus
# Iterando sobre elemento 592 del .csv de los corpus
# Iterando sobre elemento 593 del .csv de los corpus
# Iterando sobre elemento 594 del .csv de los corpus
# Iterando sobre elemento 595 del .csv de los corpus
# Iterando sobre elemento 596 del .csv de los corpus
# Iterando sobre elemento 597 del .csv de los corpus
# Iterando sobre elemento 598 del .csv de los corpus
# Iterando sobre elemento 599 del .csv de los corpus
# Iterando sobre elemento 600 del .csv de los corpus
# Iterando sobre elemento 601 del .csv de los corpus
# Iterando sobre elemento 602 del .csv de los corpus
# Iterando sobre elemento 603 del .csv de los corpus
# Iterando sobre elemento 604 del .csv de los corpus
# Iterando sobre elemento 605 del .csv de los corpus
# Iterando sobre elemento 606 del .csv de los corpus
# Iterando sobre elemento 607 del .csv de los corpus
# Iterando sobre elemento 608 del .csv de los corpus
# Iterando sobre elemento 609 del .csv de los corpus
# Iterando sobre elemento 610 del .csv de los corpus
# Iterando sobre elemento 611 del .csv de los corpus
# Iterando sobre elemento 612 del .csv de los corpus
# Iterando sobre elemento 613 del .csv de los corpus
# Iterando sobre elemento 614 del .csv de los corpus
# Iterando sobre elemento 615 del .csv de los corpus
# Iterando sobre elemento 616 del .csv de los corpus
# Iterando sobre elemento 617 del .csv de los corpus
# Iterando sobre elemento 618 del .csv de los corpus
# Iterando sobre elemento 619 del .csv de los corpus
# Iterando sobre elemento 620 del .csv de los corpus
# Iterando sobre elemento 621 del .csv de los corpus
# Iterando sobre elemento 622 del .csv de los corpus
# Iterando sobre elemento 623 del .csv de los corpus
# Iterando sobre elemento 624 del .csv de los corpus
# Iterando sobre elemento 625 del .csv de los corpus
# Iterando sobre elemento 626 del .csv de los corpus
# Iterando sobre elemento 627 del .csv de los corpus
# Iterando sobre elemento 628 del .csv de los corpus
# Iterando sobre elemento 629 del .csv de los corpus
# Iterando sobre elemento 630 del .csv de los corpus
# Iterando sobre elemento 631 del .csv de los corpus
# Iterando sobre elemento 632 del .csv de los corpus
# Iterando sobre elemento 633 del .csv de los corpus
# Iterando sobre elemento 634 del .csv de los corpus
# Iterando sobre elemento 635 del .csv de los corpus
# Iterando sobre elemento 636 del .csv de los corpus
# Iterando sobre elemento 637 del .csv de los corpus
# Iterando sobre elemento 638 del .csv de los corpus
# Iterando sobre elemento 639 del .csv de los corpus
# Iterando sobre elemento 640 del .csv de los corpus
# Iterando sobre elemento 641 del .csv de los corpus
# Iterando sobre elemento 642 del .csv de los corpus
# Iterando sobre elemento 643 del .csv de los corpus
# Iterando sobre elemento 644 del .csv de los corpus
# Iterando sobre elemento 645 del .csv de los corpus
# Iterando sobre elemento 646 del .csv de los corpus
# Iterando sobre elemento 647 del .csv de los corpus
# Iterando sobre elemento 648 del .csv de los corpus
# Iterando sobre elemento 649 del .csv de los corpus
# Iterando sobre elemento 650 del .csv de los corpus
# Iterando sobre elemento 651 del .csv de los corpus
# Iterando sobre elemento 652 del .csv de los corpus
# Iterando sobre elemento 653 del .csv de los corpus
# Iterando sobre elemento 654 del .csv de los corpus
# Iterando sobre elemento 655 del .csv de los corpus
# Iterando sobre elemento 656 del .csv de los corpus
# Iterando sobre elemento 657 del .csv de los corpus
# Iterando sobre elemento 658 del .csv de los corpus
# Iterando sobre elemento 659 del .csv de los corpus
# Iterando sobre elemento 660 del .csv de los corpus
# Iterando sobre elemento 661 del .csv de los corpus
# Iterando sobre elemento 662 del .csv de los corpus
# Iterando sobre elemento 663 del .csv de los corpus
# Iterando sobre elemento 664 del .csv de los corpus
# Iterando sobre elemento 665 del .csv de los corpus
# Iterando sobre elemento 666 del .csv de los corpus
# Iterando sobre elemento 667 del .csv de los corpus
# Iterando sobre elemento 668 del .csv de los corpus
# Iterando sobre elemento 669 del .csv de los corpus
# Iterando sobre elemento 670 del .csv de los corpus
# Iterando sobre elemento 671 del .csv de los corpus
# Iterando sobre elemento 672 del .csv de los corpus
# Iterando sobre elemento 673 del .csv de los corpus
# Iterando sobre elemento 674 del .csv de los corpus
# Iterando sobre elemento 675 del .csv de los corpus
# Iterando sobre elemento 676 del .csv de los corpus
# Iterando sobre elemento 677 del .csv de los corpus
# Iterando sobre elemento 678 del .csv de los corpus
# Iterando sobre elemento 679 del .csv de los corpus
# Iterando sobre elemento 680 del .csv de los corpus
# Iterando sobre elemento 681 del .csv de los corpus
# Iterando sobre elemento 682 del .csv de los corpus
# Iterando sobre elemento 683 del .csv de los corpus
# Iterando sobre elemento 684 del .csv de los corpus
# Iterando sobre elemento 685 del .csv de los corpus
# Iterando sobre elemento 686 del .csv de los corpus
# Iterando sobre elemento 687 del .csv de los corpus
# Iterando sobre elemento 688 del .csv de los corpus
# Iterando sobre elemento 689 del .csv de los corpus
# Iterando sobre elemento 690 del .csv de los corpus
# Iterando sobre elemento 691 del .csv de los corpus
# Iterando sobre elemento 692 del .csv de los corpus
# Iterando sobre elemento 693 del .csv de los corpus
# Iterando sobre elemento 694 del .csv de los corpus
# Iterando sobre elemento 695 del .csv de los corpus
# Iterando sobre elemento 696 del .csv de los corpus
# Iterando sobre elemento 697 del .csv de los corpus
# Iterando sobre elemento 698 del .csv de los corpus
# Iterando sobre elemento 699 del .csv de los corpus
# Iterando sobre elemento 700 del .csv de los corpus
# Iterando sobre elemento 701 del .csv de los corpus
# Iterando sobre elemento 702 del .csv de los corpus
# Iterando sobre elemento 703 del .csv de los corpus
# Iterando sobre elemento 704 del .csv de los corpus
# Iterando sobre elemento 705 del .csv de los corpus
# Iterando sobre elemento 706 del .csv de los corpus
# Iterando sobre elemento 707 del .csv de los corpus
# Iterando sobre elemento 708 del .csv de los corpus
# Iterando sobre elemento 709 del .csv de los corpus
# Iterando sobre elemento 710 del .csv de los corpus
# Iterando sobre elemento 711 del .csv de los corpus
# Iterando sobre elemento 712 del .csv de los corpus
# Iterando sobre elemento 713 del .csv de los corpus
# Iterando sobre elemento 714 del .csv de los corpus
# Iterando sobre elemento 715 del .csv de los corpus
# Iterando sobre elemento 716 del .csv de los corpus
# Iterando sobre elemento 717 del .csv de los corpus
# Iterando sobre elemento 718 del .csv de los corpus
# Iterando sobre elemento 719 del .csv de los corpus
# Iterando sobre elemento 720 del .csv de los corpus
# Iterando sobre elemento 721 del .csv de los corpus
# Iterando sobre elemento 722 del .csv de los corpus
# Iterando sobre elemento 723 del .csv de los corpus
# Iterando sobre elemento 724 del .csv de los corpus
# Iterando sobre elemento 725 del .csv de los corpus
# Iterando sobre elemento 726 del .csv de los corpus
# Iterando sobre elemento 727 del .csv de los corpus
# Iterando sobre elemento 728 del .csv de los corpus
# Iterando sobre elemento 729 del .csv de los corpus
# Iterando sobre elemento 730 del .csv de los corpus
# Iterando sobre elemento 731 del .csv de los corpus
# Iterando sobre elemento 732 del .csv de los corpus
# Iterando sobre elemento 733 del .csv de los corpus
# Iterando sobre elemento 734 del .csv de los corpus
# Iterando sobre elemento 735 del .csv de los corpus
# Iterando sobre elemento 736 del .csv de los corpus
# Iterando sobre elemento 737 del .csv de los corpus
# Iterando sobre elemento 738 del .csv de los corpus
# Iterando sobre elemento 739 del .csv de los corpus
# Iterando sobre elemento 740 del .csv de los corpus
# Iterando sobre elemento 741 del .csv de los corpus
# Iterando sobre elemento 742 del .csv de los corpus
# Iterando sobre elemento 743 del .csv de los corpus
# Iterando sobre elemento 744 del .csv de los corpus
# Iterando sobre elemento 745 del .csv de los corpus
# Iterando sobre elemento 746 del .csv de los corpus
# Iterando sobre elemento 747 del .csv de los corpus
# Iterando sobre elemento 748 del .csv de los corpus
# Iterando sobre elemento 749 del .csv de los corpus
# Iterando sobre elemento 750 del .csv de los corpus
# Iterando sobre elemento 751 del .csv de los corpus
# Iterando sobre elemento 752 del .csv de los corpus
# Iterando sobre elemento 753 del .csv de los corpus
# Iterando sobre elemento 754 del .csv de los corpus
# Iterando sobre elemento 755 del .csv de los corpus
# Iterando sobre elemento 756 del .csv de los corpus
# Iterando sobre elemento 757 del .csv de los corpus
# Iterando sobre elemento 758 del .csv de los corpus
# Iterando sobre elemento 759 del .csv de los corpus
# Iterando sobre elemento 760 del .csv de los corpus
# Iterando sobre elemento 761 del .csv de los corpus
# Iterando sobre elemento 762 del .csv de los corpus
# Iterando sobre elemento 763 del .csv de los corpus
# Iterando sobre elemento 764 del .csv de los corpus
# Iterando sobre elemento 765 del .csv de los corpus
# Iterando sobre elemento 766 del .csv de los corpus
# Iterando sobre elemento 767 del .csv de los corpus
# Iterando sobre elemento 768 del .csv de los corpus
# Iterando sobre elemento 769 del .csv de los corpus
# Iterando sobre elemento 770 del .csv de los corpus
# Iterando sobre elemento 771 del .csv de los corpus
# Iterando sobre elemento 772 del .csv de los corpus
# Iterando sobre elemento 773 del .csv de los corpus
# Iterando sobre elemento 774 del .csv de los corpus
# Iterando sobre elemento 775 del .csv de los corpus
# Iterando sobre elemento 776 del .csv de los corpus
# Iterando sobre elemento 777 del .csv de los corpus
# Iterando sobre elemento 778 del .csv de los corpus
# Iterando sobre elemento 779 del .csv de los corpus
# Iterando sobre elemento 780 del .csv de los corpus
# Iterando sobre elemento 781 del .csv de los corpus
# Iterando sobre elemento 782 del .csv de los corpus
# Iterando sobre elemento 783 del .csv de los corpus
# Iterando sobre elemento 784 del .csv de los corpus
# Iterando sobre elemento 785 del .csv de los corpus
# Iterando sobre elemento 786 del .csv de los corpus
# Iterando sobre elemento 787 del .csv de los corpus
# Iterando sobre elemento 788 del .csv de los corpus
# Iterando sobre elemento 789 del .csv de los corpus
# Iterando sobre elemento 790 del .csv de los corpus
# Iterando sobre elemento 791 del .csv de los corpus
# Iterando sobre elemento 792 del .csv de los corpus
# Iterando sobre elemento 793 del .csv de los corpus
# Iterando sobre elemento 794 del .csv de los corpus
# Iterando sobre elemento 795 del .csv de los corpus
# Iterando sobre elemento 796 del .csv de los corpus
# Iterando sobre elemento 797 del .csv de los corpus
# Iterando sobre elemento 798 del .csv de los corpus
# Iterando sobre elemento 799 del .csv de los corpus
# Iterando sobre elemento 800 del .csv de los corpus
# Iterando sobre elemento 801 del .csv de los corpus
# Iterando sobre elemento 802 del .csv de los corpus
# Iterando sobre elemento 803 del .csv de los corpus
# Iterando sobre elemento 804 del .csv de los corpus
# Iterando sobre elemento 805 del .csv de los corpus
# Iterando sobre elemento 806 del .csv de los corpus
# Iterando sobre elemento 807 del .csv de los corpus
# Iterando sobre elemento 808 del .csv de los corpus
# Iterando sobre elemento 809 del .csv de los corpus
# Iterando sobre elemento 810 del .csv de los corpus
# Iterando sobre elemento 811 del .csv de los corpus
# Iterando sobre elemento 812 del .csv de los corpus
# Iterando sobre elemento 813 del .csv de los corpus
# Iterando sobre elemento 814 del .csv de los corpus
# Iterando sobre elemento 815 del .csv de los corpus
# Iterando sobre elemento 816 del .csv de los corpus
# Iterando sobre elemento 817 del .csv de los corpus
# Iterando sobre elemento 818 del .csv de los corpus
# Iterando sobre elemento 819 del .csv de los corpus
# Iterando sobre elemento 820 del .csv de los corpus
# Iterando sobre elemento 821 del .csv de los corpus
# Iterando sobre elemento 822 del .csv de los corpus
# Iterando sobre elemento 823 del .csv de los corpus
# Iterando sobre elemento 824 del .csv de los corpus
# Iterando sobre elemento 825 del .csv de los corpus
# Iterando sobre elemento 826 del .csv de los corpus
# Iterando sobre elemento 827 del .csv de los corpus
# Iterando sobre elemento 828 del .csv de los corpus
# Iterando sobre elemento 829 del .csv de los corpus
# Iterando sobre elemento 830 del .csv de los corpus
# Iterando sobre elemento 831 del .csv de los corpus
# Iterando sobre elemento 832 del .csv de los corpus
# Iterando sobre elemento 833 del .csv de los corpus
# Iterando sobre elemento 834 del .csv de los corpus
# Iterando sobre elemento 835 del .csv de los corpus
# Iterando sobre elemento 836 del .csv de los corpus
# Iterando sobre elemento 837 del .csv de los corpus
# Iterando sobre elemento 838 del .csv de los corpus
# Iterando sobre elemento 839 del .csv de los corpus
# Iterando sobre elemento 840 del .csv de los corpus
# Iterando sobre elemento 841 del .csv de los corpus
# Iterando sobre elemento 842 del .csv de los corpus
# Iterando sobre elemento 843 del .csv de los corpus
# Iterando sobre elemento 844 del .csv de los corpus
# Iterando sobre elemento 845 del .csv de los corpus
# Iterando sobre elemento 846 del .csv de los corpus
# Iterando sobre elemento 847 del .csv de los corpus
# Iterando sobre elemento 848 del .csv de los corpus
# Iterando sobre elemento 849 del .csv de los corpus
# Iterando sobre elemento 850 del .csv de los corpus
# Iterando sobre elemento 851 del .csv de los corpus
# Iterando sobre elemento 852 del .csv de los corpus
# Iterando sobre elemento 853 del .csv de los corpus
# Iterando sobre elemento 854 del .csv de los corpus
# Iterando sobre elemento 855 del .csv de los corpus
# Iterando sobre elemento 856 del .csv de los corpus
# Iterando sobre elemento 857 del .csv de los corpus
# Iterando sobre elemento 858 del .csv de los corpus
# Iterando sobre elemento 859 del .csv de los corpus
# Iterando sobre elemento 860 del .csv de los corpus
# Iterando sobre elemento 861 del .csv de los corpus
# Iterando sobre elemento 862 del .csv de los corpus
# Iterando sobre elemento 863 del .csv de los corpus
# Iterando sobre elemento 864 del .csv de los corpus
# Iterando sobre elemento 865 del .csv de los corpus
# Iterando sobre elemento 866 del .csv de los corpus
# Iterando sobre elemento 867 del .csv de los corpus
# Iterando sobre elemento 868 del .csv de los corpus
# Iterando sobre elemento 869 del .csv de los corpus
# Iterando sobre elemento 870 del .csv de los corpus
# Iterando sobre elemento 871 del .csv de los corpus
# Iterando sobre elemento 872 del .csv de los corpus
# Iterando sobre elemento 873 del .csv de los corpus
# Iterando sobre elemento 874 del .csv de los corpus
# Iterando sobre elemento 875 del .csv de los corpus
# Iterando sobre elemento 876 del .csv de los corpus
# Iterando sobre elemento 877 del .csv de los corpus
# Iterando sobre elemento 878 del .csv de los corpus
# Iterando sobre elemento 879 del .csv de los corpus
# Iterando sobre elemento 880 del .csv de los corpus
# Iterando sobre elemento 881 del .csv de los corpus
# Iterando sobre elemento 882 del .csv de los corpus
# Iterando sobre elemento 883 del .csv de los corpus
# Iterando sobre elemento 884 del .csv de los corpus
# Iterando sobre elemento 885 del .csv de los corpus
# Iterando sobre elemento 886 del .csv de los corpus
# Iterando sobre elemento 887 del .csv de los corpus
# Iterando sobre elemento 888 del .csv de los corpus
# Iterando sobre elemento 889 del .csv de los corpus
# Iterando sobre elemento 890 del .csv de los corpus
# Iterando sobre elemento 891 del .csv de los corpus
# Iterando sobre elemento 892 del .csv de los corpus
# Iterando sobre elemento 893 del .csv de los corpus
# Iterando sobre elemento 894 del .csv de los corpus
# Iterando sobre elemento 895 del .csv de los corpus
# Iterando sobre elemento 896 del .csv de los corpus
# Iterando sobre elemento 897 del .csv de los corpus
# Iterando sobre elemento 898 del .csv de los corpus
# Iterando sobre elemento 899 del .csv de los corpus
# Iterando sobre elemento 900 del .csv de los corpus
# Iterando sobre elemento 901 del .csv de los corpus
# Iterando sobre elemento 902 del .csv de los corpus
# Iterando sobre elemento 903 del .csv de los corpus
# Iterando sobre elemento 904 del .csv de los corpus
# Iterando sobre elemento 905 del .csv de los corpus
# Iterando sobre elemento 906 del .csv de los corpus
# Iterando sobre elemento 907 del .csv de los corpus
# Iterando sobre elemento 908 del .csv de los corpus
# Iterando sobre elemento 909 del .csv de los corpus
# Iterando sobre elemento 910 del .csv de los corpus
# Iterando sobre elemento 911 del .csv de los corpus
# Iterando sobre elemento 912 del .csv de los corpus
# Iterando sobre elemento 913 del .csv de los corpus
# Iterando sobre elemento 914 del .csv de los corpus
# Iterando sobre elemento 915 del .csv de los corpus
# Iterando sobre elemento 916 del .csv de los corpus
# Iterando sobre elemento 917 del .csv de los corpus
# Iterando sobre elemento 918 del .csv de los corpus
# Iterando sobre elemento 919 del .csv de los corpus
# Iterando sobre elemento 920 del .csv de los corpus
# Iterando sobre elemento 921 del .csv de los corpus
# Iterando sobre elemento 922 del .csv de los corpus
# Iterando sobre elemento 923 del .csv de los corpus
# Iterando sobre elemento 924 del .csv de los corpus
# Iterando sobre elemento 925 del .csv de los corpus
# Iterando sobre elemento 926 del .csv de los corpus
# Iterando sobre elemento 927 del .csv de los corpus
# Iterando sobre elemento 928 del .csv de los corpus
# Iterando sobre elemento 929 del .csv de los corpus
# Iterando sobre elemento 930 del .csv de los corpus
# Iterando sobre elemento 931 del .csv de los corpus
# Iterando sobre elemento 932 del .csv de los corpus
# Iterando sobre elemento 933 del .csv de los corpus
# Iterando sobre elemento 934 del .csv de los corpus
# Iterando sobre elemento 935 del .csv de los corpus
# Iterando sobre elemento 936 del .csv de los corpus
# Iterando sobre elemento 937 del .csv de los corpus
# Iterando sobre elemento 938 del .csv de los corpus
# Iterando sobre elemento 939 del .csv de los corpus
# Iterando sobre elemento 940 del .csv de los corpus
# Iterando sobre elemento 941 del .csv de los corpus
# Iterando sobre elemento 942 del .csv de los corpus
# Iterando sobre elemento 943 del .csv de los corpus
# ...
# Iterando sobre elemento 10488 del .csv de los corpus
# Iterando sobre elemento 10489 del .csv de los corpus
# Iterando sobre elemento 10490 del .csv de los corpus
# Iterando sobre elemento 10491 del .csv de los corpus
# Iterando sobre elemento 10492 del .csv de los corpus
# Iterando sobre elemento 10493 del .csv de los corpus
# Iterando sobre elemento 10494 del .csv de los corpus
# Iterando sobre elemento 10495 del .csv de los corpus
# Iterando sobre elemento 10496 del .csv de los corpus
# Iterando sobre elemento 10497 del .csv de los corpus
# Iterando sobre elemento 10498 del .csv de los corpus
# Iterando sobre elemento 10499 del .csv de los corpus
# Iterando sobre elemento 10500 del .csv de los corpus
# Iterando sobre elemento 10501 del .csv de los corpus
# Iterando sobre elemento 10502 del .csv de los corpus
# Iterando sobre elemento 10503 del .csv de los corpus
# Iterando sobre elemento 10504 del .csv de los corpus
# Iterando sobre elemento 10505 del .csv de los corpus
# Iterando sobre elemento 10506 del .csv de los corpus
# Iterando sobre elemento 10507 del .csv de los corpus
# Iterando sobre elemento 10508 del .csv de los corpus
# Iterando sobre elemento 10509 del .csv de los corpus
# Iterando sobre elemento 10510 del .csv de los corpus
# Iterando sobre elemento 10511 del .csv de los corpus
# Iterando sobre elemento 10512 del .csv de los corpus
# Iterando sobre elemento 10513 del .csv de los corpus
# Iterando sobre elemento 10514 del .csv de los corpus
# Iterando sobre elemento 10515 del .csv de los corpus
# Iterando sobre elemento 10516 del .csv de los corpus
# Iterando sobre elemento 10517 del .csv de los corpus
# Iterando sobre elemento 10518 del .csv de los corpus
# Iterando sobre elemento 10519 del .csv de los corpus
# Iterando sobre elemento 10520 del .csv de los corpus
# Iterando sobre elemento 10521 del .csv de los corpus
# Iterando sobre elemento 10522 del .csv de los corpus
# Iterando sobre elemento 10523 del .csv de los corpus
# Iterando sobre elemento 10524 del .csv de los corpus
# Iterando sobre elemento 10525 del .csv de los corpus
# Iterando sobre elemento 10526 del .csv de los corpus
# Iterando sobre elemento 10527 del .csv de los corpus
# Iterando sobre elemento 10528 del .csv de los corpus
# Iterando sobre elemento 10529 del .csv de los corpus
# Iterando sobre elemento 10530 del .csv de los corpus
# Iterando sobre elemento 10531 del .csv de los corpus
# Iterando sobre elemento 10532 del .csv de los corpus
# Iterando sobre elemento 10533 del .csv de los corpus
# Iterando sobre elemento 10534 del .csv de los corpus
# Iterando sobre elemento 10535 del .csv de los corpus
# Iterando sobre elemento 10536 del .csv de los corpus
# Iterando sobre elemento 10537 del .csv de los corpus
# Iterando sobre elemento 10538 del .csv de los corpus
# Iterando sobre elemento 10539 del .csv de los corpus
# Iterando sobre elemento 10540 del .csv de los corpus
# Iterando sobre elemento 10541 del .csv de los corpus
# Iterando sobre elemento 10542 del .csv de los corpus
# Iterando sobre elemento 10543 del .csv de los corpus
# Iterando sobre elemento 10544 del .csv de los corpus
# Iterando sobre elemento 10545 del .csv de los corpus
# Iterando sobre elemento 10546 del .csv de los corpus
# Iterando sobre elemento 10547 del .csv de los corpus
# Iterando sobre elemento 10548 del .csv de los corpus
# Iterando sobre elemento 10549 del .csv de los corpus
# Iterando sobre elemento 10550 del .csv de los corpus
# Iterando sobre elemento 10551 del .csv de los corpus
# Iterando sobre elemento 10552 del .csv de los corpus
# Iterando sobre elemento 10553 del .csv de los corpus
# Iterando sobre elemento 10554 del .csv de los corpus
# Iterando sobre elemento 10555 del .csv de los corpus
# Iterando sobre elemento 10556 del .csv de los corpus
# Iterando sobre elemento 10557 del .csv de los corpus
# Iterando sobre elemento 10558 del .csv de los corpus
# Iterando sobre elemento 10559 del .csv de los corpus
# Iterando sobre elemento 10560 del .csv de los corpus
# Iterando sobre elemento 10561 del .csv de los corpus
# Iterando sobre elemento 10562 del .csv de los corpus
# Iterando sobre elemento 10563 del .csv de los corpus
# Iterando sobre elemento 10564 del .csv de los corpus
# Iterando sobre elemento 10565 del .csv de los corpus
# Iterando sobre elemento 10566 del .csv de los corpus
# Iterando sobre elemento 10567 del .csv de los corpus
# Iterando sobre elemento 10568 del .csv de los corpus
# Iterando sobre elemento 10569 del .csv de los corpus
# Iterando sobre elemento 10570 del .csv de los corpus
# Iterando sobre elemento 10571 del .csv de los corpus
# Iterando sobre elemento 10572 del .csv de los corpus
# Iterando sobre elemento 10573 del .csv de los corpus
# Iterando sobre elemento 10574 del .csv de los corpus
# Iterando sobre elemento 10575 del .csv de los corpus
# Iterando sobre elemento 10576 del .csv de los corpus
# Iterando sobre elemento 10577 del .csv de los corpus
# Iterando sobre elemento 10578 del .csv de los corpus
# Iterando sobre elemento 10579 del .csv de los corpus
# Iterando sobre elemento 10580 del .csv de los corpus
# Iterando sobre elemento 10581 del .csv de los corpus
# Iterando sobre elemento 10582 del .csv de los corpus
# Iterando sobre elemento 10583 del .csv de los corpus
# Iterando sobre elemento 10584 del .csv de los corpus
# Iterando sobre elemento 10585 del .csv de los corpus
# Iterando sobre elemento 10586 del .csv de los corpus
# Iterando sobre elemento 10587 del .csv de los corpus
# Iterando sobre elemento 10588 del .csv de los corpus
# Iterando sobre elemento 10589 del .csv de los corpus
# Iterando sobre elemento 10590 del .csv de los corpus
# Iterando sobre elemento 10591 del .csv de los corpus
# Iterando sobre elemento 10592 del .csv de los corpus
# Iterando sobre elemento 10593 del .csv de los corpus
# Iterando sobre elemento 10594 del .csv de los corpus
# Iterando sobre elemento 10595 del .csv de los corpus
# Iterando sobre elemento 10596 del .csv de los corpus
# Iterando sobre elemento 10597 del .csv de los corpus
# Iterando sobre elemento 10598 del .csv de los corpus
# Iterando sobre elemento 10599 del .csv de los corpus
# Iterando sobre elemento 10600 del .csv de los corpus
# Iterando sobre elemento 10601 del .csv de los corpus
# Iterando sobre elemento 10602 del .csv de los corpus
# Iterando sobre elemento 10603 del .csv de los corpus
# Iterando sobre elemento 10604 del .csv de los corpus
# Iterando sobre elemento 10605 del .csv de los corpus
# Iterando sobre elemento 10606 del .csv de los corpus
# Iterando sobre elemento 10607 del .csv de los corpus
# Iterando sobre elemento 10608 del .csv de los corpus
# Iterando sobre elemento 10609 del .csv de los corpus
# Iterando sobre elemento 10610 del .csv de los corpus
# Iterando sobre elemento 10611 del .csv de los corpus
# Iterando sobre elemento 10612 del .csv de los corpus
# Iterando sobre elemento 10613 del .csv de los corpus
# Iterando sobre elemento 10614 del .csv de los corpus
# Iterando sobre elemento 10615 del .csv de los corpus
# Iterando sobre elemento 10616 del .csv de los corpus
# Iterando sobre elemento 10617 del .csv de los corpus
# Iterando sobre elemento 10618 del .csv de los corpus
# Iterando sobre elemento 10619 del .csv de los corpus
# Iterando sobre elemento 10620 del .csv de los corpus
# Iterando sobre elemento 10621 del .csv de los corpus
# Iterando sobre elemento 10622 del .csv de los corpus
# Iterando sobre elemento 10623 del .csv de los corpus
# Iterando sobre elemento 10624 del .csv de los corpus
# Iterando sobre elemento 10625 del .csv de los corpus
# Iterando sobre elemento 10626 del .csv de los corpus
# Iterando sobre elemento 10627 del .csv de los corpus
# Iterando sobre elemento 10628 del .csv de los corpus
# Iterando sobre elemento 10629 del .csv de los corpus
# Iterando sobre elemento 10630 del .csv de los corpus
# Iterando sobre elemento 10631 del .csv de los corpus
# Iterando sobre elemento 10632 del .csv de los corpus
# Iterando sobre elemento 10633 del .csv de los corpus
# Iterando sobre elemento 10634 del .csv de los corpus
# Iterando sobre elemento 10635 del .csv de los corpus
# Iterando sobre elemento 10636 del .csv de los corpus
# Iterando sobre elemento 10637 del .csv de los corpus
# Iterando sobre elemento 10638 del .csv de los corpus
# Iterando sobre elemento 10639 del .csv de los corpus
# Iterando sobre elemento 10640 del .csv de los corpus
# Iterando sobre elemento 10641 del .csv de los corpus
# Iterando sobre elemento 10642 del .csv de los corpus
# Iterando sobre elemento 10643 del .csv de los corpus
# Iterando sobre elemento 10644 del .csv de los corpus
# Iterando sobre elemento 10645 del .csv de los corpus
# Iterando sobre elemento 10646 del .csv de los corpus
# Iterando sobre elemento 10647 del .csv de los corpus
# Iterando sobre elemento 10648 del .csv de los corpus
# Iterando sobre elemento 10649 del .csv de los corpus
# Iterando sobre elemento 10650 del .csv de los corpus
# Iterando sobre elemento 10651 del .csv de los corpus
# Iterando sobre elemento 10652 del .csv de los corpus
# Iterando sobre elemento 10653 del .csv de los corpus
# Iterando sobre elemento 10654 del .csv de los corpus
# Iterando sobre elemento 10655 del .csv de los corpus
# Iterando sobre elemento 10656 del .csv de los corpus
# Iterando sobre elemento 10657 del .csv de los corpus
# Iterando sobre elemento 10658 del .csv de los corpus
# Iterando sobre elemento 10659 del .csv de los corpus
# Iterando sobre elemento 10660 del .csv de los corpus
# Iterando sobre elemento 10661 del .csv de los corpus
# Iterando sobre elemento 10662 del .csv de los corpus
# Iterando sobre elemento 10663 del .csv de los corpus
# Iterando sobre elemento 10664 del .csv de los corpus
# Iterando sobre elemento 10665 del .csv de los corpus
# Iterando sobre elemento 10666 del .csv de los corpus
# Iterando sobre elemento 10667 del .csv de los corpus
# Iterando sobre elemento 10668 del .csv de los corpus
# Iterando sobre elemento 10669 del .csv de los corpus
# Iterando sobre elemento 10670 del .csv de los corpus
# Iterando sobre elemento 10671 del .csv de los corpus
# Iterando sobre elemento 10672 del .csv de los corpus
# Iterando sobre elemento 10673 del .csv de los corpus
# Iterando sobre elemento 10674 del .csv de los corpus
# Iterando sobre elemento 10675 del .csv de los corpus
# Iterando sobre elemento 10676 del .csv de los corpus
# Iterando sobre elemento 10677 del .csv de los corpus
# Iterando sobre elemento 10678 del .csv de los corpus
# Iterando sobre elemento 10679 del .csv de los corpus
# Iterando sobre elemento 10680 del .csv de los corpus
# Iterando sobre elemento 10681 del .csv de los corpus
# Iterando sobre elemento 10682 del .csv de los corpus
# Iterando sobre elemento 10683 del .csv de los corpus
# Iterando sobre elemento 10684 del .csv de los corpus
# Iterando sobre elemento 10685 del .csv de los corpus
# Iterando sobre elemento 10686 del .csv de los corpus
# Iterando sobre elemento 10687 del .csv de los corpus
# Iterando sobre elemento 10688 del .csv de los corpus
# Iterando sobre elemento 10689 del .csv de los corpus
# Iterando sobre elemento 10690 del .csv de los corpus
# Iterando sobre elemento 10691 del .csv de los corpus
# Iterando sobre elemento 10692 del .csv de los corpus
# Iterando sobre elemento 10693 del .csv de los corpus
# Iterando sobre elemento 10694 del .csv de los corpus
# Iterando sobre elemento 10695 del .csv de los corpus
# Iterando sobre elemento 10696 del .csv de los corpus
# Iterando sobre elemento 10697 del .csv de los corpus
# Iterando sobre elemento 10698 del .csv de los corpus
# Iterando sobre elemento 10699 del .csv de los corpus
# Iterando sobre elemento 10700 del .csv de los corpus
# Iterando sobre elemento 10701 del .csv de los corpus
# Iterando sobre elemento 10702 del .csv de los corpus
# Iterando sobre elemento 10703 del .csv de los corpus
# Iterando sobre elemento 10704 del .csv de los corpus
# Iterando sobre elemento 10705 del .csv de los corpus
# Iterando sobre elemento 10706 del .csv de los corpus
# Iterando sobre elemento 10707 del .csv de los corpus
# Iterando sobre elemento 10708 del .csv de los corpus
# Iterando sobre elemento 10709 del .csv de los corpus
# Iterando sobre elemento 10710 del .csv de los corpus
# Iterando sobre elemento 10711 del .csv de los corpus
# Iterando sobre elemento 10712 del .csv de los corpus
# Iterando sobre elemento 10713 del .csv de los corpus
# Iterando sobre elemento 10714 del .csv de los corpus
# Iterando sobre elemento 10715 del .csv de los corpus
# Iterando sobre elemento 10716 del .csv de los corpus
# Iterando sobre elemento 10717 del .csv de los corpus
# Iterando sobre elemento 10718 del .csv de los corpus
# Iterando sobre elemento 10719 del .csv de los corpus
# Iterando sobre elemento 10720 del .csv de los corpus
# Iterando sobre elemento 10721 del .csv de los corpus
# Iterando sobre elemento 10722 del .csv de los corpus
# Iterando sobre elemento 10723 del .csv de los corpus
# Iterando sobre elemento 10724 del .csv de los corpus
# Iterando sobre elemento 10725 del .csv de los corpus
# Iterando sobre elemento 10726 del .csv de los corpus
# Iterando sobre elemento 10727 del .csv de los corpus
# Iterando sobre elemento 10728 del .csv de los corpus
# Iterando sobre elemento 10729 del .csv de los corpus
# Iterando sobre elemento 10730 del .csv de los corpus
# Iterando sobre elemento 10731 del .csv de los corpus
# Iterando sobre elemento 10732 del .csv de los corpus
# Iterando sobre elemento 10733 del .csv de los corpus
# Iterando sobre elemento 10734 del .csv de los corpus
# Iterando sobre elemento 10735 del .csv de los corpus
# Iterando sobre elemento 10736 del .csv de los corpus
# Iterando sobre elemento 10737 del .csv de los corpus
# Iterando sobre elemento 10738 del .csv de los corpus
# Iterando sobre elemento 10739 del .csv de los corpus
# Iterando sobre elemento 10740 del .csv de los corpus
# Iterando sobre elemento 10741 del .csv de los corpus
# Iterando sobre elemento 10742 del .csv de los corpus
# Iterando sobre elemento 10743 del .csv de los corpus
# Iterando sobre elemento 10744 del .csv de los corpus
# Iterando sobre elemento 10745 del .csv de los corpus
# Iterando sobre elemento 10746 del .csv de los corpus
# Iterando sobre elemento 10747 del .csv de los corpus
# Iterando sobre elemento 10748 del .csv de los corpus
# Iterando sobre elemento 10749 del .csv de los corpus
# Iterando sobre elemento 10750 del .csv de los corpus
# Iterando sobre elemento 10751 del .csv de los corpus
# Iterando sobre elemento 10752 del .csv de los corpus
# Iterando sobre elemento 10753 del .csv de los corpus
# Iterando sobre elemento 10754 del .csv de los corpus
# Iterando sobre elemento 10755 del .csv de los corpus
# Iterando sobre elemento 10756 del .csv de los corpus
# Iterando sobre elemento 10757 del .csv de los corpus
# Iterando sobre elemento 10758 del .csv de los corpus
# Iterando sobre elemento 10759 del .csv de los corpus
# Iterando sobre elemento 10760 del .csv de los corpus
# Iterando sobre elemento 10761 del .csv de los corpus
# Iterando sobre elemento 10762 del .csv de los corpus
# Iterando sobre elemento 10763 del .csv de los corpus
# Iterando sobre elemento 10764 del .csv de los corpus
# Iterando sobre elemento 10765 del .csv de los corpus
# Iterando sobre elemento 10766 del .csv de los corpus
# Iterando sobre elemento 10767 del .csv de los corpus
# Iterando sobre elemento 10768 del .csv de los corpus
# Iterando sobre elemento 10769 del .csv de los corpus
# Iterando sobre elemento 10770 del .csv de los corpus
# Iterando sobre elemento 10771 del .csv de los corpus
# Iterando sobre elemento 10772 del .csv de los corpus
# Iterando sobre elemento 10773 del .csv de los corpus
# Iterando sobre elemento 10774 del .csv de los corpus
# Iterando sobre elemento 10775 del .csv de los corpus
# Iterando sobre elemento 10776 del .csv de los corpus
# Iterando sobre elemento 10777 del .csv de los corpus
# Iterando sobre elemento 10778 del .csv de los corpus
# Iterando sobre elemento 10779 del .csv de los corpus
# Iterando sobre elemento 10780 del .csv de los corpus
# Iterando sobre elemento 10781 del .csv de los corpus
# Iterando sobre elemento 10782 del .csv de los corpus
# Iterando sobre elemento 10783 del .csv de los corpus
# Iterando sobre elemento 10784 del .csv de los corpus
# Iterando sobre elemento 10785 del .csv de los corpus
# Iterando sobre elemento 10786 del .csv de los corpus
# Iterando sobre elemento 10787 del .csv de los corpus
# Iterando sobre elemento 10788 del .csv de los corpus

# %%
df_corpus_sp
# Out:
#           id                                          contenido subcarpeta  \
# 0          1  BAHIA COCOA REVIEW\n  Showers continued throug...   training
# 1         10  COMPUTER TERMINAL SYSTEMS &lt;CPML> COMPLETES ...   training
# 2        100  N.Z. TRADING BANK DEPOSIT GROWTH RISES SLIGHTL...   training
# 3       1000  NATIONAL AMUSEMENTS AGAIN UPS VIACOM &lt;VIA> ...   training
# 4      10000  ROGERS &lt;ROG> SEES 1ST QTR NET UP SIGNIFICAN...   training
# ...      ...                                                ...        ...
# 10783  21571  N.Z.'S CHASE CORP MAKES OFFER FOR ENTREGROWTH\...       test
# 10784  21573  TOKYO DEALERS SEE DOLLAR POISED TO BREACH 140 ...       test
# 10785  21574  JAPAN/INDIA CONFERENCE CUTS GULF WAR RISK CHAR...       test
# 10786  21575  SOVIET INDUSTRIAL GROWTH/TRADE SLOWER IN 1987\...       test
# 10787  21576  SIX KILLED IN SOUTH AFRICAN GOLD MINE ACCIDENT...       test
#
#                                    contenido_preproc_str
# 0      bahia cocoa review shower continue week bahia ...
# 1      computer terminal system cpml completes sale c...
# 2      nz trade bank deposit growth rise slightly zea...
# 3      national amusement ups viacom bid viacom inter...
# 4      rogers rog see st qtr net significantly rogers...
# ...                                                  ...
# 10783  nz chase corp make offer entregrowth chase cor...
# 10784  tokyo dealer dollar poise breach yen tokyo for...
# 10785  japanindia conference cut gulf war risk charge...
# 10786  soviet industrial growthtrade slow soviet unio...
# 10787  kill south african gold mine accident black mi...
#
# [10788 rows x 4 columns]

# %%
df_corpus_sp.to_csv(f"{directorio_base}\data\corpus_procesado.csv", index=False)

# %% [markdown]
# ### Representación de datos en espacio vectorial:
#
# Utilización de las siguientes técnicas:
# 1. Bag Of Words (BOW)
# 2. TF-IDF
# 3. Word2Vec
#
# Vamos a aplicar estas tres técnicas de vectorización para nuestro corpus, se construirá una función para cada tipo de vectorización, la de TF-IDF y BOW devolverán el corpus vectorizado y el vectorizador usado, la de Word2Vec únicamente retornará el corpus vectorizado utilizando el modelo word2vec de google.

# %%
# Cargar el modelo preentrenado Word2Vec
word2vec_model = api.load("word2vec-google-news-300")

# ---- Bag Of Words ----
def vectorize_bow(corpus):
    """
    Vectoriza un corpus utilizando Bag of Words.
    """
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(corpus)
    return X, vectorizer

# ---- TF-IDF ----
def vectorize_tfidf(corpus):
    """
    Vectoriza un corpus utilizando TF-IDF.
    """
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(corpus)
    return X, vectorizer

# ---- Word2Vec ----
def vectorize_word2vec(corpus_tokens, w2v_model):
    """
    Vectoriza un corpus utilizando Word2Vec preentrenado.
    Cada documento se convierte en un vector promedio.
    """
    def get_avg_word2vec(tokens, w2v_model):
        valid_vectors = [w2v_model[word] for word in tokens if word in w2v_model]
        if valid_vectors:
            return np.mean(valid_vectors)
        else:
            return np.zeros(w2v_model.vector_size)

    vectors = [get_avg_word2vec(tokens, word2vec_model) for tokens in corpus_tokens]
    return np.vstack(vectors)

# %%
# Carga del archivo .csv con el corpus preprocesado y conversión de tipo de datos
df_corpus_procesado = pd.read_csv(f"{directorio_base}\data\corpus_procesado.csv")
df_corpus_procesado["id"] = df_corpus_procesado["id"].astype("string")
df_corpus_procesado["contenido"] = df_corpus_procesado["contenido"].astype("string")

# %%
# Aplicar la vectorización a todo el corpus con las diferentes técnicas
print("Vectorizando corpus a BOW")
X_bow, bow_vectorizer = vectorize_bow(df_corpus_procesado["contenido_preproc_str"])
print("Vectorizando con TF-IDF")
X_tfidf, tfidf_vectorizer = vectorize_tfidf(df_corpus_procesado["contenido_preproc_str"])
print("Vectorizando con Word2Vec")
X_word2vec = vectorize_word2vec(df_corpus_procesado["contenido_preproc_str"], word2vec_model)
# Out:
# Vectorizando corpus a BOW
# Vectorizando con TF-IDF
# Vectorizando con Word2Vec

# %% [markdown]
# ### Construcción de un índice invertido
#
# Se implementó una función de nombre construir_indice_invertido, lo que hace es iterar sobre documento, y por cada token preprocesado que se encuentra en dicho documento crea un diccionario, por cada ocurrencia de ese token en ese documento o en otro se aumenta su valor de frecuencia en una unidad, es decir, se tendría un diccionario tipo:
#
# - {Token_preprocesado01: {2203: 20, 2210: 15}}
#
# Posteriormente, se guardarán estos resultados en un archivo de texto plano con la siguiente estructura:
#
# - Término: Token_preprocesado01
#     - Documento: 2203, Frecuencia: 20
#     - Documento: 2210, Frecuencia: 15
#
# Se creará una función para cargar el índice invertido desde este archivo de texto plano a un diccionario.
#
# Nota: En el índice invertido se guardan únicamente los tokens preprocesados que tienen una longitud mayor o igual a tres, esto debido a que existen algunos con longitud dos que corresponden a abreviaciones que varían dependiendo al contexto del documento.

# %%
def construir_indice_invertido(df, directorio_base, texto_column='contenido_preproc_str', id_column='id'):
    """
    Construye un índice invertido a partir de un DataFrame con textos preprocesados.
    Solo almacena palabras con longitud >= 3 y ordena los términos por frecuencia descendente.
    
    Parámetros:
    - df (pd.DataFrame): DataFrame que contiene los textos.
    - texto_column (str): Nombre de la columna que contiene los textos preprocesados.
    - id_column (str): Nombre de la columna que contiene los IDs de los documentos.
    
    Retorno:
    - indice_invertido (dict): Diccionario donde las claves son términos y los valores son diccionarios 
      con el ID del documento y la frecuencia del término.
    """
    # Estructura del índice invertido
    indice_invertido = defaultdict(lambda: defaultdict(int))
    
    # Construir el índice invertido
    for _, row in df.iterrows():
        doc_id = row[id_column]
        texto = row[texto_column]
        for token in texto.split():
            if len(token) >= 3:  # Filtrar palabras con longitud >= 3
                indice_invertido[token][doc_id] += 1  # Incrementar frecuencia
    
    # Ordenar términos por frecuencia descendente dentro de cada documento
    for termino in indice_invertido:
        indice_invertido[termino] = dict(sorted(indice_invertido[termino].items(), 
                                                key=lambda item: item[1], reverse=True))
        
    path_guardado_ii = f"{directorio_base}\data\indice_invertido.txt"
    guardar_indice_invertido(indice_invertido, path_guardado_ii)
    
    return f"Índice invertido creado y guardado exitosamente en data\indice_invertido.txt"


def guardar_indice_invertido(indice_invertido, output_path):
    """
    Guarda el índice invertido en un archivo de texto con formato legible.
    
    Parámetros:
    - indice_invertido (dict): Índice invertido a guardar.
    - output_path (str): Ruta del archivo de salida.
    """
    with open(output_path, 'w', encoding='utf-8') as f:
        for termino, documentos in sorted(indice_invertido.items()):  # Ordenar términos alfabéticamente
            f.write(f"Término: {termino}\n")
            for doc_id, frecuencia in documentos.items():  # Ya ordenados por frecuencia descendente
                f.write(f"    Documento: {doc_id}, Frecuencia: {frecuencia}\n")
            f.write("\n")  # Línea en blanco entre términos


def cargar_indice_invertido(input_path):
    """
    Carga el índice invertido desde un archivo de texto con formato legible.

    Parámetros:
    - input_path (str): Ruta del archivo de entrada.

    Retorno:
    - indice_invertido (dict): El índice invertido cargado desde el archivo.
    """
    indice_invertido = {}

    with open(input_path, 'r', encoding='utf-8') as f:
        termino = None
        for line in f:
            line = line.strip()
            if line.startswith("Término:"):
                termino = line.split("Término:")[1].strip()
                indice_invertido[termino] = {}
            elif line.startswith("Documento:"):
                doc_info = line.split(",")
                doc_id = doc_info[0].split("Documento:")[1].strip()
                frecuencia = int(doc_info[1].split("Frecuencia:")[1].strip())
                indice_invertido[termino][doc_id] = frecuencia
            # Ignorar líneas vacías
    return indice_invertido

# %%
construir_indice_invertido(df_corpus_procesado, directorio_base)
# Out:
# 'Índice invertido creado y guardado exitosamente en data\\indice_invertido.txt'

# %%
indice_invertido = cargar_indice_invertido(f"{directorio_base}\data\indice_invertido.txt")

# %% [markdown]
# ### Funciones para búsquedas
#
# Se implementaron dos funciones de búsqueda, una que funcione para TF-IDF, BOW y WORD2VEC, utilizando distancia coseno como métrica para mostrar los resultados.
#
# La segunda función por otro lado, es especializada para relizar búsqueda dentro del índice invertido construido en el paso anterior, esta función busca una única palabra, si se le proporciona una consulta con varias palabras y al preprocesarlas queda más de un token, se utilizará la primera válida. Si la palabran no existe dentro del índice invertido, dará un mensaje de error.

# %%
def buscar_documentos(consulta, corpus_vectorizado, vectorizador, metodo="1"):
    """
    Busca documentos en el corpus y devuelve los más relevantes según el método elegido (BoW, TF-IDF, Word2Vec).
    """
    # Vectorizar la consulta
    if metodo == "1":
        consulta_vec = vectorizador.transform([consulta])
    elif metodo == "2":
        consulta_vec = vectorizador.transform([consulta])
    elif metodo == "3":
        consulta_vec = vectorize_word2vec([consulta], vectorizador)[0].reshape(1, -1)
    else:
        raise ValueError("Método no soportado")
    
    matriz = corpus_vectorizado

    # Calcular similitudes
    similitudes = cosine_similarity(consulta_vec, matriz)
    resultados = similitudes[0]
    
    # Rankear documentos por relevancia y tomar los top_n
    indices_ordenados = resultados.argsort()[::-1]
    
    return indices_ordenados, resultados

def buscar_palabra_indice_invertido(indice_invertido, df, termino, top_n=10, texto_column='contenido'):
    """
    Busca un término en el índice invertido y devuelve los 'top_n' documentos más relevantes.
    Solo muestra el contenido del documento.
    
    Parámetros:
    - indice_invertido (dict): El índice invertido construido.
    - df (pd.DataFrame): DataFrame que contiene los documentos con sus contenidos.
    - termino (str): El término a buscar en el índice invertido.
    - top_n (int): Número de resultados más relevantes a devolver.
    - texto_column (str): Columna que contiene el contenido del documento.
    
    Retorno:
    - lista_resultados (list): Lista de los documentos más relevantes con su contenido.
    """
    # Verificar si el término está en el índice invertido
    if termino in indice_invertido:
        # Obtener los documentos con el término y su frecuencia
        documentos = indice_invertido[termino]
        
        # Ordenar los documentos por frecuencia y tomar los 'top_n' más relevantes
        documentos_relevantes = sorted(documentos.items(), key=lambda item: item[1], reverse=True)[:top_n]
        #print(documentos_relevantes)
        
        # Extraer el contenido de los documentos relevantes
        lista_resultados = []
        for doc_id, _ in documentos_relevantes:
            # Obtener el contenido del documento desde el DataFrame
            contenido = df[df['id'] == doc_id][texto_column].values[0]
            lista_resultados.append([contenido, doc_id])
        
        return lista_resultados
    else:
        return []

# %% [markdown]
# ### Ejemplos de usos prácticos
#
# A continuación se muestra como debería ser el uso de todas las funciones ya implementadas anteriormente para realizar una simulación de búsqueda de una consulta dentro del corpus usando los diferentes métodos disponibles:
#
# 1. TF-IDF
# 2. BOW
# 3. Word2Vec
# 4. Índice invertido
#
# Se devolverá el contenido de los documentos con los que exista una menor distancia respecto a la consulta, para el caso del índice invertido, se devolverá los documentos en orden descendente de acuerdo a la frecuencia del término en ese documento.

# %%
# Definir el número máximo de resultados a mostrar, la consulta y preprocesar la consulta
max_resultados = 10
consulta = "problems with trading on united states of america"
consulta_preproc = preprocesar_contenido(consulta)

# %%
# ---- Paso 3.1: Ejemplo de búsqueda ifidf, bow, word2vec ----
resultados_tfidf = buscar_documentos(consulta_preproc, X_tfidf, tfidf_vectorizer, metodo="1")

# Mostrar los resultados
print("Resultados de la búsqueda (TF-IDF):")
# Realizar la busqueda y obtener resultados relevantes con search_functions
indices_ordenados, resultados = buscar_documentos(consulta_preproc, X_tfidf, tfidf_vectorizer, metodo="1")

# Preparar los resultados incluyendo índice, relevancia y texto
resultados_detallados = [
                {
                    "indice": indice,
                    "relevancia": resultados[indice],
                    "texto": df_corpus_procesado['contenido'][indice]  # Incluir el texto crudo del documento
                }
                for indice in indices_ordenados
            ]
print("")
print(f"Mostrando resultados relevantes para la búsqueda:   {consulta}")
print("")
for resultado in resultados_detallados[:max_resultados]:
    print(f"Índice: {resultado['indice']}, Relevancia: {resultado['relevancia']:.3f}")
    print(f"Texto: {resultado['texto']}\n")
# Out:
# Resultados de la búsqueda (TF-IDF):
#
# Mostrando resultados relevantes para la búsqueda:   problems with trading on united states of america
#
# Índice: 2842, Relevancia: 0.328
# Texto: YEUTTER SAYS BUDGET CUT KEY TO BETTER U.S. TRADE
#   A reduction of the U.S. federal budget
#   deficit will be needed to help eliminate the nation's huge
#   trade deficit, U.S. trade representative Clayton Yeutter said.
#       Speaking to the New York Chamber of Commerce and Industry,
#   Yeutter said "Capital and trade flows are clearly
#   inter-releated now.
#       "Unless we get the budget deficit down, we will not get the
#   trade deficit down."
#       He did not elaborate on his views of the linkages between
#   the two deficits.
#       Private analysts have said that the financing of large U.S.
#   budget deficits requires heavy capital inflows from overseas
#   investors through purchases of U.S. Treasury and, to a lesser
#   extent, other U.S. securities as well.
#       "We'll make some progress in reducing the 170 billion dlr
#   trade deficit in 1987, but there's still a long way to go,"
#   Yeutter said.
#       He said the problem must be approached on many fronts and
#   focus most strongly on U.S. and overseas fiscal and monetary
#   policies to foster economic growth, U.S. competitiveness and
#   the establishment of a "level playing field" for trade.
#       The U.S. trade representative said the Federal Reserve
#   under Chairman Paul Volcker has done its part to improve the
#   trade situation by getting interest rates down.
#       On the fiscal side, Yeutter said "the budget deficit is
#   still our biggest problem" and there has not been enough
#   progress toward reducing that deficit.
#       In the international area, he said that "our major trading
#   partners could still do more to stimulate domestic growth."
#   Commenting on Japan, which is running around a 80 billion dlr
#   trade surplus with the United States, Yeutter said "Japan is
#   just not doing the job on the import side."
#       Yeutter declined to comment on statements relating to the
#   dollar made earlier today by Commerce Dept undersecretary of
#   Economic Affairs Robert Ortner.
#       In a Washington address to an Export-Import Bank sponsored
#   meeting, Ortner said he believed the dollar at current levels
#   was fairly priced against most European currencies, but that
#   the yen is 10 or 15 pct undervalued.
#       "The market will determine the dollar's proper value in the
#   end," Yeutter said. However, he added that, if the U.S. and
#   other nations do not take the necessary steps to cut the U.S.
#   trade deficit, "the dollar will be the equalizer."
#       Yeutter said there is no quick fix to the trade problem and
#   any resort to such tactics as protectionist trade legislation
#   or trade restrictions poses real dangers.
#       He said "there's relatively little that Congress can do to
#   legislate a solution to the trade problem."
#       Protectionist legislation will only provoke retaliation by
#   U.S. trading partners, Yeutter said.
#       "There is no doubt in my mind about the willingness of our
#   trading partners to retaliate against unfair trade
#   legislation," Yeutter said, adding that policy flexibility is
#   essential in solving international trade problems.
#
#
#
#
# Índice: 8467, Relevancia: 0.303
# Texto: JAPAN WARNS U.S. IT MAY RETALIATE IN TRADE DISPUTE
#   Japan warned the United States it may
#   take retaliatory measures if the United States imposes its
#   planned trade sanctions on April 17, a senior government
#   official said.
#       Shinji Fukukawa, Vice Minister of the International Trade
#   and Industry Ministry, said in a statement Japan would consider
#   measures under the General Agreement on Tariffs and Trade and
#   other actions if the United States imposes 100 pct tariffs on
#   some Japanese exports as planned next week.
#       However, Fukukawa said Japan was ready to continue trade
#   talks with the United States despite its failure to convince
#   America to call off the threatened tariffs during two days of
#   emergency talks which ended in Washington yesterday.
#       Last month President Reagan announced the sanctions in
#   retaliation for what he called Japan's failure to honour a July
#   1986 agreement to stop dumping computer microchips in markets
#   outside the United States and to open its home market to
#   American goods.
#       Fukukawa said the United States had regrettably not
#   listened to Japan's explanation of its efforts to live up the
#   pact and said Washington had not given any detailed explanation
#   of why it planned to impose the tariffs.
#
#
#
#
# Índice: 1601, Relevancia: 0.288
# Texto: JAPAN/U.S. WILL BE AT ODDS WHILE TRADE LOPSIDED
#   Japan is doing all it can to solve its
#   trade problems with the United States but the two nations will
#   remain at odds as long as the trade account is lopsided in
#   Japan's favour, a senior official said.
#       "So long as there is an external imbalance there will be
#   trade friction and ...Harsh words between the two governments,"
#   the Foreign Ministry official told reporters.
#       Last year, Japan racked up a 51.5 billion dlr surplus with
#   the United States and economists said they do not see it
#   falling significantly any time soon.
#       Washington announced plans last week to slap up to 300 mln
#   dlrs in tariffs on Japanese electronic goods, raising the
#   spectre of a trade war between the two countries.
#       "We take the current situation very seriously," said the
#   official, who declined to be identified. "The basic stance of
#   the Japanese government is to tackle the issues with all
#   available resources."
#       The United States has accused Japan of reneging on an
#   agreement that called on it to stop selling cut-price computer
#   microchips in world markets and to try to import more American
#   semiconductors. Tokyo has denied the charges.
#       The Foreign Ministry official refused to rule out Japanese
#   retaliation if America went ahead with its threatened tariffs
#   in the middle of this month. But he said that any response
#   would be in accordance with international law and Japan's
#   international obligations.
#       He added that both Japan and the United States must take
#   account of the impact of their dispute on their own and the
#   world economy.
#
#
#
#
# Índice: 1616, Relevancia: 0.288
# Texto: JAPAN/U.S. WILL BE AT ODDS WHILE TRADE LOPSIDED
#   Japan is doing all it can to solve its
#   trade problems with the United States but the two nations will
#   remain at odds as long as the trade account is lopsided in
#   Japan's favour, a senior official said.
#       "So long as there is an external imbalance there will be
#   trade friction and ...Harsh words between the two governments,"
#   the Foreign Ministry official told reporters.
#       Last year, Japan racked up a 51.5 billion dlr surplus with
#   the United States and economists said they do not see it
#   falling significantly any time soon.
#       Washington announced plans last week to slap up to 300 mln
#   dlrs in tariffs on Japanese electronic goods, raising the
#   spectre of a trade war between the two countries.
#       "We take the current situation very seriously," said the
#   official, who declined to be identified. "The basic stance of
#   the Japanese government is to tackle the issues with all
#   available resources."
#       The United States has accused Japan of reneging on an
#   agreement that called on it to stop selling cut-price computer
#   microchips in world markets and to try to import more American
#   semiconductors. Tokyo has denied the charges.
#       The Foreign Ministry official refused to rule out Japanese
#   retaliation if America went ahead with its threatened tariffs
#   in the middle of this month. But he said that any response
#   would be in accordance with international law and Japan's
#   international obligations.
#       He added that both Japan and the United States must take
#   account of the impact of their dispute on their own and the
#   world economy.
#
#
#
#
# Índice: 762, Relevancia: 0.266
# Texto:  EUROPE ON SIDELINES IN U.S-JAPAN MICROCHIP ROW
#   Rising imports of Japanese-made cars and
#   electronic goods may upset West European officials, but they
#   generally seem prepared to stay on the sidelines in the latest
#   trade row between the United States and Japan.
#       Japan's huge trade surplus is a sore point in West Europe,
#   as it is in the United States. But U.S. Charges of unfair trade
#   practices involving computer microchips leave Europeans cold.
#       The European Community ran a 18.2 billion dlr trade deficit
#   with Japan last year, and seeks redress when it feels Japanese
#   trade policy hurts Europeans, diplomats and economists said.
#       But only in Britain has there been any suggestion of acting
#   with the U.S. To do something about Japan's huge trade surplus.
#       "The EC is no more illiberal on trade issues than is the
#   U.S.," said Martin Wolf, director of studies at the Trade Policy
#   Research Centre in London. "Basically, their policies are pretty
#   much the same."
#       But that did not mean Europe would support the U.S., Or
#   that the EC would climb on the bandwagon to take advantage of
#   the U.S. Dispute to press its own claims, Wolf said.Basically,
#   Europeans have a different approach to trade problems, he said.
#       "In the U.S., People talk about fair trade, but not here," he
#   added. "In the U.S., It all has to do with the general ethic of
#   free competition, while in Europe, the general approach is that
#   liberal trade is good because it makes countries rich."
#       Wolf said this basic U.S. Attitude explains Washington's
#   tendency to impose so-called "countervailing duties" - an import
#   tax designed to offset advantages alleged to be unfair.
#       In Western Europe, the approach to trade disputes tends to
#   be to try to reach a settlement through negotiation, Wolf said.
#       In the latest U.S.-Japan trade row, President Reagan has
#   threatened to raise tariffs on selected Japanese electronic
#   goods by as much as 300 mln dlrs, alleging that Japan has
#   failed to abide by a 1986 U.S.-Japan pact on microchip trade.
#       But the European Community has challenged the agreement as
#   a violation of General Agreement on Tariffs and Trade (GATT)
#   practices that discriminates against its microchip producers.
#       "It follows that they're not likely to rally to the side of
#   the United States in defence of the agreement," said Wolf.
#       Although British parliamentarians are pushing for a tough
#   line on Japanese trade issues, government officials in the rest
#   of Europe told Reuter correspondents they would let the EC take
#   the lead in any response to the U.S.-Japan trade row.
#       A spokeswoman for the EC Commission in Brussels told
#   Reuters there has been no change in the Community's position
#   since a March 16 meeting of foreign ministers which sent a
#   strong warning to Tokyo on trade imbalances.
#       In a statement issued after that meeting, EC foreign
#   ministers deplored Japan's continued trade imbalance and
#   appealed for a greater Japanese effort to open up its markets.
#       EC External Trade Commissioner Willy De Clercq said after
#   the talks there was a growing impatience with Japan in the EC.
#       Diplomats accredited to the EC in Brussels said they saw no
#   signs of any immediate intention to impose any broad-ranging
#   sanctions against Japan. The EC is anxious to avoid provoking a
#   trade war, they said.
#       Instead, the Community is trying to target problem areas in
#   European trade with Japan, including wines and spirits,
#   cosmetics, and financial services, and will continue talking to
#   try to improve the situation, the diplomats said.
#       In Britain, where the government is angered over the
#   difficulties telecommunications giant Cable and Wireless has
#   faced in its bid to crack the Japanese market, officials said
#   last week that retaliatory action is being considered.
#       But government officials said last night, "We are not
#   talking about days or weeks. This is going to take time."
#       They said the government would consider its options at a
#   cabinet meeting on Thursday, but added that no final decisions
#   were expected. The main thing the British would threaten the
#   Japan with is denial of access to London's booming financial
#   markets, government officials said.
#
#
#
#
# Índice: 2531, Relevancia: 0.263
# Texto: BRITISH AIDE CRITICIZES U.S.PROTECTIONISM
#   A senior British official said that
#   protectionist bills being considered by Congress could trigger
#   retaliation by the European Community (EEC) and threaten the
#   global trading system.
#       Paul Channon, secretary for trade and industry, said if
#   Congress passed legislation to curb textile imports, which
#   would hit EC shipments as well as shipments from major Asian
#   textile producers, "the community would have to retaliate."
#       His comments echoed those made yesterday by Belgian Trade
#   Minister Herman De Croo, who said if the bill passed, the
#   community would retaliate by imposing taxes on U.S. exports.
#       Channon made his remarks at a news conference after two
#   days of talks with Reagan Administration officials and members
#   of Congress.
#       De Croo was also in Washington for trade talks.
#       Channon said there was a greater protectionism sentiment in
#   Congress since his visit here last year as Congress and the
#   Administration tried to find ways to reduce the U.S. trade
#   deficit, which last year hit a record 169.8 billion dlrs.
#       Channon also called for greater EC-U.S. cooperation to
#   force Japan to open its markets to foreign goods.
#       Channon said Japan's trade surplus is causing everyone
#   problems - its surplus with the United States last year was
#   51.5 billion dlrs and with EC nations, 16.7 billion dlrs.
#       "The more united pressure there could be, the better," he
#   said.
#       Channon also called for increased U.S.-EC cooperation to
#   avoid trade disputes.
#       He said the two sides narrowly avoided a confrontation
#   earlier this year over lost grains sales when Spain and
#   Portugal joined the community and its liberal imports
#   regulations were tightened to conform to EC standards.
#       "But if both sides drew back from the brink that time," he
#   said, ""it does not mean that they would do so on another
#   occasion."
#       Channon added that "There is increasing reesentment in
#   Europe over the U.S. tactic of negotiating under the pressure
#   of unilaterally imposed deadlines."
#       He said other potential conflicts are already in sight -
#   alleged European government subsidies of Airbus aircraft and
#   taxes on fats and oils - and "the commuity and the United States
#   must therefore learn to manage their relations better."
#       He said another bill to let the United States retaliate
#   against a nation if that nation's market was not open to U.S.
#   goods would bypass the trade pact GATT (General Agreeeement on
#   Tariffs and Trade) as an arbiter of trade practices.
#       He said foreign trade law should be judged by GATT and not
#   by the United States, adding "if the (trade) law is to be
#   interpreted by the United States and not by the GATT, what is
#   to happen to the rest of us?"
#
#
#
#
# Índice: 7343, Relevancia: 0.255
# Texto: KEY U.S. HOUSE PANEL FINISHES MAJOR TRADE BILL
#   The House Ways and Means Committee
#   completed action on legislation to toughen U.S. trade laws,
#   chairman Dan Rostenkowski said.
#       The committee's consideration of one of the most
#   controversial provisions, a plan to force major trade surplus
#   countries to cut their trade imbalance with the United States,
#   was deferred until the full House considers the trade bill, its
#   sponsor Rep. Richard Gephardt said.
#       Gephardt, a Missouri Democrat, told Reuters he was not
#   certain the exact form his trade surplus reduction proposal
#   would take. Last year the House approved his plan to force a 10
#   pct surplus cutback each year for four years, by countries such
#   as Japan.
#       The Ways and Means Committess' trade bill forces President
#   Reagan to retaliate against unfair trade practices that violate
#   international trade agreements but it allows him to wave
#   retaliatory tariffs or quotas if the action would hurt the U.S.
#   economy.
#       The trade bill gives U.S. Trade Representative Clayton
#   Yeutter more authority in trade negotiations and in decisions
#   to grant domestic industries import relief.
#       It also gives him authority to decide whether foreign trade
#   practices are unfair and violate U.S. trading rights. These
#   powers are currently held by President Reagan.
#       The administration has strongly objected to this transfer
#   of authority from Reagan to Yeutter.
#       The bill also extends U.S. authority to negotiate
#   multilateral trade agreements. The bill will be wrapped into
#   other trade legislation and voted on in the House in April.
#
#
#
#
# Índice: 5651, Relevancia: 0.247
# Texto: EC WARNS CONGRESS ON NEW TRADE BILL
#   The European Community (EC) has
#   warned the U.S. House of Representatives that tough trade
#   legislation it is considering could prompt retaliation by U.S.
#   trading partners.
#       The warning was sent in a letter from Sir Roy Denman, head
#   of the EC delegation in Washington, to Dan Rostenkowski,
#   chairman of the House Ways and Means Committee.
#       A copy of the letter was made available to Reuters.
#       Denman told Rostenkowski, an Illinois Democrat, he backed
#   aspects of the bill, such as one backing new talks under the
#   GATT and one excluding protection for the textile industry.
#       But Denman disagreed with other provisions which would
#   require President Reagan to take retaliatory trade action
#   against nations with large trade surpluses with the U.S. and
#   would set new standards for judging unfair foreign trade
#   practices.
#       Denman told Rostenkowski that GATT regulations prohibit
#   member nations from taking unilateral retaliatory action in
#   trade disputes unless the action is GATT-approved.
#       He said "If the Congress makes retaliatory action mandatory,
#   then the United States would be in violation of its
#   international legal obligations and on a collision course with
#   its major trading partners."
#       Denman added that a president should have flexibility in
#   enforcing trade laws, saying "in the last resort, any
#   administration must take its decision in light of the overall
#   national interest."
#       Otherwise, he said, "the risk would be counter-reaction by
#   trading partners of the United States, i.e., retaliation or
#   enactment of mirror image legislation to be employed against
#   imports from the United States."
#       Denman also said Congress could prompt retaliation if it
#   reduced the threshhold of unfair trade by making it easier for
#   firms to file unfair trade practice claims.
#       Retaliation could also be prompted by relaxing standards
#   for findings that imports were injuring U.S. firms.
#       "Changes in these standards must be agreed upon
#   multilaterally. They cannot be imposed by the United States
#   alone on the world trading system," he said.
#       House leaders have rejected a plan by textile-state
#   legislators to add to the trade bill a provision to curb
#   imports of cloth and clothing, similar to a measure passed two
#   years ago but vetoed by President Reagan.
#       There was concern by the leaders that Reagan would veto the
#   entire trade bill because of the textile amendment.
#
#
#
#
# Índice: 2325, Relevancia: 0.244
# Texto: CANADIANS URGE EXEMPTION FROM U.S. TRADE BILL
#   A group of Canadian lawmakers from
#   Ontario today asked their U.S. counterparts to exempt Canada
#   from the mandatory trade retaliation provisions in a major
#   trade bill being considered by the U.S. Congress.
#       At a meeting of the Northeast-Midwest Coalition, an
#   organization of U.S. legislators, David Cooke, chairman of the
#   Ontario Parliament's Select Committee on Economic Affairs, said
#   the exemption would help trade relations.
#       The trade legislation to be considered by the full House in
#   late April would require President Reagan to retaliate against
#   foreign unfair trade practices unless the trade actions would
#   harm the U.S. economy.
#       Currently, Reagan can reject trade sanctions on any
#   grounds.
#       Cooke, a member of the Liberal party, told the U.S.
#   congressmen, "I can understand (the trade bill). I think it has
#   to do with concerns you have with the other parts of the world."
#       "I would suggest to you that we are your best friends. You
#   do not have those concerns with Canada and you should sincerely
#   consider exempting our country from that bill," he added.
#       Canada is the United States' largest trading partner, with
#   two-way trade more than 113 billion dlrs in 1985, according to
#   the coalition. But the U.S. ran up a 23 billion dlr deficit in
#   manufactured goods that year compared to a 14 billion dlr
#   surplus in services trade with its neighbour.
#
#
#
#
# Índice: 3547, Relevancia: 0.237
# Texto: SOVIET ECONOMIST SEES FEW 1987 GAINS IN U.S. TRADE
#   There is little chance Soviet exports
#   to the United States will rise in 1987, but Moscow's current
#   trade reforms should result in more trade in manufactured goods
#   in future, a Soviet economist said.
#       Sergey Frolov, chief economist at Amtorg Trading Corp, an
#   agent for Soviet trade organisations and industries, told a
#   U.S.-USSR business meeting the Soviet Union produces few items
#   that western nations want.
#       But reforms, including upgrading the quality of goods and
#   allowing joint ventures with foreign firms, will encourage
#   modest export gains in future.
#       Frolov said the Soviet Union exported 500 mln dlrs worth of
#   goods to the United States in 1986 and imported 1.5 billion
#   dlrs worth. He gave no trade forecast for 1987.
#       But he said that even if all obstacles were removed, total
#   trade between the two countries would remain between two and
#   three billion dlrs a year.
#       "The post-detente embargoes have taught the USSR to limit
#   its trading with the U.S.," he said.

# %%
# ---- Paso 3.1: Ejemplo de búsqueda índice invertido ----

if len(consulta_preproc.split()) == 1:
    resultados = buscar_palabra_indice_invertido(indice_invertido, df_corpus_procesado, consulta_preproc, top_n=max_resultados)
elif len(consulta_preproc.split()) > 1:
    print("Búsqueda por índice invertido ha detectado más de una palabra, usando la primera válida...\n\n")
    resultados = buscar_palabra_indice_invertido(indice_invertido, df_corpus_procesado, consulta_preproc.split()[0], top_n=max_resultados)
else:
    print("La palabra es una stop-word o no se encuentra en el índice invertido...")
    pass

# Mostrar los resultados
for contenido, doc_id in resultados:
    print(f"Documento con ID: {doc_id}:\n{contenido}\n")
# Out:
# Búsqueda por índice invertido ha detectado más de una palabra, usando la primera válida...
#
#
# Documento con ID: 144:
# OPEC MAY HAVE TO MEET TO FIRM PRICES - ANALYSTS
#   OPEC may be forced to meet before a
#   scheduled June session to readdress its production cutting
#   agreement if the organization wants to halt the current slide
#   in oil prices, oil industry analysts said.
#       "The movement to higher oil prices was never to be as easy
#   as OPEC thought. They may need an emergency meeting to sort out
#   the problems," said Daniel Yergin, director of Cambridge Energy
#   Research Associates, CERA.
#       Analysts and oil industry sources said the problem OPEC
#   faces is excess oil supply in world oil markets.
#       "OPEC's problem is not a price problem but a production
#   issue and must be addressed in that way," said Paul Mlotok, oil
#   analyst with Salomon Brothers Inc.
#       He said the market's earlier optimism about OPEC and its
#   ability to keep production under control have given way to a
#   pessimistic outlook that the organization must address soon if
#   it wishes to regain the initiative in oil prices.
#       But some other analysts were uncertain that even an
#   emergency meeting would address the problem of OPEC production
#   above the 15.8 mln bpd quota set last December.
#       "OPEC has to learn that in a buyers market you cannot have
#   deemed quotas, fixed prices and set differentials," said the
#   regional manager for one of the major oil companies who spoke
#   on condition that he not be named. "The market is now trying to
#   teach them that lesson again," he added.
#       David T. Mizrahi, editor of Mideast reports, expects OPEC
#   to meet before June, although not immediately. However, he is
#   not optimistic that OPEC can address its principal problems.
#       "They will not meet now as they try to take advantage of the
#   winter demand to sell their oil, but in late March and April
#   when demand slackens," Mizrahi said.
#       But Mizrahi said that OPEC is unlikely to do anything more
#   than reiterate its agreement to keep output at 15.8 mln bpd."
#       Analysts said that the next two months will be critical for
#   OPEC's ability to hold together prices and output.
#       "OPEC must hold to its pact for the next six to eight weeks
#   since buyers will come back into the market then," said Dillard
#   Spriggs of Petroleum Analysis Ltd in New York.
#       But Bijan Moussavar-Rahmani of Harvard University's Energy
#   and Environment Policy Center said that the demand for OPEC oil
#   has been rising through the first quarter and this may have
#   prompted excesses in its production.
#       "Demand for their (OPEC) oil is clearly above 15.8 mln bpd
#   and is probably closer to 17 mln bpd or higher now so what we
#   are seeing characterized as cheating is OPEC meeting this
#   demand through current production," he told Reuters in a
#   telephone interview.
#
#
#
#
# Documento con ID: 2352:
# YEUTTER SAYS BUDGET CUT KEY TO BETTER U.S. TRADE
#   A reduction of the U.S. federal budget
#   deficit will be needed to help eliminate the nation's huge
#   trade deficit, U.S. trade representative Clayton Yeutter said.
#       Speaking to the New York Chamber of Commerce and Industry,
#   Yeutter said "Capital and trade flows are clearly
#   inter-releated now.
#       "Unless we get the budget deficit down, we will not get the
#   trade deficit down."
#       He did not elaborate on his views of the linkages between
#   the two deficits.
#       Private analysts have said that the financing of large U.S.
#   budget deficits requires heavy capital inflows from overseas
#   investors through purchases of U.S. Treasury and, to a lesser
#   extent, other U.S. securities as well.
#       "We'll make some progress in reducing the 170 billion dlr
#   trade deficit in 1987, but there's still a long way to go,"
#   Yeutter said.
#       He said the problem must be approached on many fronts and
#   focus most strongly on U.S. and overseas fiscal and monetary
#   policies to foster economic growth, U.S. competitiveness and
#   the establishment of a "level playing field" for trade.
#       The U.S. trade representative said the Federal Reserve
#   under Chairman Paul Volcker has done its part to improve the
#   trade situation by getting interest rates down.
#       On the fiscal side, Yeutter said "the budget deficit is
#   still our biggest problem" and there has not been enough
#   progress toward reducing that deficit.
#       In the international area, he said that "our major trading
#   partners could still do more to stimulate domestic growth."
#   Commenting on Japan, which is running around a 80 billion dlr
#   trade surplus with the United States, Yeutter said "Japan is
#   just not doing the job on the import side."
#       Yeutter declined to comment on statements relating to the
#   dollar made earlier today by Commerce Dept undersecretary of
#   Economic Affairs Robert Ortner.
#       In a Washington address to an Export-Import Bank sponsored
#   meeting, Ortner said he believed the dollar at current levels
#   was fairly priced against most European currencies, but that
#   the yen is 10 or 15 pct undervalued.
#       "The market will determine the dollar's proper value in the
#   end," Yeutter said. However, he added that, if the U.S. and
#   other nations do not take the necessary steps to cut the U.S.
#   trade deficit, "the dollar will be the equalizer."
#       Yeutter said there is no quick fix to the trade problem and
#   any resort to such tactics as protectionist trade legislation
#   or trade restrictions poses real dangers.
#       He said "there's relatively little that Congress can do to
#   legislate a solution to the trade problem."
#       Protectionist legislation will only provoke retaliation by
#   U.S. trading partners, Yeutter said.
#       "There is no doubt in my mind about the willingness of our
#   trading partners to retaliate against unfair trade
#   legislation," Yeutter said, adding that policy flexibility is
#   essential in solving international trade problems.
#
#
#
#
# Documento con ID: 15106:
# BRAZIL GRAIN HARVEST FACES STORAGE PROBLEMS
#   Storage problems with Brazil's record
#   grain crop are likely to result in losses of about five mln
#   tonnes, an Agriculture Ministry spokesman said.
#       Ministry spokesman Leonardo Brito, speaking from Brasilia,
#   told Reuters he believed that about five mln tonnes of this
#   year's estimated crop of 65 mln tonnes would be lost.
#       He said part of this would be the normal loss inevitable in
#   harvesting, but that most of it would stem from storage
#   problems.
#       Brazil has a storage capacity of 66 mln tonnes,
#   theoretically sufficient for the crop.
#       But Brito said that the storage capacity was badly
#   distributed. The states of Sao Paulo, Parana and Rio Grande do
#   Sul had between them 70 pct of the nation's capacity, but were
#   responsible for only 50 to 60 pct of production.
#       The biggest problems are concentrated in the Centre-West
#   growing regions, where rising production has outpaced storage
#   capacity.
#       Brito said the Centre-West, whose crops include soya and
#   maize, had between 30 and 40 pct of the nation's grains
#   production but only 20 pct of its storage space.
#       In addition to the poor distribution of storage units,
#   there is the problem that too much of the capacity is geared to
#   storing grain in sacks, while not enough is suitable for
#   storing loose grain, Brito said.
#       Finally, there is a shortage of lorries to transport the
#   crops.
#       The sheer scale of the task in transporting the record crop
#   has been evident from television reports, which have shown
#   enormous queues of lorries waiting outside granaries.
#
#
#
#
# Documento con ID: 15364:
# BUNDESBANK CALLS FOR CENTRAL BANK COOPERATION
#   Bundesbank board member Claus Koehler
#   called on central banks of major industrialised nations to
#   cooperate closely on exchange and interest rate policies.
#       In a lecture at the University of Surrey, pre-released
#   here, Koehler said that the only alternative to cooperation was
#   protectionism and control on capital movements.
#       "Central banks have sufficient experience of exchange market
#   transactions to steer exchange rates where they want to have
#   them," he said. He added that West German growth forecasts would
#   have to be revised downward because of the recent dollar drop
#   to 1.80 marks from above two marks at the start of 1987.
#       Koehler said that transactions on foreign exchange markets
#   had parted company with transactions in goods, services and
#   investments. It was the scale of speculative transactions that
#   determined market trends.
#       Speculative inflows could cause monetary aggregates to
#   grow. To reverse such a rise in the money stock, interest rates
#   would have to be lowered to allow funds to drain off.
#       "In other words, the monetary policy measures required are
#   different from -- and sometimes diametrically opposed to --
#   those needed when the money stock is increasing as a result of
#   mounting economic activity," Koehler said.
#       The dollar fall was one means of reducing the massive U.S.
#   Current account deficit. But attempts to keep the depreciation
#   going by talking the dollar down posed problems.
#       The sharp drop of the dollar had led to an immediate steep
#   rise in the cost of U.S. Imports and a sharp fall in the cost
#   of European imports. But the volume effect of falling imports
#   to the U.S. And rising imports to Europe would take time to
#   make itself felt compared with the price effect.
#       "Hence the depreciation of the dollar may well be going
#   further than would be necessary to adjust the current account
#   over the medium term," Koehler said.
#       A reduction in the U.S. Current account deficit would occur
#   only if the growth rate of GNP was higher than domestic demand.
#   In Japan and West Germany by contrast, domestic demand should
#   rise faster than GNP.
#       "In Germany this did indeed happen in 1986," Koehler said.
#       If a further appreciation of the dollar was to be
#   prevented, the U.S. Current account deficit could be offset by
#   an inflow of foreign funds into the U.S..
#       But only if there was an appropriate interest rate
#   differential would Europe and Japan look for financial
#   investment in the U.S.
#       When selecting monetary policy instruments, a central bank
#   had to pay greater heed than in the past to the impact its
#   measures might have on expectations and consequent decisions.
#       Koehler said the Bundesbank was changing money market rates
#   by operating on the open market rather than adjusting leading
#   interest rates because of the signal this gives to the market
#   and its substantial impact on exchange rates.
#       It was not only important to achieve the domestic goals of
#   price stability, economic growth and full employment but also
#   to tackle international problems like the exchange rate
#   problem, the debt problem and the current account problem.
#       A strategy had to be designed that helped "the safeguarding
#   of non-inflationary economic growth in an international
#   monetary system largely free of disruptions," Koehler said.
#       Given the system of floating exchange rates, it was
#   necessary for central banks to agree to intervene. It sufficed
#   to tell the market where central banks saw exchange rates over
#   the next few years and intervention points should not be set,
#   because they were only testing points for the market, he said.
#       In order to keep the international monetary system free of
#   disruptions central banks should not only intervene jointly but
#   also cooperate on interest rate policies, Koehler said.
#
#
#
#
# Documento con ID: 11768:
# ECONOMIC SPOTLIGHT - CHINA MUST PRESERVE FARMLAND
#   "If we go on using up
#   farmland as we have done since 1980, there will be none left in
#   20 years to grow grain on."
#       Xu Jinfeng, a middle-aged official in Fengbang village on
#   the edge of Shanghai, sums up the dilemma China faces as it
#   tries to feed its more than one billion people and at the same
#   time let them get richer by building factories and new homes.
#       China has to feed one quarter of the world's population,
#   but only one seventh of its land is arable.
#       Sharp increases in farm output since 1979 turned China into
#   a net grain exporter for the first time in 1985, and again in
#   1986.
#       But the rapid industrialisation of the countryside which
#   has occurred at the same time, has gobbled up arable land for
#   factories and homes for peasants who can now afford them.
#       Official figures show that China lost just under one pct of
#   its arable land to other uses in 1985 and a slightly smaller
#   amount last year. It gained 26 mln new mouths to feed during
#   the two years.
#       "We lost very little land prior to 1980 when the
#   industrialisation began," official Xu said. "Since then, nearly
#   all the families in the county have built new homes and many
#   factories have gone up."
#       "Last year we lost land to a new railway line," Xu said. But
#   land losses in future should fall because nearly all families
#   already have new houses, she added.
#       The issue of land loss is a matter of major concern to the
#   Peking leadership, which announced earlier this month that
#   China will issue nationwide quotas for conversion of grain land
#   for the first time this year.
#       "The present situation of abusing, occupying unlawfully,
#   wasting and destroying land and land resources is serious," said
#   an article in the official press explaining the new measures.
#       "It has resulted in great losses of cultivated farmland," it
#   said. "China has a large population and its land resources are
#   badly deficient."
#       An official of the Shanghai city government said county
#   authorities could approve conversion of only 0.3 hectares of
#   arable land to other uses, while anything more than that must
#   be approved by the city government.
#      The Peking government faces another major obstacle in its
#   efforts to ensure China's people get enough grain to eat. The
#   prices the state pays to farmers for grain are too low, making
#   it more profitable for them to grow other crops.
#       To offset this, the state offers farmers cheap fertiliser
#   and diesel oil and payment in advance for grain it contracts to
#   buy. The state then sells the grain at subsidised prices to
#   China's 200 mln city residents. Rural factories also subsidise
#   grain output, paying farmers bonuses to grow it.
#       Some officials argue that the simplest solution to the
#   problem would be for the state to raise city grain prices.
#       Chen Zuyuan, Communist Party secretary of a village in the
#   eastern province of Zhejiang, said the government listened too
#   much to the demands of "selfish city people" and could raise city
#   grain prices without any problem.
#       But the government has ruled out a price rise. "Raising the
#   price of grain would directly conflict with the goal of social
#   stability," said a China Daily editorial this month.
#       The Shanghai official said prices must be reformed over the
#   long term. "We must be very careful. We have a very large
#   population which is used to price stability and will object to
#   price rises," he said. "The problem is how to do it."
#       The Shanghai official said a rise in grain prices might
#   also affect the prices of hundreds of food products made with
#   grain and consumed by city residents.
#       In addition, the state faces the problem of inadequate
#   investment by farmers in land and in grain in particular.
#       The official press has reported that farmers fear farm
#   policy may change and they are putting their new wealth into
#   building graves, memorial halls for ancestors and homes.
#       Under reforms introduced in the late 1970s, farmers sign
#   contracts with the state requiring them to grow certain crops,
#   but they have considerable freedom in how to use their land.
#       "As the expiration date of the 15-year contract is almost at
#   the halfway mark, farmers are beginning to worry about the
#   future," the China Daily said in an editorial last month.
#       Their anxieties stem from the fact that they are allowed to
#   use the land but not own it. For most of the period of
#   Communist rule, the land was organised into collectives where
#   there was little room for individual initiative.
#       "New measures are needed to reassure them of the consistency
#   of government policies and make them interested in long-term
#   investment," the newspaper said.
#
#
#
#
# Documento con ID: 11773:
# COMMERZBANK SEES LOWER OPERATING PROFIT THIS YEAR
#   Commerzbank AG &lt;CBKG.F> management
#   board chairman Walter Seipp said that from the present
#   viewpoint the bank must expect 1987 full operating profit to be
#   lower than in 1986.
#       In the first two months of the year, partial operating
#   profit -- excluding trading on the bank's own account -
#   declined, he said, without giving details.
#       The interest surplus fell 2.8 pct compared with 2/12ths of
#   1986 results, while the commission surplus, because of the
#   quiet stock exchange business, fell back still more strongly.
#   By contrast the personnel and fixed asset expenses increased.
#       German banks do not report full operating profit. But Seipp
#   said last year the figure for the first time had topped one
#   billion marks for the parent bank, and the group result was
#   around 50 pct higher than this.
#       Commenting on 1986, Seipp said, "we were able to raise the
#   full operating profit...Slightly above the record result of
#   1985 because own account profits increased slightly."
#       He gave no concrete details but added that in January and
#   February, good own account trading profits meant that the drop
#   in full operating earnings was more modest than that in the
#   partial operating figure.
#       The bank would, as a result, be more profit-oriented in
#   future, developing, for example, more into investment banking,
#   keeping a tight rein on personnel costs and dampening
#   expenditures on fixed assets.
#       Turning to 1986 results, Seipp said by year end there had
#   been a strong growth in business volume.
#       Over the year business volume rose by 9.9 pct to 93.2
#   billion marks compared with 1985, Seipp added.
#       Group balance sheet volume rose by 8.0 pct to 148.15
#   billion. It would have been around five billion marks higher
#   still if currency relationships had remained unchanged.
#       In the parent bank, the interest surplus rose nine pct in
#   the year, while the interest margin held roughly at 1985's 2.56
#   pct despite pressure on credit rates.
#       The surplus on commission business, which had soared by a
#   quarter in 1985, rose by 11.6 pct last year thanks almost
#   exclusively to growth in securities commissions, Seipp said.
#       Personnel expenditure was up 11.9 pct last year, at more
#   than 1.5 billion marks. Fixed asset expenditure rose by 9.6 pct
#   to more than 650 mln.
#       As a result, the parent bank partial operating profit rose
#   by 3.2 pct to 752 mln marks.
#       Parent bank tax payment rose to 244 mln marks last year
#   from 233 mln in 1985.
#       Seipp said extraordinary earnings included a "high
#   two-figure million" in profit from the sale of the bank's AEG AG
#   &lt;AEGG.F> shares to Daimler-Benz AG &lt;DAIG.F> during the latter's
#   majority stake purchase booked last year.
#       The ability of the bank to write off depreciations in
#   credit business against profits from securities trading and
#   earnings on the sale of stakes had been utilised, as in prior
#   years, to its full extent.
#       Because of numerous insolvencies at home, by far the
#   largest part of the provisions were set aside for individual
#   write-downs from domestic business. Abroad, the circle of
#   problem debtor countries rose last year, although the ratio of
#   credit exposure to provisions improved further.
#       Seipp said that because about half the group's exposure to
#   problem nations was in dollars, the bank had swapped into
#   dollars individual provisions hitherto held primarily in marks.
#       "This means that no open currency positions exist any longer
#   on the amount of the provision that is made against an actual
#   default," he added.
#       Despite the increase in concern over debtor nations in the
#   last few weeks, he said, the international banking community is
#   better armed than it was against payment problems.
#       All banks had significantly strengthened their capital
#   base, most European banks had made considerable provisions
#   against bad debts while goverments and central banks were
#   better prepared for unforseen difficulties.
#       He described debt-equity swaps as a very interesting new
#   approach to indebted nations' problems. There was a lot of
#   interest in direct investment via an equity participation in
#   Latin America, particularly from West German firms.
#
#
#
#
# Documento con ID: 12848:
# IMF, WORLD BANK TO MEET AMID NEW INFLATION FEARS
#   Amid new concerns about inflation,
#   interest rate increases and trade confrontations,
#   finance ministers and central bankers meet next week to discuss
#   a deteriorating global debt and economic situation.
#       The meetings, under the auspices of the International
#   Monetary Fund and World Bank, come as interest rates are
#   turning higher and the already-weak dollar has sunk further,
#   upsetting bond and stock markets.
#       Uncertainty is growing about the vitality of the global
#   economy and whether the heavily-indebted countries can continue
#   to carry the burden of their growing debt without vast new
#   assistance.
#       Monetary and diplomatic sources said there are no signs
#   any new debt initiative of the sort that Treasury Secretary
#   James Baker unveiled 18 months ago in Seoul is in the works.
#       The strategy has drawn a serious challenge from Brazil,
#   which suspended interest payments on 67 billion dlrs of
#   commercial bank debt last month. The Banks have responded by
#   laying the groundwork for writing down Brazilian loans.
#       Separately, French Prime Minister Jacques Chirac, in a
#   visit earlier this week with President Reagan, sounded out the
#   administration on a plan to funnel worldwide grain surpluses to
#   the very poorest states.
#       The French plan is certain to be discussed by the ministers
#   in detail during next week's meetings and will undoubtedly be
#   embraced by the developing countries.
#       "There's interest on the part of some countries for looking
#   at the support of the special problems of the very poorest
#   countries, because their position is so extreme," a Reagan
#   administration official said.
#       He suggested Washington was open to disussing the issue.
#       The meetings will also assess the success of the Baker debt
#   initiative, which called for new funding to help debtor
#   countries grow out of their problems.
#       The largest industrial countries have been attempting to
#   coordinate economic policy in the hope of controlling the
#   decline of the dollar, U.S. trade and budget deficits and other
#   problems.
#       At the same time, the industrial countries see little
#   evidence of a strengthening of economic activity and the Fund
#   forecasts they will grow 2.5 pct.
#       The United States sees 3.2 pct growth for itself,
#   continuing its expansion for a fifth year, and has asked other
#   industrial countries to stimulate their economies.
#       These issues directly affect the debt problem and the
#   ability of the debtor countries to grow out of their
#   difficulties.
#       In recent years, U.S. markets have absorbed the exports of
#   developing country, allowing them to earn critical foreign
#   exchange. But the United States wants to cut its trade deficit,
#   running at a record 169.8 billion dlrs, and is pressing others
#   to import more from developing countries.
#       The discussions, from April six to 10, will be
#   wide-ranging, touching everything from interest rates to the
#   impact of development loans on the environment, according to
#   monetary sources.
#       The talks will include an examination of trade
#   protectionist pressures in the wake of a decision by the Reagan
#   administration to place some 300 mln dlrs in tariffs on
#   microchip products from Japan, the sources said.
#       The move accelerated the dollar's decline as financial
#   markets grew alarmed that trade war was in the offing.
#       There is concern that the action, prompted by U.S. charges
#   that Japan has been selling computer chip products below fair
#   market value and has kept its own market closed to imports,
#   further undermining the international trading system.
#       At the same time, the ministers will discuss the
#   fundamental price weakness in basic commodities, the export
#   mainstay of many developing countries.
#       The so-called Group of Five industrial countries -- the
#   United States, Japan, West Germany, France and Britain -- will
#   gather for the first time since their February talks in Paris,
#   where they agreed to keep the dollar from sliding further.
#       The Five will be joined later by Italy and Canada for
#   further debate on economic policy coordination.
#       As part of the Paris accord, surplus countries such as
#   Japan agreed to stimulate their economies, while America
#   said it would reduce its federal budget deficit.
#       Other major issues of the meetings include a U.S. bid to to
#   have a larger say in approving loans of the Inter-American
#   Development Bank, strengthening the link between loans and
#   economic policy changes in debtor nations.
#       Washington is also pressing the World Bank to take more
#   account of the environment when making loan for dams and other
#   projects.
#       The new head of the Bank, Barber Conable, has said this
#   issue is being reviewed and will be part of a reorganization
#   plan for the Bank, now being prepared.
#
#
#
#
# Documento con ID: 5171:
# SAUDI BUSINESSMEN TO DISCUSS PRIVATE SECTOR
#   Saudi Arabian business
#   leaders assembled for a conference aimed at thrashing out
#   problems facing the private sector of the kingdom's
#   oil-dependent economy.
#       The meeting of some 500 top businessmen from across Saudi
#   Arabia comes at a time of guarded optimism in industry and
#   commerce following the OPEC pact to boost world oil prices.
#       The four-day conference in this resort town, high in the
#   mountains above the Tihamah plain stretching to the Red Sea,
#   has been organised by Saudi Arabia's chambers of commerce.
#       Finance Minister Mohammed Ali Abal-Khail and Commerce
#   Minister Suleiman Abdulaziz al-Salim will attend the first day.
#       Bankers and businessmen said the conference will air
#   problems facing commerce and industry after last year's slide
#   in oil prices and examine ways to promote higher investment in
#   a private sector sorely short of finance.
#       Government planners have long recognised that Saudi Arabia,
#   the world's largest crude exporter, needs to foster private
#   enterprise to diversify its oil-based economy.
#       The fledgling private sector was hard hit by the Middle
#   East recession as early as 1983 and several big manufacturing
#   and trading companies ran into problems repaying loans.
#       Renewed optimism this year stems largely from the accord
#   reached by OPEC last December to curb oil output and boost
#   prices to a benchmark level of 18 dlrs per barrel.
#       With oil prices recovering, Saudi Arabia went ahead at the
#   turn of the year with long-delayed budget plans incorporating a
#   52.7 billion riyal deficit to be bridged by drawing down
#   foreign reserves.
#       The simple act of publishing a budget restored a measure of
#   confidence to the business community.
#       Some share prices have risen by more than 35 pct since last
#   November, while banks are generally reporting a slowdown in the
#   number of new non-performing loans.
#       But not all bankers are convinced. One senior corporate
#   finance manager in Riyadh said: "Banks are still reluctant to
#   lend ... There is certainly more optimism in the air, but I am
#   not sure if it is firmly based."
#       Some businessmen and bankers point out that government
#   spending is still under tight control and the non-oil economy
#   may still be contracting.
#       Capital expenditure on large projects has been cut sharply.
#   A U.S. Embassy report on Saudi Arabia published just before the
#   budget said: "While industrialisation has continued to be one of
#   the government's highest priorities, the recession, the
#   payments problem and the lack of financing have reduced Saudi
#   and foreign investor interest in industry."
#       It is the lack of fresh investment that is expected to be a
#   major issue among the businessmen gathered here.
#       Official figures show the number of new licences for
#   industrial ventures fell 24 pct in the six months to March
#   1986, compared with the same period in 1985.
#       Lending by the Saudi Industrial Development Fund, a major
#   source of industry backing, has fallen steadily since 1983.
#       Trading companies have also been hit, some caught with huge
#   inventories of construction equipment as recession bit.
#       Some firms laid off workers and cut bloated inventories.
#   Others have effectively been liquidated. A few have reached
#   agreement with bankers to extend debt repayments.
#       The latest rescheduling is for the shipping-to-hotels
#   conglomerate REDEC. Its negotiators have just initialled a
#   draft accord to restructure payments on 1.3 billion riyals of
#   bank debt.
#       Bankers and businessmen said the conference was also likely
#   to discuss the apparent reluctance of U.S. And British firms to
#   step up investment in the kingdom.
#       A British government delegation has just left Riyadh after
#   holding preliminary talks on ways of offsetting the huge Saudi
#   outlay on a defence contract to supply 132 fighter aircraft
#   worth five billion stg.
#
#
#
#
# Documento con ID: 5458:
# BRAZIL SAYS DEBT CRISIS IS WORLD PROBLEM
#   Brazilian Finance Minister
#   Dilson Funaro said his country's foreign debt crisis could only
#   be solved by changes in the international financial system.
#       Speaking to a business conference he said "It is not Brazil
#   that has to make adjustments with the IMF (International
#   Monetary Fund). It is the international financial community
#   that is taking away resources from the developing countries."
#       "The crisis is not in Brazil, a country that has had the
#   third biggest trade surplus ...In the past two years Brazil had
#   remitted 24 billion dlrs in debt servicing and received only
#   two billion in fresh funds," he added.
#       Funaro said that during his recent trip to the U.S., Europe
#   and Japan to explain Brazil's decision last month to suspend
#   interest payments on 68 billion dlrs of commercial debt, he
#   stressed the country's commitment to growth.
#       "We need to and will make the effort (to solve the debt
#   problem) but we cannot make an effort that means we stop
#   growing," he said, adding that political and not purely
#   commercial solutions were needed to the debt crisis.
#       Brazil, whose 108 billion dlr foreign debt is the largest
#   in the developing world, has been under pressure from official
#   and private creditors to work out an economic adjustment
#   program with the IMF to combat rocketing inflation and foreign
#   payments problems.
#       President Jose Sarney's government has repeatedly refused
#   to approach the Fund, arguing that an IMF programme would lead
#   to recession. Funaro said that in his talks with creditors he
#   had tried to restore credibility in the country in the hope of
#   finding a lasting solution to the debt problem.
#       "We are negotiating so that the debt question should not be
#   one of continuous crisis."
#       To sustain internal growth Brazil would have to import more
#   machinery and equipment this year and export fewer raw
#   materials. The country was thus targetting a fall in this
#   year's trade surplus to 8.0 billion dlrs from 1986's 9.5
#   billion.
#       Domestically, Funaro said economies had led to a reduction
#   in the public sector deficit to 2.7 pct of gross domestic
#   product in 1986, the lowest for many years and that this should
#   fall to 1.5 pct this year.
#
#
#
#
# Documento con ID: 8029:
# CANADA'S CLARK SEES TRADE AS MOST URGENT PROBLEM
#   Trade is the most urgent problem
#   facing U.S.-Canadian relations because of a pressing need to
#   reach a new bilateral pact within the coming months, Joe Clark,
#   Canadian secretary of state for external affairs, said.
#       Negotiators for the two countries have been meeting for
#   more than a year in an effort to work out an agreement.
#       "The most urgent problem now is the trade question because
#   that has to be decided within the next 10 months," Clark told
#   the Commonwealth Club of California. "We have a fast track
#   authority from your Congress for approval or rejection of
#   whatever the negotiators achieve."
#       Clark said that, as a practical matter, an initial
#   agreement must be reached by late September or early October.
#       He listed environmental questions, particularly acid rain,
#   and defense as the second and third most important bilateral
#   issues facing Ottawa and Washington.
#       On Wednesday, President Reagan announced that he will seek
#   2.5 billion dlrs from Congress to address the acid rain
#   problem. Some interpreted the move as a goodwill gesture in
#   advance of his annual meeting, on April 5-6 in Ottawa, with
#   Prime Minister Brian Mulroney.
#       In a question-and-answer session with the public affairs
#   group, Clark said that the two countries must find better
#   mechanisms for resolving their trade disputes.
#       "This rash of countervailing actions, where we acted on
#   corn and you acted on soft wood and we both said they were
#   quasijudicial -- the dispute resolution mechanisims in place
#   now are not working adequately in either of our interests," he
#   said.
#       Ottawa also is seeking to change some of Washington's rules
#   on government procurement that penalize Canadian businesses, he
#   said.
#       "There are a number of Canadian companies that, in order to
#   secure substantial contracts in the United States, have had to
#   move their head offices out of our country into your country
#   because you have national procurement requirements," he said.
#       In turn, he added, the United States would like to change
#   some of the procurement requirements that exist at the
#   provincial government level in Canada.
#       Clark declined to forecast the outcome of the discussions.
#       "What will come out of it remains for the negotiators, in
#   the first instance, to propose, and then governments and
#   congresses will have judge," he said.
#       In his prepared remarks, Clark said that the United States
#   has tended to take Canada for granted, although it exports to
#   its northern neighbor more than twice what it exports to Japan.
#   "Yet you bought almost 10 per cent more from Japan last year
#   than you bought from Canada," he said. REUTER
